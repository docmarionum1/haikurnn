# %%
import re
import pandas as pd
import inflect
inflect_engine = inflect.engine()

# %%
# Load Phonemes

WORDS = {}

# Standard Dict
with open('cmudict.dict.txt', 'r') as f:
    for line in f.readlines():
        word, phonemes = line.strip().split(' ', 1)
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0]
        phonemes = phonemes.split(' ')
        syllables = sum([re.match(r'.*\d', p) is not None for p in phonemes])
        #print(word, phonemes, syllables)
        if word not in WORDS:
            WORDS[word] = []
        WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })
        
# Load custom phonemes
vowels = ['AA', 'AE', 'AH', 'AO', 'AW', 'AX', 'AXR', 'AY', 'EH', 'ER', 'EY', 'IH', 'IX', 'IY', 'OW', 'OY', 'UH', 'UW', 'UX']

with open('8659.dict.txt', 'r') as f:
    for line in f.readlines():
        word, phonemes = line.strip().split('\t', 1)
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0].lower()
        phonemes = phonemes.split(' ')
        syllables = sum([(p in vowels) for p in phonemes])
        
        if word not in WORDS:
            WORDS[word] = []
        WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })

# %%
df = pd.read_csv('haikus_sballas8.csv', names=['haiku'])
df = df.join(df['haiku'].str.split('\n', expand=True))
# Get ones with exactly 3 lines
df = df.dropna(subset=[0,1,2])
df = df[(((df[3] == '') | pd.isnull(df[3])) & pd.isnull(df[[4, 5, 6, 7, 8]]).all(axis=1))]
#df = df['']

df = df[['haiku', 0, 1, 2]]
df['lang'] = 'en'
df
# Out:
#                                                   haiku  \
# 0     rectory roofers\ntheir ladders\ntake them high...
# 1               summer cabin\nthe ants\ndo the dishes\n
# 2     lagoon at sunrise?\nthe shadow\nchases its pel...
# 3     barren trees\neven the tiniest twig\nembraced ...
# 4             windfall apples\nbees tango\nto a waltz\n
# 5     that foghorn bawl?\ncalf separated\nfrom its m...
# 6              spray art\nthe cherry knows\nno bounds\n
# 7     cold night\nthe escalating heat\nof my old not...
# 8                  fly fishing\nmy thoughts\nuntangle\n
# 9     arrows of geese\nthe puppy chases\nleaves on t...
# 10    absently choking\non a sliver of lemon\nnear-t...
# 11    twilight?\na full moon\nbetween fractured bran...
# 12    at the tulip festival\nshe holds a bouquet\nof...
# 13    random rain splatters\non the sidewalk . . .\n...
# 14    yukon hike\nwater sloshes to the beat\nof the ...
# 15    spring rain . . .\nthe dog's coat finer\nthan ...
# 16    winter solstice . . .\na furlong of a dream\nc...
# 17    autumn sky?\nswaying wheat field\nshaping the ...
# 18    blue sky morning\nthe hospital huffs\nthe only...
# 19    still-life lilies\nresidents sitting\nin the n...
# 20    year's end?\nonly the sound of mouse clicks\nf...
# 21    high tide\nwild blackberry canes\novertake the...
# 22         ocean swim\nnot knowing what's\nbeneath me\n
# 23    stocking\nempty to the toe\nthe spray of citrus\n
# 24    autumn's last month\nstill awaiting\nmy inheri...
# 25    after the rain\nonly a few petals left\nwith t...
# ...                     ...                             ...
# 8212       ice storm ended?     the height of a short man's
# 8213                 hunger              the metallic taste
# 8214            pencil pine             the last of the sun
# 8215           fading stars             stones on the beach
# 8216           his promised                          return
# 8217              escorting                a dead dragonfly
# 8218      grain of the wood              their conversation
# 8219               deep fog          a sax returns the call
# 8220  scent of applewood...                    pork bellies
# 8221         eagle cloud...            the mistral's breath
# 8222         eagle sighting       the passing trucker and i
# 8223            first frost    the scent of coffee reaching
# 8224         the randomness            of where things fall
# 8225     the smell of sweat                      here comes
# 8226          muggy evening                       the whine
# 8227              fireflies           the sparking thoughts
# 8228   the longest drought?                a coyote nuzzles
# 8229          rain at last!        i ask the piano salesman
# 8230             wing beats                    of a pelican
# 8231         i open my eyes       from dreams to daydreams:
# 8232               a pigeon      cooing circles on the dock
# 8233           evening dusk      the clang of pots and pans
# 8234         billiard balls                   on worn felt?
# 8235         summer evening                    dusk falling
# 8236          rice field...         all these extra prayers
# 8237           an undertone           to the orchid's scent
# 8238          coconut grove                leaf blades comb
# 8239           spruce woods                fireweed filling
# 8240        corrugated sun?             chilies and laundry
# 8241          home from war                     we ease out
#
#                                2 lang
# 0               take them higher   en
# 1                  do the dishes   en
# 2             chases its pelican   en
# 3           embraced by the mist   en
# 4                     to a waltz   en
# 5                from its mother   en
# 6                      no bounds   en
# 7             of my old notebook   en
# 8                       untangle   en
# 9             leaves on the wind   en
# 10            near-total eclipse   en
# 11    between fractured branches   en
# 12                 of dandelions   en
# 13                    polka dots   en
# 14              of the bear bell   en
# 15                     than mine   en
# 16               curls inside me   en
# 17              shaping the wind   en
# 18               the only clouds   en
# 19    in the nursing-home lounge   en
# 20               from every desk   en
# 21            overtake the shore   en
# 22                    beneath me   en
# 23           the spray of citrus   en
# 24                my inheritance   en
# 25                 with the rose   en
# 26                     candlelit   en
# 27                       at dawn   en
# 28                                 en
# 29                    passing by   en
# ...                          ...  ...
# 8212                   slam dunk   en
# 8213              of winter wind   en
# 8214                 angles away   en
# 8215                wet with dew   en
# 8216              paper airplane   en
# 8217             100 undertakers   en
# 8218              at the viewing   en
# 8219               of a tug horn   en
# 8220           in the smokehouse   en
# 8221                 in my bones   en
# 8222           share a thumbs-up   en
# 8223            a little further   en
# 8224                  red maples   en
# 8225        the collection plate   en
# 8226      of the battery charger   en
# 8227             of an insomniac   en
# 8228            the jimson weeds   en
# 8229       to riff a little bach   en
# 8230  our'sails?catch?the?breeze   en
# 8231            whirligig beetle   en
# 8232               end of summer   en
# 8233          through a marriage   en
# 8234                    the rain   en
# 8235        through the skylight   en
# 8236                become stars   en
# 8237           somewhere a clock   en
# 8238               the moonlight   en
# 8239                 the vacancy   en
# 8240             in rooftop haze   en
# 8241         the champagne corks   en
#
# [8206 rows x 5 columns]

# %%
# Dictionary of words not found, must go get the phonemes
# http://www.speech.cs.cmu.edu/tools/lextool.html
NOT_FOUND = set()

def get_syllable_count(line):
    if pd.isnull(line):
        return None
    
    counts = [0]
    line = line.lower()

    # Replace numeric words with the words written out
    ws = []
    for word in line.split(' '):
        if re.search(r'\d', word):
            x = inflect_engine.number_to_words(word).replace('-', ' ')
            ws = ws + x.split(' ')
        else:
            ws.append(word)

    line = ' '.join(ws)

    for word in line.split(' '):
        try:
            word = re.match(r'[\'"]*([\w\']*)[\'"]*(.*)', word).groups()[0]

            if word:
                if word not in WORDS:
                    word = word.strip('\'')
                syllables = set(p['syllables'] for p in WORDS[word])
                #print(syllables)
                new_counts = []
                for c in counts:
                    for s in syllables:
                        new_counts.append(c+s)

                counts = new_counts
        except:
            NOT_FOUND.add(word)
            return None

    return ','.join([str(i) for i in set(counts)])

# %%
for i in range(3):
    df['%s_syllables' % i] = df[i].apply(get_syllable_count)
    
print(NOT_FOUND)

df
# Out:
# set()
#                                                   haiku  \
# 0     rectory roofers\ntheir ladders\ntake them high...
# 1               summer cabin\nthe ants\ndo the dishes\n
# 2     lagoon at sunrise?\nthe shadow\nchases its pel...
# 3     barren trees\neven the tiniest twig\nembraced ...
# 4             windfall apples\nbees tango\nto a waltz\n
# 5     that foghorn bawl?\ncalf separated\nfrom its m...
# 6              spray art\nthe cherry knows\nno bounds\n
# 7     cold night\nthe escalating heat\nof my old not...
# 8                  fly fishing\nmy thoughts\nuntangle\n
# 9     arrows of geese\nthe puppy chases\nleaves on t...
# 10    absently choking\non a sliver of lemon\nnear-t...
# 11    twilight?\na full moon\nbetween fractured bran...
# 12    at the tulip festival\nshe holds a bouquet\nof...
# 13    random rain splatters\non the sidewalk . . .\n...
# 14    yukon hike\nwater sloshes to the beat\nof the ...
# 15    spring rain . . .\nthe dog's coat finer\nthan ...
# 16    winter solstice . . .\na furlong of a dream\nc...
# 17    autumn sky?\nswaying wheat field\nshaping the ...
# 18    blue sky morning\nthe hospital huffs\nthe only...
# 19    still-life lilies\nresidents sitting\nin the n...
# 20    year's end?\nonly the sound of mouse clicks\nf...
# 21    high tide\nwild blackberry canes\novertake the...
# 22         ocean swim\nnot knowing what's\nbeneath me\n
# 23    stocking\nempty to the toe\nthe spray of citrus\n
# 24    autumn's last month\nstill awaiting\nmy inheri...
# 25    after the rain\nonly a few petals left\nwith t...
# 26        empty restaurant\nall the tables\ncandlelit\n
# 27    spring again . . .\na songbird's paean\nat dawn\n
# 28                     the busker\nbuttons his collar\n
# 29    rolling thunder\nthe bass on the car stereo\np...
# ...                                                 ...
# 8212  ice storm ended?\nthe height of a short man's\...
# 8213       hunger\nthe metallic taste\nof winter wind\n
# 8214    pencil pine\nthe last of the sun\nangles away\n
# 8215  fading stars\nstones on the beach\nwet with dew\n
# 8216             his promised\nreturn\npaper airplane\n
# 8217     escorting\na dead dragonfly\n100 undertakers\n
# 8218  grain of the wood\ntheir conversation\nat the ...
# 8219  deep fog\na sax returns the call\nof a tug horn\n
# 8220  scent of applewood...\npork bellies\nin the sm...
# 8221  eagle cloud...\nthe mistral's breath\nin my bo...
