# %%
import time

from bs4 import BeautifulSoup
from langdetect import detect
import pandas as pd
import requests

# %%
i = 0
haikus = []

# %%
while True:
    time.sleep(.2)
    response = requests.get('http://www.tempslibres.org/tl/tlphp/dbhk03.php?id=%s&lg=e' % i)
    soup = BeautifulSoup(response.text, 'html.parser')
    lines = soup.find('p', 'dbhkanahaiku').get_text().splitlines()
    if lines:
        if '' in lines:
            haiku = lines[:lines.index('')]
        else:
            haiku = lines

        print(i, haiku)
        haikus.append(haiku)
        
    i += 1
# Out:
# 3 ['kiri saite', 'suterare mura ni', 'haka nokoru']
# 4 ['de son fauteuil roulant', "l'enfant ne voit par la fenÃªtre", 'que le ciel']
# 5 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 6 ['Memorial Day --', 'a shadow for each', 'white cross']
# 7 ['spring rain -', 'as the doctor speaks', 'i think of lilacs']
# 8 ['spring moonset --', 'a rice ball for', 'breakfast']
# 9 ['sunny afternoon', 'an old man lingers', 'near the mailbox']
# 10 ['cinco de mayo', 'horses roll', 'in the shallows']
# 11 ['quitting time', 'the smell of rain', 'in the lobby']
# 12 ['waves', 'slowly cresting towards shore', 'a faint moon']
# 13 ['overnight rain --', 'the scent of orange blossoms', 'in a desert town']
# 14 ['haru no ame', 'mukashi mukashi no', 'monogatari']
# 15 ["l'orage ce matin", 'un demi-cercle parfait', 'du rosier en fleurs']
# 16 ['misty summer rain', 'calling pheasant', 'in Zen temple']
# 17 ['day is done', 'poppies amidst', 'the dying grass']
# 18 ['urban geese -', 'voices extemporise', 'around a sitar']
# 19 ['watching clouds', 'the white petals', 'of a crushed crocus']
# 20 ['mountain stream', '   two well placed rocks', 'the path home']
# 21 ['AprÃ¨s la pluie -', 'des capsules de biÃ¨re', 'au bord du chemin']
# 22 ['night shift--', 'in the parking lot car lights', 'dim near morning']
# 23 ['a wild violet', 'on the sunny hill~', 'noon time nap']
# 24 ['a sunny day', 'pink haze of the cherry blossoms', 'over the hill']
# 25 ['macchie di rosso...', 'soltanto papaveri', "nell'erba verde"]
# 26 ['polished oak --', "the freesia's shadow ends", 'in coffee foam']
# 27 ['matin de banlieue', "les escargots gagnent l'herbe", 'de la voie ferrÃ©e']
# 28 ['nobody here', 'a table in the mountain', 'speckled with petals']
# 29 ['first date', 'not even noticing', 'the new moon']
# 30 ['vanishing difference . . .', '  gliding geese settle onto', '    their reflections']
# 31 ["Ã\xa0 l'horizon", 'la ligne jaune', 'du colza']
# 32 ['sentier dÃ©sert', 'plus aucun passage', 'entre les orties']
# 33 ["bruit d'avion", 'la boule de pissenlit', 'perd ses graines']
# 34 ['distant hawk', 'a gust of cherry petals', 'crosses the lawn']
# 35 ['multicolore', 'la lessive des voisins - ', 'pommiers en fleurs']
# 36 ['Orange sunrise peaks through', "The tubes and wires of father's", 'Life support machine']
# 37 ['moonlessness--', 'so many ways', 'I want to touch you']
# 38 ['earth day--', 'even the shadows at dusk', 'smell green']
# 39 ['le niveau baisse', 'les pattes des flamands roses', 'rallongent']
# 40 ['so cold -', 'a goose honks its way', 'across the night sky']
# 41 ['damp straw . . .', '   the day-old colt mesmerized', '       by the radio']
# 42 ['prying', '   at the window . . .', '       wind']
# 43 ["in winter's wind", 'the call of a friend', 'who now has cancer']
# 44 ["fin de l'hiver-", 'les graines de ciboulette', 'au creux de ma main']
# 45 ['rainy bridge-', 'the river flowing', 'faster']
# 46 ['spring breeze-', "the balcony's shadows", 'on my book']
# 47 ['winter drizzle', 'all the passing faces look', 'into the cafe']
# 48 ['smells of spring', 'adrift in the morning air', 'bubbles under ice']
# 49 ['Spring morning', 'your hand on my breast', 'a bird']
# 50 ['crossroads', 'the brown core', 'of an apple']
# 51 ['hot afternoon', 'a flirting couple', "in the memorial's shade"]
# 52 ['last red in the sky', "a small girl's moon face rises", 'over the counter']
# 53 ['day moon', 'the woman with silver hair', 'steps back into the shade']
# 54 ['morning delivery --', 'snow comes in', 'with the FedEx man']
# 55 ['Easter--', 'an anxious mother calls', 'in the wind']
# 56 ['lumiÃ¨re du bureau', 'une courte ombre', 'autour de la pomme']
# 57 ['premiers crocus fanÃ©s', 'de plus en plus variÃ©', 'le chant des oiseaux']
# 58 ['windless day', 'the prolific weeds', 'at the grave site']
# 59 ['nel crepuscolo', 'voli di cormorani', "e sciacquio d'onde"]
# 60 ['Spring day', 'cool and grey', 'cup of tea']
# 61 ['Grey today', 'the waves rush', 'memories']
# 62 ['en mode vibreur', 'le tÃ©lÃ©phone avance', 'vers la poubelle']
# 63 ['paon de Maguelone', 'ses plumes bleu outremer', 'entre mer et ciel']
# 64 ['Ã©quinoxe de mars', 'la lune au-dessus du toit', 'est coupÃ©e en deux']
# 65 ["le prunus, tout rose     face Ã\xa0 l'Ã©choppe du fleuriste    fermÃ©e le lundi!"]
# 66 ['Spring equinox', 'Pray the ancestor grave', 'In cold rain']
# 67 ['folding chair', 'the newborn colt tries', 'to stand']
# 68 ['scattered sun --', 'one chickadee', 'louder than the rest']
# 69 ['orthopaedic clinic', 'a three-legged chair', 'outside the entrance']
# 70 ["the plane's landing lights", 'a wave of barking', 'sweeps the neighbourhood']
# 71 ['lilas roux', 'derriÃ¨re la grille rouillÃ©e', "le chant d'enfant"]
# 72 ['the way grass parts', 'as the pheasant passes', "spring's end"]
# 73 ['at half-mast', 'a butterfly passes by', 'the still flag']
# 74 ['half asleep -', 'the rhythm of the', 'receding rain']
# 75 ['evening service --', 'light beams', 'into the night']
# 76 ['ooame ya', 'tobimawaru wa', 'shiroki cho']
# 77 ['watching summer clouds', 'thoughts shaping and', 'reshaping']
# 78 ['geese honking---', 'children in the', 'bathtub playing']
# 79 ['Des pyjamas noirs', 'Ã©bouriffÃ©s par le vent.', 'Envol des corbeaux.']
# 80 ['rabbit trail', 'nothing but ears', 'above the snow']
# 81 ['late night at the office', 'an exit sign floats', 'next to the moon']
# 82 ['celtic harp', 'the first raindrops touch', 'my cheeks']
# 83 ['traffic jam', 'three saffron-robed men munch nuts', 'in their SUV']
# 84 ["Valentine's Day", 'a forsythia', 'without birds']
# 85 ['early spring air', 'all day long', 'our beds not made']
# 86 ['husband away', 'washing his socks', 'by hand']
# 87 ['her fresh flowers -', 'his fresh grave', "valentine's day"]
# 88 ['valentines -', "the mailman's steps", 'break the ice']
# 89 ['only two pinecones', 'on the park bench ~', "Valentine's day"]
# 90 ['lit dÃ©fait', 'un sourire sur le bord', 'de la flÃ»te vide']
# 91 ['lakeside,', 'below the egret---', 'a city of lights']
# 92 ['hedgerow birds', 'three boys share a spliff', 'by the school gate']
# 93 ['after the rain', 'moon and stars', 'underfoot']
# 94 ['dwindling bonfire', 'a shooting star', 'near Orion']
# 95 ['cold night-', 'a plane blinks through', "Orion's bow"]
# 96 ['dark tree silhouettes', 'low on the horizon', 'Orion rises']
# 97 ['Science day', 'the programme begins', 'with rituals']
# 98 ['traffic argument', "the camel's sneer", 'is impartial']
# 99 ['jour vide et lent', "aprÃ¨s l'avoir mis dehors -", 'Ã©toile filante']
# 100 ['winter stars', 'suddenly a whiff', 'of perfume']
# 101 [' trains come and go', 'but the same people', 'drinks at bar']
# 102 ['first raindrops', 'the freight train I passed', 'two states ago']
# 103 ['silhouette. . .', '  a shining snow path to', '     a pale moon']
# 104 ['thousands of miles', 'away, her first birthday---', 'fresh mango']
# 105 ['swimming across', 'the moonlit sky---', 'a gray carp']
# 106 ['half moon', 'darkness drinking from an', 'alabaster teacup']
# 107 ['floating', 'down river', "an egret's shadow"]
# 108 ['a McDo box', 'floats towards the fountain', 'insect on board']
# 109 ['Jouseki ni Jizo nokorite Yuki no koe']
# 110 ['Futo ni Furansu to kaku Yuki moyohi']
# 111 ['new year...', 'a magpie turns over', 'an old leaf']
# 112 ['new year', 'fireworks', 'in a misty sky']
# 113 ['silence', 'the moon breaks through', 'the firework smoke']
# 114 ['nuit de dÃ©gel -', 'le bonhomme de neige', 'est parti sans sa pipe']
# 115 ['Calligraphes au temple -', 'priÃ¨res pour les blaireaux', 'donneurs de poils']
# 116 ['Premier ciel dÃ©gagÃ© -', 'entre Orion et sa chienne', 'un avion gronde.']
# 117 ['spring mist', 'the tree I take shelter under', 'planted in remembrance']
# 118 ['lingering cold...', 'the last jar of maple syrup', 'on the cupboard shelf']
# 119 ['oh moon, moon', 'above so much powdery snow', 'father is still ill']
# 120 [" jour d'Ã©tÃ©", 'deux Ã¢nes suivent leur ombre', 'sur la route']
# 121 ['vent de sable', 'les dunes disparaissent', 'une odeur de thÃ©']
# 122 ['Tourbillons de neige', 'des fleurs blanches', 'dans le magnolia']
# 123 ['tempÃªte en mer', 'hurlements de haubans', 'cartes sur la table']
# 124 ['deepening snow--', 'she leaves our atlas open', 'to her homeland']
# 125 ['familiar names-', 'the warmth of a woodstove', 'in January']
# 126 ['eddying leaves', "the old woman's wrinkled face", 'and saree']
# 127 ['morning mist', 'the iora is gone', 'before I recall its name']
# 128 ['drifting fog', 'the house across the road', 'reappears']
# 129 ['le dÃ©gel', 'dans une fenÃªtre Ã©troite', 'la demi-lune']
# 130 ['...vos haikus estivals', 'une note des poires et des myrtilles', 'dans le thÃ©']
# 131 ['la neige tombe', 'un peu inclinÃ©e', 'la lune']
# 132 ["soleil d'hiver", 'le plat de ma main', 'sur la vitre froide']
# 133 ['kirinoyoni amaikaorino shirokiume']
# 134 ["Sur l'Ã©cran Ã©teint,", 'toute ma bibliothÃ¨que', 'au soleil!']
# 135 ['fading', 'right before my eyes', 'morning moon']
# 136 ['morning glories', 'find their way to the sun', 'on barbed wire']
# 137 ['summer rain', 'the smell of earth', 'in the air']
# 138 ['early spring', 'everything', 'dripping']
# 139 ['more rain -', 'mildew colors', 'the old roof']
# 140 ['mountain storm', 'somewhere during its echo', 'the thunder ends']
# 141 ['even my pee', 'stays inside this', 'cold winter night']
# 142 ['snowfall---', 'a milk mustache', "on my daughter's face"]
# 143 [' drowned', 'in the sound of the rain', 'other familiar sounds']
# 144 ['lentement', 'le scarabÃ©e avance', 'tempÃªte de juin']
# 145 ['sun dog--', 'so many names', 'carved on the cliff ']
# 146 ['Fly,', 'be afraid!', 'No Buddhists in this house!']
# 148 ["pendant l'arrosage   les pages de mon livre   au vent de juillet"]
# 149 ['sundown', 'summer evening melts in dark', 'fragrance of tea~']
# 150 ['before dinner...', 'the spider and a fly', 'share the sunset']
# 151 ['he kissed me', 'on the fourth of july', 'fireworks!']
# 152 ['working late', 'the sound of a small brown moth', 'in the lampshade']
# 153 ['in the yard', 'between our argument -', 'a red dragonfly']
# 154 ['free floating', 'a tide full of shell fragments', 'and fireworks ']
# 155 ['late summer rain --', 'two kids break the bottles', 'under the bridge']
# 156 ['morning fog', "the bluebird's call", 'clearly audible']
# 157 ['nuit orageuse -', 'le bourdonnement', "d'une moissonneuse"]
# 158 ['nuit de pleine lune -', "un moustique sur l'Ã©cran", "de l'ordinateur"]
# 159 ['rain', 'the sound of a horse galloping', 'through leaves']
# 160 ["pÃ¨re et fils dans l'eau", 'la jeune mÃ¨re voilÃ©e', "dans l'ombre"]
# 161 [' too hot to sleep', "i search for my son's footprint", 'in the front drive']
# 162 ['the boat crests a wave -', 'tracing my finger around', 'an ancient stone']
# 163 ['a mosquito', 'aiming noisily <>', 'the sound of one hand']
# 164 ["zÃ©brures dans l'espace", 'le store se coule dans la rue', 'par une fenÃªtre']
# 165 ['novocain prick--', 'the warmth where', 'the dental nurse leans']
# 166 ['the smell', 'of many campfires', 'in this old hunting shirt']
# 167 ['sculpting', 'clay, the potter', 'at dawn']
# 168 ['master wind', 'sweeping the temple', 'zealously']
# 169 ['house cleaning---', 'the forest fire', 'at dawn']
# 170 ['metal birds', 'fly south to the', 'forest fire']
# 171 ['thunderstorm --', 'a shadow pauses', 'at the gate']
# 172 ['ticket de mÃ©tro -', 'juste assez de place', 'pour un haÃ¯ku']
# 173 ["crickets' songs", 'in the pitch-dark night --', 'how many secrets']
# 174 ['earthquake', 'with the typhoon -- more coins', 'at the temple']
# 175 ['food channel', 'between commercials', 'dinner burns']
# 176 ['fading this', 'autumn night---', "the heron's legs"]
# 177 ['we sip sweet tea', 'in silence. . .', "a soldier's mother"]
# 178 ['autumn visit -', 'over war news we talk', 'of babies . . .']
# 179 ['fireside -', "a son's face smiles down", 'from the mantelpiece']
# 180 ['remembering summer', 'how brittle the leaves', 'underfoot']
# 181 ['Les moustiques', 'dans ma nouvelle maison', "ne m'ont pas suivi"]
# 182 ["Orage d'Ã©tÃ©", 'le petit linge de ma voisine', 'bien accrochÃ©']
# 183 ['deep in the night', 'my computer turned off --', 'sound of autumn rain']
# 184 [" chemin de l'Ã©cole", 'deux vaches portent avec leurs cornes', 'le soleil']
# 185 ['no more war', 'two fighting beetles', 'on a tombstone']
# 186 ['near the wall', 'of the cemetery', 'a condom']
# 187 ['during the vigil', 'a withered flower', 'on the tiled floor']
# 188 ['no moon--', 'the individual', 'songs of crickets']
# 189 ['mur du cimetiÃ¨re', 'la vigne vierge dÃ©borde', 'rouge en octobre']
# 190 ['the smell of water between the iron pump and cup']
# 191 ['indian summer-', 'rouging her cheeks', 'as she waits for a drink']
# 192 ['vents et pluie', 'entre les montagnes', "le dos d'une baleine"]
# 193 ['pour le goÃ©land', 'dÃ©jeuner de moucherons', 'sur dos de baleine']
# 194 ['egrets', 'plucking shadows', 'at dusk']
# 195 ['sugar for the tea', 'behind the bowl', 'a line of ants']
# 196 ['fire ant mound', 'against the flower pot', 'after the rain']
# 197 ['forgetting my words', 'step by step', 'the autumn night deepens']
# 198 ['parc dÃ©sert', 'tapis de feuilles jaunes', "qu'un chat roux foule"]
# 199 ['loud pub music', 'a long silence', 'between the flirting couple']
# 200 ['la nuit qui fraÃ®chit', "le buste de l'astronome", 'manteau sur le dos']
# 201 ['autumn bonfire â\x80\x93', 'all my summer dreams', 'scatter with the smoke']
# 202 ['fading light -', 'a red leaf bouquet', 'at the smallest grave']
# 203 ['out of the city,', 'so many stars', 'unnamed']
# 204 ['marbres Ã©blouissants', 'grincements des robinets', 'temps de la Toussaint']
# 205 ['solo trip', 'in the campfire smoke', 'old memories']
# 206 ['les feuilles rouges', 'les premiÃ¨res Ã\xa0 tomber', 'un porto ce soir']
# 207 ['one hundred views', 'of the sunrise -', 'appartment block']
# 208 ['doves', 'on the TV antenna', 'war on TV']
# 209 ['the red maple-', 'striptease', 'in the driveway']
# 210 ['Le cliquetis du sÃ©cateur', "dans les branches de l'oranger-", 'la mÃ©tÃ©o annonce du froid']
# 211 ['pumpkin moon:', 'tai chi movements time', 'the eclipse photos']
# 212 ['frost', 'on the pumpkin:', 'lunar eclipse']
# 213 ['All Saints Day -', 'in the field only small', 'pumpkins are left']
# 214 ['all hallows eve---', 'stars paint the', 'cemetery ground']
# 215 ['all saints day---', 'spent candles', 'in the cemetery']
# 216 ['dark clouds---', 'a student drawing', 'with charcoal']
# 217 ['sur le carrelage blanc', 'elle semble encore plus grosse', "l'araignÃ©e du radiateur"]
# 218 ["l'Ã©corce du pommier", 'rongÃ©e un peu plus haut', 'cette annÃ©e']
# 219 ['BrÃ»lerie', "l'odeur du cafÃ©", 'un chien qui renifle']
# 220 ['Best Of Mac Donald', 'deux limaÃ§ons roux', 'sur une frite']
# 221 ["le faÃ®te de l'arbre", 'chatouille le nez', 'du grand Bouddha']
# 222 ['dehors passe un train', 'de wagons jaunes, dans le bar', "soudain tout s'Ã©claire."]
# 223 ['chemises Ã\xa0 repasser', 'montagne de coton, soupir', 'bruit de vapeur']
# 224 ['typhoon passed--', 'one watering can', 'in the sandbox']
# 225 ['typhoon passed--', 'comes the', 'local circus']
# 226 ['red dragonflies', 'gather around the', 'blind person']
# 227 ['letter from overseas', 'a call from southward geese', 'penetrates the thicket']
# 228 ['indian summer', "the neighbor's daughter sunbathes", 'beside their empty pool']
# 229 ['scent of roses --', 'counting the stars', 'one by one']
# 230 ['eating rice---', 'how many stars are', 'in the sky ?']
# 231 ['falling leaves---', 'a trail of clothing', 'leads to the bed']
# 232 ['biting his nails,', 'a little boy watches', 'the outgoing tide']
# 233 ['cold night---', 'my reflection', 'sipping coffee']
# 234 ['November moon', 'the last ball of cheese', 'in the fridge']
# 235 ['pleine lune sans nuages', 'cinq doigts tambourinent', 'sur-une-chute-de-reins']
# 236 ['the Thanksgiving meal -', 'after eating the talk', 'slows down']
# 237 ['around where the', 'steppingstone ends off', 'autumn gone']
# 238 ['dawn --', "the maple's colors", 'spread through the fog']
# 239 ['geriatric ward--', 'the table groans', 'when they fold it up']
# 240 ['rouge sang', 'dans les mÃ¢choires de la benne', 'le dahlia']
# 241 ["sous l'Ã©pervier", 'faisant le Saint Esprit :', 'un tas de fumier']
# 242 ['watching', 'the lunar eclipse', 'a dead rose']
# 243 ['moon viewing---', 'just me and spider', 'tonight']
# 244 ['moon viewing---', 'warming my hands', 'with a cup of coffee']
# 245 ['Halloween night', 'ghosts and goblins', 'watch the rain']
# 246 ['burning leaves --', 'Kerry concedes', 'the election']
# 247 ['downpour -', "the pumpkin's smile", 'goes out']
# 248 ['indian summer', 'the viagra stock', 'deflates']
# 249 ["chemin Ã\xa0 l'aube", "l'ouvrage des araignÃ©es", 'sur mon front']
# 250 ['Un escargot', "dans l'oeil droit de la citrouille-", "lendemain d'Halloween"]
# 251 ['Sur le fil Ã\xa0 linge', 'un oiseau en Ã©quilibre-', 'quelque part Ã\xa0 Fallouja']
# 252 ['an old temple', 'amongst cedar trees', 'too many leaves fallen...']
# 253 ['from an old temple', 'to an old temple', 'autumn wind']
# 254 ['hundreds of', 'gentians blooming--', 'class reunion']
# 255 ['a new day --', "the priest's robes", 'fill with snow']
# 256 ['late harvester --', 'sickle moon in the sky', 'over the mature corn']
# 257 ['silent phone', 'only the ring', 'from his teacup']
# 258 ['the teacup', 'as empty as', 'my evening']
# 259 ['a teacup', 'to fill', 'my afternoon']
# 260 ['my day', 'measured out', 'in teaspoons']
# 261 ['discarding', 'the tea leaves--', 'distant thunder']
# 262 ['mÃ©lÃ¨ze roux', 'herbe bleue -', "l'aube"]
# 263 ['dans le velux', 'jambes enchevÃªtrÃ©es', 'et neige']
# 264 ['la route de travail', 'dans les feuilles et les galets', 'un sillon profond']
# 265 ['ce soir dans la rue', 'un parfum du chocolat', 'noir']
# 266 ['les dos noirs des pierres tombales', "-- quelques couleurs Ã\xa0 l'horizon", 'aprÃ¨s le coucher de soleil']
# 267 ['moonlight', "baby's cheek", 'at breast']
# 268 ['cold night', 'the clink of bottles', 'in a grocery cart']
# 269 ['contemplating', 'nightfall---', 'the stone buddha']
# 270 ['the offering', 'in front of the stone buddha', 'eaten by cats']
# 271 ['between two rivers,', 'the echo of', 'his mallet']
# 272 ['sunday afternoon---', 'a steam train', 'pushes back the fog']
# 273 ['winter clouds', 'seem to move slower too', 'in the cold night']
# 274 ['it happened', 'just after the full moon', 'snow']
# 275 ['long-distance train', 'men on the platform', 'talk on their mobiles']
# 276 ['two minutes silence', 'a cell phone keeps ringing', 'Nehru smiles from his frame']
# 277 ['Venus', 'a faint glow', 'from the refinery']
# 278 ['Mimi kakishi', 'Ato mata muon', 'Miyukibare']
# 279 ['terrasse au midi', 'toutes les ombres', "sentent l'anis"]
# 280 ['flocon de neige', 'sans une parole, la femme', 'bÃ¢illonnÃ©e']
# 281 ['predawn', 'a grey dove outside', 'my window']
# 282 ['solstice', 'a shaft of sunlight', 'through rock']
# 283 ['rainburst--', 'thoughts of you', 'fading']
# 284 ['desert wind', "the potter's fingerprints", 'on an ancient shard']
# 285 ['another test', 'another doctor visit', 'long winter nights']
# 286 ['arctic air', 'soothes the desert heat . . .', 'blended whiskey']
# 287 ['December dusk -', 'a solitary pine tree', 'all lit up']
# 288 ['christmas services', 'a cellular phone rings out', "handel's messiah"]
# 289 ['dried wheat grass---', 'a bleached blond', 'combing her hair']
# 290 ['no stars', 'in the sky tonight', 'hungry carp']
# 291 ['breathless --', 'camellias falling', 'one by one']
# 292 ["musÃ©e de l'armÃ©e --", 'les casques allemands', 'sont attachÃ©s']
# 293 ['in the dry grass', 'frost appears', 'on the fallen pears']
# 294 ['slate skys', 'chalk mark outlines', 'on the sidewalk']
# 295 [' food channel --', 'between commercials,', 'dinner burns']
# 296 ['autumn', 'along the highway', 'buzzards wait']
# 297 ['together', 'we watch the eclipse', 'far apart']
# 298 ['last leaves', 'shaking on a branch', 'late migrators']
# 299 ['empty sky', 'she turns love letters', 'into wings']
# 300 ['a butterfly', 'hovers above me', "friend's funeral"]
# 301 ['Entre le tilleul', 'et le monument aux morts', 'dÃ©filÃ© de feuilles.']
# 302 ['sortie du mÃ©tro', 'polyphonies corses', 'tÃ©lÃ©phoniques']
# 303 ['sur la neige', "un petit sac d'ordures bleu", 'couleur du ciel']
# 304 ['windstorm', 'the berry stains', 'on the path']
# 305 ['Remembrance Day-', 'even the traffic', 'pauses for 2 minutes']
# 306 ['21-gun salute-', 'mortar fire echoes', 'in his eyes']
# 307 ['dignified march-', 'veterans and peacekeepers', 'pass the applause']
# 308 [' bare trees', 'in patches of fog', 'from here', 'to the scarecrow']
# 309 ['wild fires', 'in the mist', 'the ashes']
# 310 ['growing darkness', 'gleam of setting sun', 'on Chinese Lantern']
# 311 ['rain scented air', 'a thousand frogs', 'croaking']
# 312 ['grey sky', 'the cluster of white breaks up', 'into egrets']
# 313 ['night traffic', 'the silent lake', 'seems much bigger']
# 314 ['little pawprints', 'in the concrete', 'from the lost kitten']
# 315 ['Danube dripping', "from a housewife's bag", 'the tail of a carp']
# 316 ['Nuit des Sans-abri']
# 317 ['nuages chair de poisson', "sur le pare-brise de l'ambulance"]
# 318 ['secousses du tramway', "pointe de l' hameÃ§on", 'au soleil']
# 319 ['la lune blanche', 'un peu fondu', 'le givre sur les toits']
# 320 ['amefuri no', '  minoru kaki yori', '     hito shizuku']
# 321 ['false dawn', 'sometimes i still', 'think of home']
# 322 ['first frost -', 'a twirl of yellow leaves', 'as the bus passes']
# 323 ["aprÃ¨s l'orage", 'tout le monde en bave', "mÃªme l'escargot"]
# 324 ['the same moon', 'shines on us both --', 'these cold sheets']
# 325 ['sodium light -', 'a darker world beneath', 'the puddles']
# 326 ['lockerbie -', 'the long walk from graveyard', 'into town']
# 327 ['silbury hill -', 'my wife pregnant with our', 'first child']
# 328 ['north winds â\x80\x93', 'snow flakes and', 'the smell of smoke']
# 329 ['burning leaves', 'this foggy evening---', 'two kinds of smoke']
# 330 ['stoplight', 'each of us tapping', 'to our own beat']
# 331 ['laundry encounter', 'a plastic shark', 'falls out of a bath towel']
# 332 ["'seven samurai' *", 'half the village burning', 'while my son makes popcorn']
# 333 ['hard winter ground -', 'we argue about', 'the constellations']
# 334 ['road accident', 'a crowd of teddies stares out', 'from the shop window']
# 335 ['giorni piÃ¹ brevi', 'nella cesta dei cachi', 'un grillo morto']
# 336 ['deep night', 'one cricket chirps', 'anyhow']
# 337 ['ants transport a moth', 'traffic noise penetrates', 'the bamboo grove']
# 338 ['autumn breakfast', "the last mosquito's hover", 'over my campfire']
# 339 ['passing monarchs --', 'a few leaves flutter', 'to the road']
# 340 ['waiting for winter---', 'eating rice balls', 'under a full moon']
# 341 ['scooping steamed rice,', 'the laborer', 'at sundown']
# 342 ['windswept afternoon---', 'tea scent', 'on my tongue']
# 343 ["physalis sÃ©chÃ©s - le couteau noir, posÃ© pour peler l'orange"]
# 344 ["grandfather's grave", 'just another stone', 'for the dragonfly']
# 345 ['a sleepless hour', 'first the geese', 'then the train']
# 346 ['fall clock', 'the deer by the pond', 'an hour earlier']
# 347 ['morning troubles', 'it starts with a dead cricket', 'in the spider web']
# 348 ['cotton fields*', 'the only white left', 'is the snow']
# 349 ["l'imprimante crache", 'le phÃ©nix millÃ©naire--', 'une autre feuille']
# 350 ["Brumes d'octobre", 'le bruit de la corne', 'sans le bateau']
# 351 ['peach moon . . .', 'the thin slice left', 'for us']
# 352 ['grassy moon', 'we slip off our shoes', 'to count the stars']
# 353 ['alba brumosa', 'funghi rossi crescono', 'fra le tombe']
# 354 ['sulla collina', 'gregge di case sparse', 'senza pastore']
# 355 ['barbone morto', 'passaggio di stagione', 'tra i rifiuti']
# 356 ["l'ombre", 'de son piercing au menton', 'marque midi']
# 357 ['par la fenÃªtre -', 'un bleu comme Ã§a', 'pour nos fauteuils']
# 358 ['the fish lazily surface', 'in the pond nearby ~', 'the sun on my teacup']
# 359 ['Parting the fog', 'blue nose of the ferry', 'homeward bound']
# 360 ['Autumn sky', 'many layers of clouds', 'pile of leaves']
# 361 ['Autumn sky', 'shades of pink and purple', 'field of pumkins']
# 362 ['last light', 'sounds of crows settling', 'in the tree']
# 363 ['Week-end Ã\xa0 la campagne.', "Du trÃ¨fle que sous l'auto -", 'premiÃ¨re neige.']
# 364 ['ce matin', 'le rouge des tramways', 'premiÃ¨re neige']
# 365 ['une nouvelle voiture', 'la feuille se pose plus loin', '-- bruine']
# 366 ['5 heures du matin', 'derriÃ¨re la buÃ©e du souffle', "ceinture de l'Orion"]
# 367 ['chirping birds --', 'the instant I press', 'the stop button']
# 368 ['plasma tv -', 'in high resolution', "the homeless man's face"]
# 369 ['the sound of geese', 'drowned by the sound of the train', 'this morning']
# 370 ['At breakfast', 'after first sip of coffee', 'i notice a rainbow']
# 371 ['cicadas', 'at twilight', 'finally it rains']
# 372 ['la veranda', 'avant la mise en bocaux -', 'senteurs de pÃªches']
# 373 ['fading bougainvillea', ' in the night sky . . .', '    mars!']
# 374 ['afternoon lull', 'the traffic island', 'crowded with pigeons']
# 375 ['bike tail lights', 'a lingering smell', 'of perfume']
# 376 ['quiet lane', 'after the jasmine', 'smell of fried onions']
# 377 ['gentle', 'on my window', 'summer rain', 'and his whispers rising', 'falling, rising. . .']
# 378 ["summer's end-", 'a cool rain slides', 'down the hollyhocks']
# 379 ["summer's end", 'my hand lingers', 'in the dry grass']
# 380 ['hungry', 'half of the moon', 'hidden']
# 381 ['rain', 'another leaf', 'down']
# 382 ['sharia', 'the sound of one hand', 'clapping']
# 383 ['evening flares', "at summer's end", 'fireflies']
# 384 ['acorn falls', 'the sound of rain', 'continues']
# 385 ['Au premier matin', "de l'automne, le gong vibre", 'jusque dans les chaumiÃ¨res.']
# 386 ['Matin brumeux.', 'Sans cesse elle croise ses doigts', "-- marque d'une bague."]
# 387 ['First day of autumn', 'splash of a spawning salmon', 'another cycle begins']
# 388 ['Last day of September', 'bay and islands in fog', 'aroma of coffee']
# 389 ['First day of October', 'the morning sun in my eyes', 'clank of the furnace']
# 390 ['A fine mist', 'covers the tall cedars', 'foggy glasses']
# 391 ['les jours rÃ©trÃ©cissent', 'la petaside dessÃ©chÃ©e', "n'est plus aussi grande"]
# 392 ['splatting drops . . .', '  moments ago they held', '      a rainbow']
# 393 ['hillside thunder', 'barely a rainbow in a plume', 'of smoke']
# 394 ['morning camp', 'only an ember remains', "but it's enough"]
# 395 ['tra i lampi', 'il suono della cavalletta', 'ancora un poco']
# 396 ['blackout --', 'how bright Mars shines', 'this summer night!']
# 397 ['rush hour ~', 'closing the car window', 'on my hair']
# 398 ['aprÃ¨s la pluie', 'sur le mur - tisse encore', "l'araignÃ©e"]
# 399 ['black-out--', 'the holiday glow', 'of fireflies']
# 400 ['black-out--', "in my neighbor's house", 'a room to room glow']
# 401 ['warmed-over coffee--', 'the gray gray sound', 'of winter rain']
# 402 ['the old temple', 'a snake on the stone step', 'crawling away']
# 403 ['sparrow song--', 'two ladies on the verandah', 'just before the rain']
# 404 ['mushiatsui asa', 'te ga kimi o', 'omoidashi']
# 405 ['taifuu ya', 'sugi tatta ba ni', 'hikari ari']
# 406 ['ame no yoru', 'niwa no iwa ni wa', 'mizu no oto']
# 407 ["perruque blonde - un petit sourire d'aprÃ¨s chimio"]
# 408 ['summer heat', 'my air conditioner', 'sweating']
# 409 ["summer's end-", 'one haiku becomes', 'another']
# 410 ['sunset', 'the shopkeeper burns incense', 'to drive out mosquitoes']
# 411 ['sudden rain', 'cows crowd the entrance', 'to the hotel']
# 412 ['opulent temple', 'pigeons occupy', 'every niche']
# 413 ['Over the bay', 'August full moon rises', 'as days shorten']
# 414 ['dog days --', 'the hill carried away', 'a truck at a time']
# 415 ['lingering day --', 'I study the moss', 'in a park bench']
# 416 ['last straw rejection --', 'the telemarketer tells me', "I'm too old"]
# 417 ['dandelion seeds', '  ai r  b  o   r   n', '     in a cool breeze']
# 418 ["summer's end", 'an orange sunset', 'crayoned on the wall']
# 419 ['two moons', 'on August 27th', "Mother's birthdate"]
# 420 ['Wild fires rage', 'scent of cedar', 'fills the air']
# 421 ['children dancing', 'circles in the rain-', 'autumn leaves']
# 422 ['falling leaves-', 'unpacking winter clothes', 'from cedar trunks']
# 423 ['starless night--', 'Las Vegas spills', 'over the desert']
# 424 ['garden embrace', 'the fresh smell of her', 'sun dried laundry']
# 425 ['kitchen embrace', 'the smell of her hot', 'apple pie']
# 426 ['farewell embrace', 'a faint essence', 'of mothballs']
# 427 ['fallen tree', "the poor woman's axe", 'gleams brightly']
# 428 ['muddy street', "the black pig's feet", 'and tail tip are white']
# 429 ['unkempt garden', 'a hibiscus blooms', 'amongst the weeds']
# 430 ['jardin zen', 'les stÃ¨les Ã©mergent du sable', 'un autre soldat mort']
# 431 ['pleasantly drunk', 'in the orchard', 'a flock of waxwings']
# 432 ["bonfire's glow", 'my niece cups her hands', 'around a firefly']
# 433 ['dark', 'clouds', 'a pigeon', 'on the last', 'streetlight']
# 434 ['Twin Towers-', 'where once two shadows', 'now only sun']
# 435 ['rice seedlings-', 'each step deeper', 'in the mud']
# 436 ['the moon', 'in every puddle', 'the same']
# 437 ['the stench', 'of a dead sheep', 'in summer', 'rain']
# 438 ['sad words', 'and tears in my teacup', 'rainstorm']
# 439 ['rainy New York', 'from the tenth storey window', 'black umbrellas bloom']
# 440 ['rainy Baltimore', 'umbrella blossoms', 'in cafe windows']
# 441 ["Go-ban en bois d'if.", 'Les pierres de nacre et de schiste', 'aux ombres semblables.']
# 442 ["Effluves d'Ã©tÃ©.", "Dans l'herbe jaune ondoie l'ombre", 'du frÃªne immobile.']
# 443 ['summer wind', "the blue jay's reflection", 'in the birdbath']
# 444 ['Memorial Day', 'a layer of dust', 'covers his urn']
# 445 ['cloudburst', 'the flies are already', 'in the house']
# 446 ['soft rain', 'the sound of hammering', 'from the construction site']
# 447 ["l'arbre mort", 'dans la forÃªt luxuriante -', "couvert d'ex-voto"]
# 448 ["tandis qu'il me cause", 'sur la galerie', 'mon ombre, se cache...']
# 449 ["veiller su'l perron", 'par un soir de juillet', 'ombre dans le dos']
# 450 ['insomnie', 'la danse des Ã©toiles', 'un moment']
# 451 ['brise', "d'une nuit de juillet", "feu d'une luciole"]
# 452 ['sunset --', "the day's heat", 'still in the car']
# 453 ['end of the drought --', 'a mushroom tilts', 'under the spruce']
# 454 ['baume --', "jusqu'Ã\xa0 la source", 'dans la pluie']
# 455 ['Des Ã©clats de rires', 'tombent par la fenÃªtre', '- samedi soir']
# 456 ['la danse du tissu', 'autour des jambes de la femme', 'grÃ¨ve des transports']
# 457 [' day moon -', 'the girl brushing her hair', 'smiles suddenly']
# 458 ['iris bleu', "elle regarde l'aiguille", 'pÃ©nÃ©trer sa chair']
# 459 [' ils boitent tous', 'sur la pente de lâ\x80\x99ancien quai', '-- les oiseaux reprennent']
# 460 ['une autre poussiÃ¨re', 'le lendemain de la pluie', 'traces des gouttes']
# 461 ['la lune jaune', 'au-dessus des feux clignotants', 'minuit']
# 462 ['Chataignier en fleur.', 'Chandelier qui brille', 'sur la table.']
# 463 ['lifting fog', 'the face of an old friend', 'on my morning walk']
# 464 ['daybreak ...', 'still sipping bitter coffee', 'we rehash last night']
# 465 ['deepening dusk --', 'a fish leaps', 'between grebes']
# 466 ['cloud shadows --', 'and eagle picks over', 'what the tide left']
# 467 ['ebb tide --', 'a photo of a missing girl', 'flutters in the breeze']
# 468 ['first raindrops --', 'frog bones in', 'the middle of the path']
# 469 ['after the long wait . . .', '  two unattended dove eggs', '      in summer rain']
# 470 ['walking to work -', 'the blossoms on my street', 'late this year']
# 471 ['morning mist--', 'a canada goose', 'asleep on the dock']
# 472 ['pleine lune', "l'ombre de ses seins", 'se pose sur moi']
# 473 [" lampi d'estate", 'svelano nella notte', 'le vie nascoste']
# 474 ['Papillons de nuit -', 'Des fleurs du chÃ¨vrefeuille', 'fanÃ©es sur le sol']
# 475 ['ContrÃ´le des passeports.', 'Sous le toit de la douane', "un nid d'hirondelle"]
# 476 ['summer solstice', 'he remembers', 'to lift the sea']
# 477 ['fresh paint', 'a white moth circles', 'the bug light']
# 478 ['les yeux bleus', "elle boit de l'eau de source -", "veille de l'Ã©tÃ©"]
# 479 ['deux heures du matin', 'un tout petit insecte', 'traverse la page neuf']
# 480 ['slow boats --', 'the wind pushes a butterfly', 'out to sea']
# 481 ['Reading a book', 'a sudden brightness', 'the full moon']
# 482 ['arrivÃ©e en gare -', 'malgrÃ© le brouillard Ã©pais', 'les bruits de la ville']
# 483 ["nÃ©gociations   au Conseil de SÃ©curitÃ© - j'achÃ¨te une maison"]
# 484 ['jambes croisÃ©es', 'nous buvons nos cafÃ©s', 'et parlons de la guerre']
# 485 ['Falling leaves', 'I already miss you', 'This winter']
# 486 ['storm warnings . . .', 'sunday afternoon by the fire', 'mail from an old friend']
# 487 ['Shivering', 'in the cold spring air.', '  Plum blossoms!']
# 488 ["it's as if winter", 'is about to leave', 'mom', 'with the slant in her back', 'and the sail in her hair']
# 489 ['lune des neiges', 'si froide encore', 'notre entente']
# 490 ['Strada nebbiosa', "dopo l'angolo trovo", 'un muro chiuso']
# 491 ['minus forty-six', 'steam from the coffee', 'warms my nose']
# 492 ['rumeurs du matin -', "l'ombre d'une fumÃ©e", 'sur la faÃ§ade blanche']
# 493 ['Grande MarÃ©e', 'Le pÃ©trole', 'au plus haut']
# 494 ['skyscraper', 'a window-washer squeegees', 'the thunderhead']
# 495 ['High winds', 'trees down on power lines', 'no morning coffee']
# 496 ['On a grey day', 'a spot of colour', 'his red hair']
# 497 ['3:00 a.m.--', 'through sounds of winter rain', 'the mail plane landing']
# 498 ['no wind tonight', 'across this reach of prairie', 'all those stars']
# 499 ['Epiphanie - premiÃ¨res galettes sur la cÃ´te franÃ§aise']
# 500 ['a dry new year', 'december snowman begins', 'to show his age']
# 501 ['Au pied du lampadaire', 'un sapin de janvier']
# 502 ['dispute familiale', 'la fumÃ©e monte de la soupe', 'la neige tombe']
# 503 ['first snow', 'the asylum seeker', 'thoughts on the land']
# 504 ['lune des pluies', 'mÃªme plus long le jour', 'si sombre encore']
# 505 ['checking dividends', 'on the cashpoint screen', 'to and fro...an ant']
# 506 ['sunshine and snow', 'the boys in the reserves', 'watch the letterbox']
# 507 ['rumors of war --', 'removing decorations', 'from the Christmas tree']
# 508 ['insomnia', 'the mouse', 'has it too']
# 509 ['stars at dusk', 'a spray of willow buds', 'by the gate']
# 510 ['untrodden snow --', 'my breath clouds the way', 'into the trees']
# 511 ['crescent moon --', 'I follow the trail of', 'a dragged Christmas tree']
# 512 ['new year bon fire']
# 513 ['fireworks gone', "Orion's beauty remains", 'in the stillness']
# 514 ['entracte', '-- le mort du premier acte', 'sert les biÃ¨res']
# 515 ['Mass over--', 'the rush to be first', 'out of the lot']
# 516 ['her plastic lifelines', 'in harsh hospital light -', 'even fresh flowers, fade']
# 517 ["this winter's day the garbage cans evanesce"]
# 518 ['entracte -', 'on parle de la guerre', 'en coulisses']
# 519 ['home again', 'even the ants', 'seem familiar']
# 520 ['along the road', 'shape of a willow', 'conforms to the trucks']
# 521 ['obituary', "a child's face", 'smiles from the page']
# 522 ['23 dÃ©cembre', 'une minute de plus', 'un jour de moins']
# 523 ['pause fumette', 'trois PÃ¨res NoÃ«l avec barbes', 'dÃ©capotÃ©es']
# 524 ['vingt ans aprÃ¨s', '- un seul visage au fond du puits', 'de mon pÃ¨re']
# 525 ['Avant de se quitter', 'disperser les braises -', 'envol des lucioles']
# 526 ['Les ombres des entants', "d'un feu Ã\xa0 l'autre-", 'ciel Ã©toilÃ©']
# 527 ["Juste avant l'hiver", 'un Bouddha de pacotille', 'son dernier cadeau']
# 528 ['Dernier lambeau', "du froid crÃ©puscule d'automne", 'Envie de pÃªches']
# 529 ["new year's day . . .", '     spent bottle-rockets', '           in the road']
# 530 ['wolf prints . . .', '  the gas lantern', '     splutters']
# 531 ['white roads', 'leading nowhere ><', 'Happy New Year ?']
# 532 ['drinking mulled wine', 'on the square --', 'white breaths']
# 533 ["nuit d'hiver", 'des braseros sous le pont', 'ombres dressÃ©es']
# 534 ['first Christmas', 'a tiny new stocking', 'joins the family']
# 535 ["l'aube de fin juin", 'un bourgeon du lys orange', "s'appuyant sur le prunier mort"]
# 536 ['juillet:', 'deux petites dames', 'odeur de la lessive', 'lune de nacre']
# 537 ['septembre:', "les vaguelettes s'en vont vers le sud", 'deux baigneurs de soleil', 'se promÃ¨nent']
# 538 ['une Ã®le et une grosse vague', "mal Ã\xa0 l'aise en regardant le choix", "de son fond d'Ã©cran"]
# 539 ['juin: un midi torride', 'les joncs dans les pots Ã\xa0 fleurs', 'dans un moule Ã\xa0 lac noir']
# 540 ['mai:', "les oiseaux s'envolent", 'le long de la faÃ§ade', 'tombent les ombres']
# 541 ['le vent en bourrasques', 'une Ã©toile en paille oscille lentement', 'quand on parle']
# 542 ['autumn sun', 'my shadow over', 'tombstones']
# 543 ['fly fishing;', 'the sound of the wind', 'in the reel']
# 544 ['mountain cave --', 'from out of darkness', 'the morning light']
# 545 ['chill night', 'new fallen pear blossoms', 'glow in the moonlight']
# 546 ['changing winds', 'bring up your kite', 'and the Dow']
# 547 ["chez l'antiquaire --", "au fond de l'armoire vide", 'les rais du soleil']
# 548 ['pleine lune -', 'il manque deux soirs', 'Ã\xa0 sa rondeur']
# 549 ["solstice d'Ã©tÃ©", 'les jours plus longs', 'les Ã©crits plus courts']
# 550 ['courber la tÃªte', 'en passant sous le lilas', 'lourd de neige']
# 551 ['attendre le matin', 'le soleil au bout des branches', "de l'Ã©rable"]
# 552 ['le vent de printemps', 'disperse les fleurs du magnolia', 'ses dix-neuf ans']
# 553 ['la derniÃ¨re note', "avant qu'elle monte dans l'autobus", "matin froid d'hiver"]
# 554 ['ses cheveux coiffÃ©s', "Ã\xa0 l'abri du vent sud-ouest", 'tombe ouverte']
# 555 ['il prolonge', "la soufflerie de l'ordinateur", 'le grillon']
# 556 ['les enfants font', 'flotter des lanternes de couleur', "soir d'Hiroshima"]
# 557 ['fresh autumn breeze', 'or the advance of age?', 'forgotten tea...']
# 558 ['dÃ©but mars', 'sur la carcasse du chien', 'les premiÃ¨res mouches']
# 559 ['marÃ©e basse -', 'dans le fortin Ã©cartelÃ©', "le cadavre d'un chien"]
# 560 ['soleil couchant', 'sur la vitre du quatriÃ¨me', "la trace d'un oiseau"]
# 561 ['rentrÃ©e des classes --', 'encore un peu de marÃ©e haute', 'tout prÃ¨s des dunes']
# 562 ['60 today', 'the full moon', 'still rising']
# 563 ['desert garden', 'frosted lettuce leaves', 'in the pink dawn']
# 564 ['Passover darkness -', 'before the buds burst open;', "a child's eyes in death."]
# 565 ['misty morning', 'echoes of blue jay cries', 'through the pines']
# 566 ["farmer's market", 'she paints a flower', "on a child's cheek"]
# 567 ['montana morning', 'the horses with their backs', 'to blowing snow']
# 568 ['street light sway ~', 'dreams of her linger', 'with the storm']
# 569 ['tandem bicycle', 'wind in our hair', 'a shared laugh']
# 570 ['fresh brewed coffee', 'cream and sugar swirls', 'she stirs in her thoughts']
# 571 ['dry haystack', 'flames climb higher', 'against the night sky']
# 572 ['spring breeze', 'blowing dandelions', 'in circles']
# 573 ['Sack of cheeries ~', 'clouds grow dark on the road', 'to the coast']
# 574 ['salmon sunrise', 'a splash resounds over', 'the calm bay']
# 575 ['Harley Davidson ', 'rutilante de rosÃ©e - ', "dimanche d'Ã©tÃ©"]
# 576 ['trÃ¨s haut la ronde des hirondelles - le jour persiste']
# 577 ['sea breeze --', 'under full sail', 'a pregnant skipper']
# 578 ['au dernier rang du spectacle de mime - torticolis']
# 579 ["le ciel couvert ce dimanche matin d'Ã©tÃ© - le cafÃ© infuse"]
# 580 ['brume estivale - ', 'la ville en ombres chinoises ', 'du noir au gris']
# 581 ["la Saint Jean d'Ã©tÃ© - ", "oÃ¹ le soleil s'est couchÃ©,", 'la premiÃ¨re Ã©toile']
# 582 ["bruine d'Ã©tÃ© au confluent des deux fleuves - barques immobiles"]
# 583 ['road closed', 'moose tracks continue on', 'local traffic only']
# 584 ["la fin des vacances - Ã\xa0 la tÃ©lÃ©, d'Artagnan parle en anglais"]
# 585 ['le casse-noisettes passe de mains en mains - craquements de bois mort']
# 586 ['les gÃ©raniums arrosent le macadam - dÃ©clin du jour']
# 587 ["sous l'aube terne d'octobre le vol d'un pigeon encore noir"]
# 588 ['aprÃ¨s la crue', 'un trait sur le passÃ©', 'peint sur le mur blanc']
# 589 ['Soir de carnaval', 'Des confettis', 'jusque dans le lit']
# 590 ['chilled by spring winds', 'schoolgirls sniffing body spray', 'behind the gym']
# 591 ['needle exchange', 'sharing a breakfast drink', 'in Museum Square']
# 592 ['mayflowers', 'three small boys track down', 'terrorists']
# 593 ["boy's bedroom", "a blackbird's nest", 'found deep in the lilac']
# 594 ['a lost child', 'in a ward of iron lungs', 'her daffodils']
# 595 ['teeth in a glass', 'the nurse takes away his pot', 'of blue hyacinths']
# 596 ['coffee cold', 'she clips the obituary', 'from many papers']
# 597 ['august wind', 'on the dock seagulls', 'stand on two legs']
# 598 ['strong winter wind', 'bits of Batman kite wings', 'fall from the tree']
# 599 ['georgia peach', 'sweet cream and wrinkle remover', 'in the shopping cart']
# 600 ['a skein of birds', 'twines across the sky', 'the northbound train departs']
# 601 ['dawn chorus begins', 'I reach for', 'the snooze button']
# 602 ['brise dans le lierre', 'deux couples de papillons', 'se poursuivent sans bruit']
# 603 ['tÃªte levÃ©e', 'le cheval cueille aux branches', 'la neige fraÃ®che']
# 604 ['par ce vasistas', 'le soleil ne passait plus', 'depuis longtemps']
# 605 ['late rising moon', 'fireflies decorate', 'the tamarind tree']
# 606 ['moving day', 'my life', 'reduced to boxes']
# 607 ['rainstorm', 'ants drink', 'from a droplet']
# 608 ['meteor watching --', 'a match lights up', 'an unknown face']
# 609 ['snestormen -- ', 'alle vejskiltene', 'er hvide']
# 610 ['Ancient roman ruins', 'along both sides of the road', 'white jet trail above...']
# 611 ['Sky dewed with stars', 'cool air listening in news', 'a man was hanged.']
# 612 ['Country cemetery', 'snail on corroded tombstone', 'trails from A to O...']
# 613 ['leftover summer grass', '... horses browse', 'through crusted snow']
# 614 ['old leather saddle', 'cherry colored and shiny', 'smells of horse']
# 615 ["dentist's office -", 'cracks between tiles', 'filled with dirt']
# 616 ['raking the leaves ~', 'wind blows', 'the wrong way']
# 617 ['hot beach sand...', 'between my fingers', 'a cigarette butt']
# 618 ['between the second', 'and the third line -', 'short trip to bathroom']
# 619 ['stupid arab -', 'he only wants to learn', 'to fly straight']
# 620 ['egret stands', 'in the blue rice field,', 'dusk creeps in']
# 621 ['long centipede', 'on the ceiling- long talks', 'of what to do']
# 622 ['white clouds drift', 'in the August sky,', 'a child dreams']
# 623 ['desire', 'the honey', 'inside me']
# 624 ['Post Office --', 'stamped on the sidewalk', 'pink blossoms']
# 625 ['straw hat -', 'flowers fading', 'under the sun']
# 626 ['voices of loons', 'cross the misted cove', 'call and response']
# 627 ['rainy day--', 'they give me back', 'my shoelaces']
# 628 ['dusk--', 'the space between us', 'filling with snow']
# 629 ['fragile morning--', 'a blue psilocybin in the middle', 'of the garden']
# 630 ['Talking with you', 'now this morning somehow', 'scent of plumeria']
# 631 ['Red as the poppy', 'maple leaves fall', 'on the memorial']
# 632 ['First day of Autumn', 'even your touch feels', 'somewhat cooler']
# 633 ['At last some sunshine', 'blue Pacifc this morning', 'boiling tea water']
# 634 ['In the room', 'white lillies in the vase', 'scent of pepper']
# 635 ['Light-studded ferry', 'passes in the starless night', 'another week-end']
# 636 ['The sunrise', 'fresh salmon on ice', 'so very pink']
# 637 ['A tunnel of fog', 'connects the two islands', 'warmth of my duvet']
# 638 ['October morning', 'a new pair of new wool socks', 'on my very cold feet']
# 639 ['Last night of Summer', 'the bright full moon of last night', 'hidden by a cloud']
# 640 ['All my lights off', 'to watch the rising', 'of the Harvest moon']
# 641 ['In this desert', 'a memory of blue sea --', 'shells in the sand']
# 642 ['Federal Express', 'reaches me through the fog', 'plumeria lei']
# 643 ['Midnight and full moon', 'my neighbour asks to borrow', 'the vacum cleaner']
# 644 ['The blue iris', 'colour changing hue', 'soft Summer rain']
# 645 ['A sea change', 'the weather turns cool', 'hot rum and lemon']
# 646 ['moldy odors', 'in the nursing home', 'dying elders']
# 647 ['Ã©quinoxe', "toutes les couleurs de l'automne", 'dans le ciel']
# 648 ['february 15th', 'a broken heart', 'in the cookie box']
# 649 ['smell of newsprint', 'twenty beauty queens', 'with one smile']
# 650 ['gust of wind', 'a womanâ\x80\x99s face lights up', 'by the cooking fire']
# 651 ['rice-green pond', 'dark herons stand', 'in an arc']
# 652 ['midnight', 'the moon dances', 'in my teacup']
# 653 ['burnt-down house', 'yellow elders bloom', 'in the garden']
# 654 ['waiting for moonrise', 'the moving red dot', 'becomes a plane']
# 655 ['cool morning', 'a fog of insecticide', "in the red truck's wake"]
# 656 ['harsh sunlight', 'faces peep through the bars', 'of the police van']
# 657 ['moonrise', 'a woman croons', 'to her baby']
# 658 ['burnt house', 'the ownerâ\x80\x99s name', 'on the iron gate']
# 659 ['petrol fumes', 'smell of fresh bread', 'from the bakery']
# 660 ['clacking rails', 'five languages', 'in the compartment']
# 661 ['small talk', 'sixteen ants on the wall...', 'seventeen...']
# 662 ['flight of egrets', 'a boy stands with his ear', 'to a telephone pole']
# 663 ['last station', 'the king of hearts on the floor', 'of the compartment']
# 664 ['sultry afternoon', 'little mirages', 'above the tar']
# 665 ['melting tar', 'silk cotton drifts', 'across the road']
# 666 ['smoky moon', 'a cloud of insects around', 'the street light']
# 667 ['crystal morning', 'dried puke', 'on the car door']
# 668 ['a bullock cart', 'loaded high with shoe boxes', 'the driverâ\x80\x99s cracked feet']
# 669 ['empty street', 'the For Sale sign', 'overgrown with weeds']
# 670 ['tree less corners', 'the tall shadows', 'of beer bottles']
# 671 ['faded asters', 'the cortege pauses at her gate', 'moves on']
# 672 ['biopsy', 'just a cyst - this time', 'a break in the clouds']
# 673 ['plastic flowers', 'placed beside the highway', 'memory fades']
# 674 ['troubled sleep --', 'steam rises', 'from a storm sewer']
# 675 ['Wall Street watch --', 'the unnerving plunge', 'of her neckline']
# 676 ["my daughter's 18th birthday --", 'the warming sunshine', 'in her hair']
# 677 ["orthopedist's office --", 'all paintings tilted', 'slightly off center']
# 678 ['stood up', 'by a part-time lover --', 'shooting star']
# 679 ['english newspaper', 'a lot of starving people', 'between fish & chips']
# 680 ['five star hotel -', 'a cockroach scurries', 'pool-side']
# 681 ['his old hands', 'working the soil -', 'smell of brewed tea::    ses vieilles mains', '   travaillant le sol -', '   odeur du thÃ© infusÃ©']
# 682 ['forty-six years', 'writing my name', 'yellow in snow']
# 683 ['at the memorial', "a hawk's cry", 'scatters her ashes']
# 684 ["hawk's hover -", 'the view of calm seas', 'through a gunport']
# 685 ["mothers' day", 'I let the phone ring longer', 'for her']
# 686 ['mid October', 'the sudden thinness', 'of my robe']
# 687 ['wood flute music', 'through an open window', "the crow's rasp"]
# 688 ['scenting two pages', "of the Webster's Unabridged . . .", 'wild lilac']
# 689 ["Valentine's dinner--", 'nothing on the menu', 'suits him']
# 690 ['from the armoire,', 'scent of passion in a candle', 'yet to be burned']
# 691 ['stroke of  . . .', 'his snoring punctuated', 'by fireworks']
# 692 ["a new year's bonfire", 'misty rain', 'on the embers']
# 693 ['typhoon warning', 'a farmer on the path', 'between the rice fields']
# 694 ['the farmer lady', 'a few daffodils in a basket', 'of white radish']
# 695 ['March wind', 'a strawberry off', 'from my birthday cake']
# 696 ['just extinguished-', 'smoke slowly curls', 'out pumpkin eyes']
# 697 ['Jour de pluie', 'Au travers des vitraux', 'Le jasmin jaune']
# 698 ['arthrite -', 'un autre verre de vin', 'de la main gauche']
# 699 ['automne ce matin -', "l'oiseau sur son Ã©paule gauche", 'recouvert']
# 700 ['afternoon rain-', 'a neighbor opening her curtains', 'too']
# 701 ['Lune parfaitement ronde', 'BuÃ©e sur la vitre']
# 702 ["jusqu'Ã\xa0 tard dans la nuit", 'nos deux tasses vides', 'depuis longtemps']
# 703 ['New-York September', 'the one-way sign points towards', 'the billowing cloud']
# 704 ['Full moon night -', "the shape of the mannequins' breasts", 'in the shop-window']
# 705 ["milieu d'aoÃ»t", 'les haÃ¯kus', 'Ã\xa0 marÃ©e basse']
# 706 ['la poÃ©tesse', 'partie, restent les haÃ¯kus', 'et la tasse froide']
# 707 ['les seins des mannequins', 'pointent dans la vitrine', '- approche du printemps']
# 708 ['sur la cheminÃ©e', 'le bleu du couvreur', '- Ã©quinoxe vernal']
# 709 ['huit heures.', 'trois quart lune, son halo', "d'hiver - rond encore"]
# ...
# 11431 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11432 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11433 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11434 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11435 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11436 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11437 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11438 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11439 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11440 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11441 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11442 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11443 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11444 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11445 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11446 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11447 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11448 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11449 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11450 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11451 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11452 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11453 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11454 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11455 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11456 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11457 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11458 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11459 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11460 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11461 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11462 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11463 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11464 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11465 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11466 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11467 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11468 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11469 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11470 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11471 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11472 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11473 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11474 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11475 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11476 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11477 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11478 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11479 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11480 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11481 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11482 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11483 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11484 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11485 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11486 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11487 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11488 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11489 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11490 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11491 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11492 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11493 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11494 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11495 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11496 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11497 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11498 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11499 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11500 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11501 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11502 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11503 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11504 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11505 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11506 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11507 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11508 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11509 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11510 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11511 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11512 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11513 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11514 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11515 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11516 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11517 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11518 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11519 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11520 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11521 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11522 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11523 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11524 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11525 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11526 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11527 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11528 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11529 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11530 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11531 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11532 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11533 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11534 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11535 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11536 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11537 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11538 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11539 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11540 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11541 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11542 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11543 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11544 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11545 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11546 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11547 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11548 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11549 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11550 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11551 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11552 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11553 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11554 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# 11555 ["clapotis de l'eau -", "la radio d'un pÃªcheur", 'en sourdine']
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     170             conn = connection.create_connection(
# --> 171                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     172
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      78     if err is not None:
# ---> 79         raise err
#      80
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      68                 sock.bind(source_address)
# ---> 69             sock.connect(sa)
#      70             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# c:\Users\Jeremy\Anaconda3\lib\http\client.py in request(self, method, url, body, headers)
#    1106         """Send a complete request to the server."""
# -> 1107         self._send_request(method, url, body, headers)
#    1108
#
# c:\Users\Jeremy\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers)
#    1151             body = _encode(body, 'body')
# -> 1152         self.endheaders(body)
#    1153
#
# c:\Users\Jeremy\Anaconda3\lib\http\client.py in endheaders(self, message_body)
#    1102             raise CannotSendHeader()
# -> 1103         self._send_output(message_body)
#    1104
#
# c:\Users\Jeremy\Anaconda3\lib\http\client.py in _send_output(self, message_body)
#     933
# --> 934         self.send(msg)
#     935         if message_body is not None:
#
# c:\Users\Jeremy\Anaconda3\lib\http\client.py in send(self, data)
#     876             if self.auto_open:
# --> 877                 self.connect()
#     878             else:
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     195     def connect(self):
# --> 196         conn = self._new_conn()
#     197         self._prepare_conn(conn)
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     179             raise NewConnectionError(
# --> 180                 self, "Failed to establish a new connection: %s" % e)
#     181
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x00000247BF86FE80>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     444                     retries=self.max_retries,
# --> 445                     timeout=timeout
#     446                 )
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPConnectionPool(host='www.tempslibres.org', port=80): Max retries exceeded with url: /tl/tlphp/dbhk03.php?id=11556&lg=e (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000247BF86FE80>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-4252e3946512> in <module>()
#       1 while True:
#       2     time.sleep(.2)
# ----> 3     response = requests.get('http://www.tempslibres.org/tl/tlphp/dbhk03.php?id=%s&lg=e' % i)
#       4     soup = BeautifulSoup(response.text, 'html.parser')
#       5     lines = soup.find('p', 'dbhkanahaiku').get_text().splitlines()
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     510         }
#     511         send_kwargs.update(settings)
# --> 512         resp = self.send(prep, **send_kwargs)
#     513
#     514         return resp
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     620
#     621         # Send the request
# --> 622         r = adapter.send(request, **kwargs)
#     623
#     624         # Total elapsed time of the request (approximately)
#
# c:\Users\Jeremy\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     511                 raise SSLError(e, request=request)
#     512
# --> 513             raise ConnectionError(e, request=request)
#     514
#     515         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='www.tempslibres.org', port=80): Max retries exceeded with url: /tl/tlphp/dbhk03.php?id=11556&lg=e (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000247BF86FE80>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))

# %%
haikus2 = haikus[:7599]

# %%
haikus3 = []
for haiku in haikus2:
    try:
        haikus3.append([line.encode('latin1').decode('utf-8') for line in haiku])
    except:
        print(haiku)
# Out:
# ['Ù\x88Ø\xadØ§Ø²Øª Ù', 'Ø´Ø§Ø±Ù\x83ØªÙ\x8a Ø¹Ù\x84Ù\x89 Ø«Ù\x84Ø§Ø«Ø© Ø£ØµÙ\x88Ø§Øª', 'Ø¢Ø®Ø± Ø±Ø³Ø§Ø¦Ù\x84Ù\x8a', 'Ø¥Ù\x84Ù\x8aÙ\x87Ø§', 'Ø£Ù\x88Ø±Ø§Ù\x82 Ø§Ù\x84Ø®Ø±Ù\x8aÙ\x81']

# %%
df = pd.DataFrame.from_records(haikus3)
df['haiku'] = df.apply(lambda r: '\n'.join([l for l in r[0:9] if l]), axis=1)

# %%
df
# Out:
#                                           0  \
# 0                                kiri saite
# 1                   de son fauteuil roulant
# 2                       clapotis de l'eau -
# 3                           Memorial Day --
# 4                             spring rain -
# 5                         spring moonset --
# 6                           sunny afternoon
# 7                             cinco de mayo
# 8                             quitting time
# 9                                     waves
# 10                        overnight rain --
# 11                              haru no ame
# 12                         l'orage ce matin
# 13                        misty summer rain
# 14                              day is done
# 15                            urban geese -
# 16                          watching clouds
# 17                          mountain stream
# 18                         Après la pluie -
# 19                            night shift--
# 20                            a wild violet
# 21                              a sunny day
# 22                      macchie di rosso...
# 23                          polished oak --
# 24                        matin de banlieue
# 25                              nobody here
# 26                               first date
# 27               vanishing difference . . .
# 28                              à l'horizon
# 29                           sentier désert
# ...                                     ...
# 7568                   pregnant again . . .
# 7569                      saison de pluie _
# 7570  la niqabée quitte le salon de beauté~
# 7571                          Tous les mois
# 7572                   bottes en caoutchouc
# 7573                            thé du soir
# 7574                            a dragonfly
# 7575                             pranayama—
# 7576                         midnight . . .
# 7577                        subway transfer
# 7578                           white satin
# 7579                      fortieth birthday
# 7580                        after the storm
# 7581                    Rue pavillonnaire ~
# 7582                               canicule
# 7583                      crépuscule d'été~
# 7584                      marées montantes-
# 7585                      potager du matin~
# 7586                            un scorpion
# 7587                        Présage de mort
# 7588                             sécheresse
# 7589                       bruine d'automne
# 7590                           matin d'été_
# 7591                         chaleur moite-
# 7592                      cottonwood leaves
# 7593                             one finger
# 7594                    blackberry brambles
# 7595                           summer break
# 7596                          Oregon summer
# 7597                odeur de paille sèche -
#
#                                          1                          2     3  \
# 0                         suterare mura ni                haka nokoru  None
# 1          l'enfant ne voit par la fenêtre                que le ciel  None
# 2                    la radio d'un pêcheur                en sourdine  None
# 3                        a shadow for each                white cross  None
# 4                     as the doctor speaks          i think of lilacs  None
# 5                          a rice ball for                  breakfast  None
# 6                       an old man lingers           near the mailbox  None
# 7                              horses roll            in the shallows  None
# 8                        the smell of rain               in the lobby  None
# 9            slowly cresting towards shore               a faint moon  None
# 10            the scent of orange blossoms           in a desert town  None
# 11                      mukashi mukashi no                 monogatari  None
# 12                  un demi-cercle parfait        du rosier en fleurs  None
# 13                        calling pheasant              in Zen temple  None
# 14                          poppies amidst            the dying grass  None
# 15                      voices extemporise             around a sitar  None
# 16                        the white petals        of a crushed crocus  None
# 17                   two well placed rocks              the path home  None
# 18                   des capsules de bière          au bord du chemin  None
# 19           in the parking lot car lights           dim near morning  None
# 20                      on the sunny hill~              noon time nap  None
# 21        pink haze of the cherry blossoms              over the hill  None
# 22                       soltanto papaveri            nell'erba verde  None
# 23               the freesia's shadow ends             in coffee foam  None
# 24           les escargots gagnent l'herbe          de la voie ferrée  None
# 25                 a table in the mountain       speckled with petals  None
# 26                       not even noticing               the new moon  None
# 27               gliding geese settle onto          their reflections  None
# 28                          la ligne jaune                   du colza  None
# 29                      plus aucun passage           entre les orties  None
# ...                                    ...                        ...   ...
# 7568               the fluttering of moths         against the window  None
# 7569             elle rentre sous le préau           la corde à linge  None
# 7570                            lune noire                       None  None
# 7571                  une lunaison rouge--                 matin gris  None
# 7572                         ah les années                    de boue  None
# 7573  dans un parfum de menthe son absence                     infuse  None
# 7574                        on a dragonfly                summer heat  None
# 7575                   the candle goes out       as it lights another  None
# 7576            scent of the incense stick             burning itself  None
# 7577                     the homeless lady              sells mirrors  None
# 7578                 cool against her skin          choosing a coffin  None
# 7579                 fastening my old belt              at a new hole  None
# 7580                      mountains return               a bit softer  None
# 7581                            La chaleur                      aboie  None
# 7582              sous nos corps immobiles          la moiteur du lit  None
# 7583                   l'odeur des braises               qu'on éteint  None
# 7584                 la blancheur du linge              sur les toits  None
# 7585                croquer les concombres             sans les laver  None
# 7586                se hâte dans le patio-                    sirocco  None
# 7587                   les troncs cernés--              peinture fluo  None
# 7588                    dans l’eau vaseuse              un ibis blanc  None
# 7589                   acidulée et fraiche             la pomme verte  None
# 7590                    la brise des dunes  a un goût de figues mûres  None
# 7591               dans le potager l'éclat              d'une luciole  None
# 7592                         the quiet way      they soften the night  None
# 7593                    raised in greeting                  heat wave  None
# 7594                        along the road         blues on the radio  None
# 7595                      the sun scatters                my freckles  None
# 7596      The haze from distant wildfires        turning the moon red  None
# 7597       les lumières d'une moissonneuse         au fond de la nuit  None
#
#          4     5     6     7     8  \
# 0     None  None  None  None  None
# 1     None  None  None  None  None
# 2     None  None  None  None  None
# 3     None  None  None  None  None
# 4     None  None  None  None  None
# 5     None  None  None  None  None
# 6     None  None  None  None  None
# 7     None  None  None  None  None
# 8     None  None  None  None  None
# 9     None  None  None  None  None
# 10    None  None  None  None  None
# 11    None  None  None  None  None
# 12    None  None  None  None  None
# 13    None  None  None  None  None
# 14    None  None  None  None  None
# 15    None  None  None  None  None
# 16    None  None  None  None  None
# 17    None  None  None  None  None
# 18    None  None  None  None  None
# 19    None  None  None  None  None
# 20    None  None  None  None  None
# 21    None  None  None  None  None
# 22    None  None  None  None  None
# 23    None  None  None  None  None
# 24    None  None  None  None  None
# 25    None  None  None  None  None
# 26    None  None  None  None  None
# 27    None  None  None  None  None
# 28    None  None  None  None  None
# 29    None  None  None  None  None
# ...    ...   ...   ...   ...   ...
# 7568  None  None  None  None  None
# 7569  None  None  None  None  None
# 7570  None  None  None  None  None
# 7571  None  None  None  None  None
# 7572  None  None  None  None  None
# 7573  None  None  None  None  None
# 7574  None  None  None  None  None
# 7575  None  None  None  None  None
# 7576  None  None  None  None  None
# 7577  None  None  None  None  None
# 7578  None  None  None  None  None
# 7579  None  None  None  None  None
# 7580  None  None  None  None  None
# 7581  None  None  None  None  None
# 7582  None  None  None  None  None
# 7583  None  None  None  None  None
# 7584  None  None  None  None  None
# 7585  None  None  None  None  None
# 7586  None  None  None  None  None
# 7587  None  None  None  None  None
# 7588  None  None  None  None  None
# 7589  None  None  None  None  None
# 7590  None  None  None  None  None
# 7591  None  None  None  None  None
# 7592  None  None  None  None  None
# 7593  None  None  None  None  None
# 7594  None  None  None  None  None
# 7595  None  None  None  None  None
# 7596  None  None  None  None  None
# 7597  None  None  None  None  None
#
#                                                   haiku
# 0             kiri saite\nsuterare mura ni\nhaka nokoru
# 1     de son fauteuil roulant\nl'enfant ne voit par ...
# 2     clapotis de l'eau -\nla radio d'un pêcheur\nen...
# 3       Memorial Day --\na shadow for each\nwhite cross
# 4     spring rain -\nas the doctor speaks\ni think o...
# 5         spring moonset --\na rice ball for\nbreakfast
# 6     sunny afternoon\nan old man lingers\nnear the ...
# 7           cinco de mayo\nhorses roll\nin the shallows
# 8        quitting time\nthe smell of rain\nin the lobby
# 9     waves\nslowly cresting towards shore\na faint ...
# 10    overnight rain --\nthe scent of orange blossom...
# 11          haru no ame\nmukashi mukashi no\nmonogatari
# 12    l'orage ce matin\nun demi-cercle parfait\ndu r...
# 13    misty summer rain\ncalling pheasant\nin Zen te...
# 14         day is done\npoppies amidst\nthe dying grass
# 15    urban geese -\nvoices extemporise\naround a sitar
# 16    watching clouds\nthe white petals\nof a crushe...
# 17    mountain stream\n   two well placed rocks\nthe...
# 18    Après la pluie -\ndes capsules de bière\nau bo...
# 19    night shift--\nin the parking lot car lights\n...
# 20     a wild violet\non the sunny hill~\nnoon time nap
# 21    a sunny day\npink haze of the cherry blossoms\...
# 22    macchie di rosso...\nsoltanto papaveri\nnell'e...
# 23    polished oak --\nthe freesia's shadow ends\nin...
# 24    matin de banlieue\nles escargots gagnent l'her...
# 25    nobody here\na table in the mountain\nspeckled...
# 26          first date\nnot even noticing\nthe new moon
# 27    vanishing difference . . .\n  gliding geese se...
# 28                à l'horizon\nla ligne jaune\ndu colza
# 29    sentier désert\nplus aucun passage\nentre les ...
# ...                                                 ...
# 7568  pregnant again . . .\nthe fluttering of moths\...
# 7569  saison de pluie _\nelle rentre sous le préau\n...
# 7570  la niqabée quitte le salon de beauté~\nlune noire
# 7571    Tous les mois\nune lunaison rouge--\nmatin gris
# 7572       bottes en caoutchouc\nah les années\nde boue
# 7573  thé du soir\ndans un parfum de menthe son abse...
# 7574           a dragonfly\non a dragonfly\nsummer heat
# 7575  pranayama—\nthe candle goes out\nas it lights ...
# 7576  midnight . . .\nscent of the incense stick\nbu...
# 7577  subway transfer\nthe homeless lady\nsells mirrors
# 7578  white satin \ncool against her skin\nchoosing ...
# 7579  fortieth birthday\nfastening my old belt\nat a...
# 7580    after the storm\nmountains return\na bit softer
# 7581             Rue pavillonnaire ~\nLa chaleur\naboie
# 7582  canicule\nsous nos corps immobiles\nla moiteur...
# 7583  crépuscule d'été~\nl'odeur des braises\nqu'on ...
# 7584  marées montantes-\nla blancheur du linge\nsur ...
# 7585  potager du matin~\ncroquer les concombres\nsan...
# 7586       un scorpion\nse hâte dans le patio-\nsirocco
# 7587  Présage de mort\nles troncs cernés--\npeinture...
# 7588      sécheresse\ndans l’eau vaseuse\nun ibis blanc
# 7589  bruine d'automne\nacidulée et fraiche\nla pomm...
# 7590  matin d'été_\nla brise des dunes\na un goût de...
# 7591  chaleur moite-\ndans le potager l'éclat\nd'une...
# 7592  cottonwood leaves\nthe quiet way\nthey soften ...
# 7593          one finger\nraised in greeting\nheat wave
# 7594  blackberry brambles\nalong the road\nblues on ...
# 7595        summer break\nthe sun scatters\nmy freckles
# 7596  Oregon summer\nThe haze from distant wildfires...
# 7597  odeur de paille sèche -\nles lumières d'une mo...
#
# [7598 rows x 10 columns]

# %%
df['lang'] = df['haiku'].apply(lambda h: detect(h))

# %%
df.to_csv('../../input/poems/raw/tempslibres.csv')
