# %%
import json
from pathlib import Path
import re

import inflect
import numpy as np
import pandas as pd

# %%
root_path = Path('../..')
input_path = root_path / 'input' 
dictionary_path = input_path / 'dictionaries'
poem_path = input_path / 'poems'
raw_path = poem_path / 'raw'

all_haikus = []

# %% [markdown]
# # Load Tempslibres Poems
#
# Load haikus from tempslibres, which were downloaded to `tempslibres.csv` using `Download Haikus From Tempslibres.ipynb`

# %%
# Load the file
df = pd.read_csv(str(raw_path / 'tempslibres.csv'), encoding='latin1')
df = df[df['lang'] == 'en'].copy()

# Only keep the first three lines of english haikus 
df = df[~pd.isnull(df['0']) & ~pd.isnull(df['1']) & ~pd.isnull(df['2'])].copy()
df = df[['0', '1', '2']]
df.columns = [0, 1, 2]

df['source'] = 'tempslibres'
all_haikus.append(df)
df.head()
# Out:
#                    0                     1                  2       source
# 3    Memorial Day --     a shadow for each        white cross  tempslibres
# 4      spring rain -  as the doctor speaks  i think of lilacs  tempslibres
# 5  spring moonset --       a rice ball for          breakfast  tempslibres
# 6    sunny afternoon    an old man lingers   near the mailbox  tempslibres
# 7      cinco de mayo           horses roll    in the shallows  tempslibres

# %%
df.columns
# Out:
# Index([0, 1, 2, 'source'], dtype='object')

# %% [markdown]
# # Load img2poem
#
# The data from the paper [Beyond Narrative Description: Generating Poetry from Images by Multi-Adversarial Training](https://arxiv.org/abs/1804.08473).
#
# From: https://github.com/bei21/img2poem
#
# It contains many different types of poems, so only keep three line poems.

# %%
# Read the JSON file
with (raw_path / 'unim_poem.json').open('r') as f:
    j = json.load(f)
    
# keep only the three line poems
df = pd.DataFrame({
    'haiku': [i['poem'] for i in j if len(i['poem'].split('\n')) == 3]
})

# Split them into lines
df = df['haiku'].str.split('\n', expand=True)

df['source'] = 'img2poems'
all_haikus.append(df)
df.head()
# Out:
#                                                 0  \
# 0         jesus smiles grabs his guitar and plays
# 1             after a flying ovation she realizes
# 2         you do a lot more talking in your sleep
# 3  look back: you see the path we chose was steep
# 4   there was a time when talk of love came cheap
#
#                                                1  \
# 0    a couple of familiar riffs crooning take it
# 1       she is not with the kozmic blues band or
# 2     than you used to do now you're growing old
# 3  and needed all our strength  but we were bold
# 4    and what was bought was what the other sold
#
#                                                 2     source
# 0  take another little piece of my heart now baby  img2poems
# 1             big brother and the holding company  img2poems
# 2           i wonder what there is for me to keep  img2poems
# 3       it took our breath and left us only sleep  img2poems
# 4       there was so much we didn't think to keep  img2poems

# %% [markdown]
# # PoetRNN
#
# Training data from [Sam Ballas's PoetRNN](https://github.com/sballas8/PoetRNN)

# %%
# Read the CSV and split the haikus into lines
df = pd.read_csv(str(raw_path / 'sballas8.csv'), names=['haiku'])
df = df['haiku'].str.split('\n', expand=True)

# Drop ones without at least three lines
df = df.dropna(subset=[0,1,2])

# Keep only the ones with exactly three lines
df = df[(((df[3] == '') | pd.isnull(df[3])) & pd.isnull(df[[4, 5, 6, 7, 8]]).all(axis=1))]


df = df[[0, 1, 2]]
df['source'] = 'sballas'
all_haikus.append(df)
df.head()
# Out:
#                     0                      1                     2   source
# 0     rectory roofers          their ladders      take them higher  sballas
# 1        summer cabin               the ants         do the dishes  sballas
# 2  lagoon at sunrise?             the shadow    chases its pelican  sballas
# 3        barren trees  even the tiniest twig  embraced by the mist  sballas
# 4     windfall apples             bees tango            to a waltz  sballas

# %% [markdown]
# # Haikuzao
#
# https://github.com/herval/creative_machines/tree/master/haikuzao

# %%
with (raw_path / 'haikuzao.txt').open('r') as f:
    text = f.read()
    
df = pd.DataFrame({
    'haiku': [i for i in text.split('\n\n') if len(i.split('\n')) == 3]
})

# Split them into lines
df = df['haiku'].str.split('\n', expand=True)

df['source'] = 'haikuzao'
all_haikus.append(df)
df.head()
# Out:
#                      0                              1  \
# 0     a skein of birds          twines across the sky
# 1   dawn chorus begins                    I reach for
# 2  en haut des cuisses     dans l'espace sous le slip
# 3       new March snow  the grouse with a missing toe
# 4     Remembrance Day-               even the traffic
#
#                               2    source
# 0  the northbound train departs  haikuzao
# 1             the snooze button  haikuzao
# 2             un morceau de mer  haikuzao
# 3                  still around  haikuzao
# 4          pauses for 2 minutes  haikuzao

# %%
all_haikus = pd.concat(all_haikus, sort=False)

# Drop duplicates because there are some poems in multiple sources
all_haikus['hash'] = (all_haikus[0] + all_haikus[1] + all_haikus[2]).str.replace(r'[^A-Za-z]', '').str.upper()
all_haikus = all_haikus.drop_duplicates(subset=['hash'])

all_haikus
# Out:
#                                  0                                 1  \
# 3                  Memorial Day --                 a shadow for each
# 4                    spring rain -              as the doctor speaks
# 5                spring moonset --                   a rice ball for
# 6                  sunny afternoon                an old man lingers
# 7                    cinco de mayo                       horses roll
# 8                    quitting time                 the smell of rain
# 9                            waves     slowly cresting towards shore
# 10               overnight rain --      the scent of orange blossoms
# 13               misty summer rain                  calling pheasant
# 14                     day is done                    poppies amidst
# 16                 watching clouds                  the white petals
# 17                 mountain stream             two well placed rocks
# 19                   night shift--     in the parking lot car lights
# 20                   a wild violet                on the sunny hill~
# 21                     a sunny day  pink haze of the cherry blossoms
# 23                 polished oak --         the freesia's shadow ends
# 25                     nobody here           a table in the mountain
# 26                      first date                 not even noticing
# 27      vanishing difference . . .         gliding geese settle onto
# 31                    distant hawk           a gust of cherry petals
# 33    Orange sunrise peaks through   The tubes and wires of father's
# 34                  moonlessness--                      so many ways
# 35                     earth day--          even the shadows at dusk
# 37                       so cold -             a goose honks its way
# 38                damp straw . . .       the day-old colt mesmerized
# 39                          prying               at the window . . .
# 40                in winter's wind              the call of a friend
# 42                   rainy bridge-                 the river flowing
# 43                  spring breeze-             the balcony's shadows
# 44                  winter drizzle        all the passing faces look
# ...                            ...                               ...
# 4757                    cloudy day                         daffodils
# 4760                    April city                    piss and apple
# 4761                   chiaroscuro                    windmills brew
# 4762                   closed buds                          the rain
# 4763                        sunset                two lonely poplars
# 4764                  yellow daisy                rocked by the wind
# 4766            before the storm -                    on the bitumen
# 4767               herons beak key                         his image
# 4768                    gray night              - On the glass shade
# 4769                    November 1            while slowly butterfly
# 4770               last leaves red          a butterfly takes flight
# 4771              end of September          gnawed through the sheet
# 4772                      a breeze                   the leaves fall
# 4773              district Airport       under the streaks that fade
# 4774                  autumn night                     in blue light
# 4775                     white dew                   on the clover -
# 4777                 the cold wave                       sharp edges
# 4778          last day of the year           - Traces of sleds rusty
# 4779             drizzle September               slow fall of a leaf
# 4780          sun behind the cloud               a small hot pumpkin
# 4781                muffled sounds                     seconds wings
# 4782              the Danube flows     in the direction of the blade
# 4783                  cool morning                     Ball chestnut
# 4784          the trough and crest            bump against the rocks
# 4785               the sea is calm              a butterfly flutters
# 4786               not bloomed yet           the field of sunflowers
# 4810                  lime quarter             an ice cube collapses
# 4845                  as she yells                         stillness
# 4847           divorce proceedings               our bed gets bigger
# 4848                  silently day                     becomes night
#
#                             2       source  \
# 3                 white cross  tempslibres
# 4           i think of lilacs  tempslibres
# 5                   breakfast  tempslibres
# 6            near the mailbox  tempslibres
# 7             in the shallows  tempslibres
# 8                in the lobby  tempslibres
# 9                a faint moon  tempslibres
# 10           in a desert town  tempslibres
# 13              in Zen temple  tempslibres
# 14            the dying grass  tempslibres
# 16        of a crushed crocus  tempslibres
# 17              the path home  tempslibres
# 19           dim near morning  tempslibres
# 20              noon time nap  tempslibres
# 21              over the hill  tempslibres
# 23             in coffee foam  tempslibres
# 25       speckled with petals  tempslibres
# 26               the new moon  tempslibres
# 27          their reflections  tempslibres
# 31           crosses the lawn  tempslibres
# 33       Life support machine  tempslibres
# 34        I want to touch you  tempslibres
# 35                smell green  tempslibres
# 37       across the night sky  tempslibres
# 38               by the radio  tempslibres
# 39                       wind  tempslibres
# 40         who now has cancer  tempslibres
# 42                     faster  tempslibres
# 43                 on my book  tempslibres
# 44              into the cafe  tempslibres
# ...                       ...          ...
# 4757               heads down     haikuzao
# 4760                 blossoms     haikuzao
# 4761     the halo of the moon     haikuzao
# 4762               is beating     haikuzao
# 4763     lean toward the east     haikuzao
# 4764               stormy sky     haikuzao
# 4766  browned petals hibiscus     haikuzao
# 4767     on the water surface     haikuzao
# 4768             a straw star     haikuzao
# 4769          is her sun spot     haikuzao
# 4770       close to the earth     haikuzao
# 4771             The blue sky     haikuzao
# 4772            on the petals     haikuzao
# 4773             flying heron     haikuzao
# 4774            a yellow rose     haikuzao
# 4775                 Moon day     haikuzao
# 4777            of halfpipe -     haikuzao
# 4778    in the snow yesterday     haikuzao
# 4779  against the black trunk     haikuzao
# 4780               in my palm     haikuzao
# 4781                 throttle     haikuzao
# 4782             a white boat     haikuzao
# 4783              well closed     haikuzao
# 4784  the sky after the storm     haikuzao
# 4785          above the rocks     haikuzao
# 4786     the nearly full moon     haikuzao
# 4810                over jazz     haikuzao
# 4845             of the ficus     haikuzao
# 4847               and bigger     haikuzao
# 4848  in this childless house     haikuzao
#
#                                                    hash
# 3                   MEMORIALDAYASHADOWFOREACHWHITECROSS
# 4             SPRINGRAINASTHEDOCTORSPEAKSITHINKOFLILACS
# 5                    SPRINGMOONSETARICEBALLFORBREAKFAST
# 6           SUNNYAFTERNOONANOLDMANLINGERSNEARTHEMAILBOX
# 7                    CINCODEMAYOHORSESROLLINTHESHALLOWS
# 8                  QUITTINGTIMETHESMELLOFRAININTHELOBBY
# 9             WAVESSLOWLYCRESTINGTOWARDSSHOREAFAINTMOON
# 10    OVERNIGHTRAINTHESCENTOFORANGEBLOSSOMSINADESERT...
# 13            MISTYSUMMERRAINCALLINGPHEASANTINZENTEMPLE
# 14                  DAYISDONEPOPPIESAMIDSTTHEDYINGGRASS
# 16         WATCHINGCLOUDSTHEWHITEPETALSOFACRUSHEDCROCUS
# 17          MOUNTAINSTREAMTWOWELLPLACEDROCKSTHEPATHHOME
# 19     NIGHTSHIFTINTHEPARKINGLOTCARLIGHTSDIMNEARMORNING
# 20                 AWILDVIOLETONTHESUNNYHILLNOONTIMENAP
# 21      ASUNNYDAYPINKHAZEOFTHECHERRYBLOSSOMSOVERTHEHILL
# 23         POLISHEDOAKTHEFREESIASSHADOWENDSINCOFFEEFOAM
# 25      NOBODYHEREATABLEINTHEMOUNTAINSPECKLEDWITHPETALS
# 26                   FIRSTDATENOTEVENNOTICINGTHENEWMOON
# 27    VANISHINGDIFFERENCEGLIDINGGEESESETTLEONTOTHEIR...
# 31         DISTANTHAWKAGUSTOFCHERRYPETALSCROSSESTHELAWN
# 33    ORANGESUNRISEPEAKSTHROUGHTHETUBESANDWIRESOFFAT...
# 34                MOONLESSNESSSOMANYWAYSIWANTTOTOUCHYOU
# 35               EARTHDAYEVENTHESHADOWSATDUSKSMELLGREEN
# 37             SOCOLDAGOOSEHONKSITSWAYACROSSTHENIGHTSKY
# 38           DAMPSTRAWTHEDAYOLDCOLTMESMERIZEDBYTHERADIO
# 39                                PRYINGATTHEWINDOWWIND
# 40         INWINTERSWINDTHECALLOFAFRIENDWHONOWHASCANCER
# 42                     RAINYBRIDGETHERIVERFLOWINGFASTER
# 43               SPRINGBREEZETHEBALCONYSSHADOWSONMYBOOK
# 44       WINTERDRIZZLEALLTHEPASSINGFACESLOOKINTOTHECAFE
# ...                                                 ...
# 4757                        CLOUDYDAYDAFFODILSHEADSDOWN
# 4760                      APRILCITYPISSANDAPPLEBLOSSOMS
# 4761           CHIAROSCUROWINDMILLSBREWTHEHALOOFTHEMOON
# 4762                         CLOSEDBUDSTHERAINISBEATING
# 4763            SUNSETTWOLONELYPOPLARSLEANTOWARDTHEEAST
# 4764                YELLOWDAISYROCKEDBYTHEWINDSTORMYSKY
# 4766    BEFORETHESTORMONTHEBITUMENBROWNEDPETALSHIBISCUS
# 4767             HERONSBEAKKEYHISIMAGEONTHEWATERSURFACE
# 4768                 GRAYNIGHTONTHEGLASSSHADEASTRAWSTAR
# 4769           NOVEMBERWHILESLOWLYBUTTERFLYISHERSUNSPOT
# 4770  LASTLEAVESREDABUTTERFLYTAKESFLIGHTCLOSETOTHEEARTH
# 4771      ENDOFSEPTEMBERGNAWEDTHROUGHTHESHEETTHEBLUESKY
# 4772                    ABREEZETHELEAVESFALLONTHEPETALS
# 4773  DISTRICTAIRPORTUNDERTHESTREAKSTHATFADEFLYINGHERON
# 4774                  AUTUMNNIGHTINBLUELIGHTAYELLOWROSE
# 4775                         WHITEDEWONTHECLOVERMOONDAY
# 4777                    THECOLDWAVESHARPEDGESOFHALFPIPE
# 4778  LASTDAYOFTHEYEARTRACESOFSLEDSRUSTYINTHESNOWYES...
# 4779  DRIZZLESEPTEMBERSLOWFALLOFALEAFAGAINSTTHEBLACK...
# 4780          SUNBEHINDTHECLOUDASMALLHOTPUMPKININMYPALM
# 4781                  MUFFLEDSOUNDSSECONDSWINGSTHROTTLE
# 4782   THEDANUBEFLOWSINTHEDIRECTIONOFTHEBLADEAWHITEBOAT
# 4783                  COOLMORNINGBALLCHESTNUTWELLCLOSED
# 4784  THETROUGHANDCRESTBUMPAGAINSTTHEROCKSTHESKYAFTE...
# 4785        THESEAISCALMABUTTERFLYFLUTTERSABOVETHEROCKS
# 4786  NOTBLOOMEDYETTHEFIELDOFSUNFLOWERSTHENEARLYFULL...
# 4810              LIMEQUARTERANICECUBECOLLAPSESOVERJAZZ
# 4845                      ASSHEYELLSSTILLNESSOFTHEFICUS
# 4847        DIVORCEPROCEEDINGSOURBEDGETSBIGGERANDBIGGER
# 4848        SILENTLYDAYBECOMESNIGHTINTHISCHILDLESSHOUSE
#
# [27734 rows x 5 columns]

# %% [markdown]
# # Get Syllable Count For Each Row

# %%
# Load Phonemes

# Standard Dict
WORDS = {}
with (dictionary_path / 'cmudict.dict.txt').open('r') as f:
    for line in f.readlines():
        word, phonemes = line.strip().split(' ', 1)
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0]
        phonemes = phonemes.split(' ')
        syllables = sum([re.match(r'.*\d', p) is not None for p in phonemes])
        #print(word, phonemes, syllables)
        if word not in WORDS:
            WORDS[word] = []
        WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })
        
# Load custom phonemes
CUSTOM_WORDS = {}
vowels = ['AA', 'AE', 'AH', 'AO', 'AW', 'AX', 'AXR', 'AY', 'EH', 'ER', 'EY', 'IH', 'IX', 'IY', 'OW', 'OY', 'UH', 'UW', 'UX']
with (dictionary_path / 'custom.dict.txt').open('r') as f:
    for line in f.readlines():
        try:
            word, phonemes = line.strip().split('\t', 1)
        except:
            print(line)
            continue
        word = re.match(r'([^\(\)]*)(\(\d\))*', word).groups()[0].lower()
        phonemes = phonemes.split(' ')
        syllables = sum([(p in vowels) for p in phonemes])
        
        if word not in CUSTOM_WORDS:
            CUSTOM_WORDS[word] = []
        CUSTOM_WORDS[word].append({
            'phonemes': phonemes,
            'syllables': syllables
        })

# %%
inflect_engine = inflect.engine()

# Dictionary of words not found, must go get the phonemes
# http://www.speech.cs.cmu.edu/tools/lextool.html
NOT_FOUND = set()

def get_words(line):
    """
    Get a list of the words in a line
    """
    line = line.lower()
    # Replace numeric words with the words written out
    ws = []
    for word in line.split(' '):
        if re.search(r'\d', word):
            x = inflect_engine.number_to_words(word).replace('-', ' ')
            ws = ws + x.split(' ')
        else:
            ws.append(word)

    line = ' '.join(ws)

    words = []
    for word in line.split(' '):
        word = re.match(r'[\'"]*([\w\']*)[\'"]*(.*)', word).groups()[0]
        word = word.replace('_', '')
        words.append(word)
        
    return words

def count_non_standard_words(line):
    """
    Count the number of words on the line that don't appear in the default CMU Dictionary.
    """
    count = 0
    for word in get_words(line):
        if word and (word not in WORDS):
            count += 1
    return count

def get_syllable_count(line):
    """
    Get the possible syllable counts for the line
    """
    counts = [0]
    return_none = False
    for word in get_words(line):
        try:
            if word:
                if (word not in WORDS) and (word not in CUSTOM_WORDS):
                    word = word.strip('\'')
                    
                if word in WORDS:
                    syllables = set(p['syllables'] for p in WORDS[word])
                else:
                    syllables = set(p['syllables'] for p in CUSTOM_WORDS[word])
                #print(syllables)
                new_counts = []
                for c in counts:
                    for s in syllables:
                        new_counts.append(c+s)

                counts = new_counts
        except:
            NOT_FOUND.add(word)
            return_none = True

    if return_none:
        return None
    
    return ','.join([str(i) for i in set(counts)])

# %%
# Remove haikus with lots of unknown words
# Likely either non-english or just lots of typos
all_haikus['unknown_word_count'] = np.sum([all_haikus[i].apply(count_non_standard_words) for i in range(3)], axis=0)
all_haikus = all_haikus[all_haikus['unknown_word_count'] < 3].copy()

for i in range(3):
    all_haikus['%s_syllables' % i] = all_haikus[i].apply(get_syllable_count)
    
print("Unknown Words: ", len(NOT_FOUND))

with open('unrecognized_words.txt', 'w') as f:
    for w in NOT_FOUND:
        f.write(w)
        f.write('\n')

all_haikus
# Out:
# Unknown Words:  0
#                                  0                                 1  \
# 3                  Memorial Day --                 a shadow for each
# 4                    spring rain -              as the doctor speaks
# 5                spring moonset --                   a rice ball for
# 6                  sunny afternoon                an old man lingers
# 7                    cinco de mayo                       horses roll
# 8                    quitting time                 the smell of rain
# 9                            waves     slowly cresting towards shore
# 10               overnight rain --      the scent of orange blossoms
# 13               misty summer rain                  calling pheasant
# 14                     day is done                    poppies amidst
# 16                 watching clouds                  the white petals
# 17                 mountain stream             two well placed rocks
# 19                   night shift--     in the parking lot car lights
# 20                   a wild violet                on the sunny hill~
# 21                     a sunny day  pink haze of the cherry blossoms
# 23                 polished oak --         the freesia's shadow ends
# 25                     nobody here           a table in the mountain
# 26                      first date                 not even noticing
# 27      vanishing difference . . .         gliding geese settle onto
# 31                    distant hawk           a gust of cherry petals
# 33    Orange sunrise peaks through   The tubes and wires of father's
# 34                  moonlessness--                      so many ways
# 35                     earth day--          even the shadows at dusk
# 37                       so cold -             a goose honks its way
# 38                damp straw . . .       the day-old colt mesmerized
# 39                          prying               at the window . . .
# 40                in winter's wind              the call of a friend
# 42                   rainy bridge-                 the river flowing
# 43                  spring breeze-             the balcony's shadows
# 44                  winter drizzle        all the passing faces look
# ...                            ...                               ...
# 4757                    cloudy day                         daffodils
# 4760                    April city                    piss and apple
# 4761                   chiaroscuro                    windmills brew
# 4762                   closed buds                          the rain
# 4763                        sunset                two lonely poplars
# 4764                  yellow daisy                rocked by the wind
# 4766            before the storm -                    on the bitumen
# 4767               herons beak key                         his image
# 4768                    gray night              - On the glass shade
# 4769                    November 1            while slowly butterfly
# 4770               last leaves red          a butterfly takes flight
# 4771              end of September          gnawed through the sheet
# 4772                      a breeze                   the leaves fall
# 4773              district Airport       under the streaks that fade
# 4774                  autumn night                     in blue light
# 4775                     white dew                   on the clover -
# 4777                 the cold wave                       sharp edges
# 4778          last day of the year           - Traces of sleds rusty
# 4779             drizzle September               slow fall of a leaf
# 4780          sun behind the cloud               a small hot pumpkin
# 4781                muffled sounds                     seconds wings
# 4782              the Danube flows     in the direction of the blade
# 4783                  cool morning                     Ball chestnut
# 4784          the trough and crest            bump against the rocks
# 4785               the sea is calm              a butterfly flutters
# 4786               not bloomed yet           the field of sunflowers
# 4810                  lime quarter             an ice cube collapses
# 4845                  as she yells                         stillness
# 4847           divorce proceedings               our bed gets bigger
# 4848                  silently day                     becomes night
#
#                             2       source  \
# 3                 white cross  tempslibres
# 4           i think of lilacs  tempslibres
# 5                   breakfast  tempslibres
# 6            near the mailbox  tempslibres
# 7             in the shallows  tempslibres
# 8                in the lobby  tempslibres
# 9                a faint moon  tempslibres
# 10           in a desert town  tempslibres
# 13              in Zen temple  tempslibres
# 14            the dying grass  tempslibres
# 16        of a crushed crocus  tempslibres
# 17              the path home  tempslibres
# 19           dim near morning  tempslibres
# 20              noon time nap  tempslibres
# 21              over the hill  tempslibres
# 23             in coffee foam  tempslibres
# 25       speckled with petals  tempslibres
# 26               the new moon  tempslibres
# 27          their reflections  tempslibres
# 31           crosses the lawn  tempslibres
# 33       Life support machine  tempslibres
# 34        I want to touch you  tempslibres
# 35                smell green  tempslibres
# 37       across the night sky  tempslibres
# 38               by the radio  tempslibres
# 39                       wind  tempslibres
# 40         who now has cancer  tempslibres
# 42                     faster  tempslibres
# 43                 on my book  tempslibres
# 44              into the cafe  tempslibres
# ...                       ...          ...
# 4757               heads down     haikuzao
# 4760                 blossoms     haikuzao
# 4761     the halo of the moon     haikuzao
# 4762               is beating     haikuzao
# 4763     lean toward the east     haikuzao
# 4764               stormy sky     haikuzao
# 4766  browned petals hibiscus     haikuzao
# 4767     on the water surface     haikuzao
# 4768             a straw star     haikuzao
# 4769          is her sun spot     haikuzao
# 4770       close to the earth     haikuzao
# 4771             The blue sky     haikuzao
# 4772            on the petals     haikuzao
# 4773             flying heron     haikuzao
# 4774            a yellow rose     haikuzao
# 4775                 Moon day     haikuzao
# 4777            of halfpipe -     haikuzao
# 4778    in the snow yesterday     haikuzao
# 4779  against the black trunk     haikuzao
# 4780               in my palm     haikuzao
# 4781                 throttle     haikuzao
# 4782             a white boat     haikuzao
# 4783              well closed     haikuzao
# 4784  the sky after the storm     haikuzao
# 4785          above the rocks     haikuzao
# 4786     the nearly full moon     haikuzao
# 4810                over jazz     haikuzao
# 4845             of the ficus     haikuzao
# 4847               and bigger     haikuzao
# 4848  in this childless house     haikuzao
#
#                                                    hash  unknown_word_count  \
# 3                   MEMORIALDAYASHADOWFOREACHWHITECROSS                   0
# 4             SPRINGRAINASTHEDOCTORSPEAKSITHINKOFLILACS                   0
# 5                    SPRINGMOONSETARICEBALLFORBREAKFAST                   1
# 6           SUNNYAFTERNOONANOLDMANLINGERSNEARTHEMAILBOX                   0
# 7                    CINCODEMAYOHORSESROLLINTHESHALLOWS                   1
# 8                  QUITTINGTIMETHESMELLOFRAININTHELOBBY                   0
# 9             WAVESSLOWLYCRESTINGTOWARDSSHOREAFAINTMOON                   0
# 10    OVERNIGHTRAINTHESCENTOFORANGEBLOSSOMSINADESERT...                   0
# 13            MISTYSUMMERRAINCALLINGPHEASANTINZENTEMPLE                   0
# 14                  DAYISDONEPOPPIESAMIDSTTHEDYINGGRASS                   0
# 16         WATCHINGCLOUDSTHEWHITEPETALSOFACRUSHEDCROCUS                   0
# 17          MOUNTAINSTREAMTWOWELLPLACEDROCKSTHEPATHHOME                   0
# 19     NIGHTSHIFTINTHEPARKINGLOTCARLIGHTSDIMNEARMORNING                   0
# 20                 AWILDVIOLETONTHESUNNYHILLNOONTIMENAP                   0
# 21      ASUNNYDAYPINKHAZEOFTHECHERRYBLOSSOMSOVERTHEHILL                   0
# 23         POLISHEDOAKTHEFREESIASSHADOWENDSINCOFFEEFOAM                   1
# 25      NOBODYHEREATABLEINTHEMOUNTAINSPECKLEDWITHPETALS                   0
# 26                   FIRSTDATENOTEVENNOTICINGTHENEWMOON                   0
# 27    VANISHINGDIFFERENCEGLIDINGGEESESETTLEONTOTHEIR...                   0
# 31         DISTANTHAWKAGUSTOFCHERRYPETALSCROSSESTHELAWN                   0
# 33    ORANGESUNRISEPEAKSTHROUGHTHETUBESANDWIRESOFFAT...                   0
# 34                MOONLESSNESSSOMANYWAYSIWANTTOTOUCHYOU                   1
# 35               EARTHDAYEVENTHESHADOWSATDUSKSMELLGREEN                   0
# 37             SOCOLDAGOOSEHONKSITSWAYACROSSTHENIGHTSKY                   0
# 38           DAMPSTRAWTHEDAYOLDCOLTMESMERIZEDBYTHERADIO                   0
# 39                                PRYINGATTHEWINDOWWIND                   0
# 40         INWINTERSWINDTHECALLOFAFRIENDWHONOWHASCANCER                   0
# 42                     RAINYBRIDGETHERIVERFLOWINGFASTER                   0
# 43               SPRINGBREEZETHEBALCONYSSHADOWSONMYBOOK                   1
# 44       WINTERDRIZZLEALLTHEPASSINGFACESLOOKINTOTHECAFE                   0
# ...                                                 ...                 ...
# 4757                        CLOUDYDAYDAFFODILSHEADSDOWN                   0
# 4760                      APRILCITYPISSANDAPPLEBLOSSOMS                   0
# 4761           CHIAROSCUROWINDMILLSBREWTHEHALOOFTHEMOON                   1
# 4762                         CLOSEDBUDSTHERAINISBEATING                   0
# 4763            SUNSETTWOLONELYPOPLARSLEANTOWARDTHEEAST                   1
# 4764                YELLOWDAISYROCKEDBYTHEWINDSTORMYSKY                   0
# 4766    BEFORETHESTORMONTHEBITUMENBROWNEDPETALSHIBISCUS                   1
# 4767             HERONSBEAKKEYHISIMAGEONTHEWATERSURFACE                   0
# 4768                 GRAYNIGHTONTHEGLASSSHADEASTRAWSTAR                   0
# 4769           NOVEMBERWHILESLOWLYBUTTERFLYISHERSUNSPOT                   0
# 4770  LASTLEAVESREDABUTTERFLYTAKESFLIGHTCLOSETOTHEEARTH                   0
# 4771      ENDOFSEPTEMBERGNAWEDTHROUGHTHESHEETTHEBLUESKY                   0
# 4772                    ABREEZETHELEAVESFALLONTHEPETALS                   0
# 4773  DISTRICTAIRPORTUNDERTHESTREAKSTHATFADEFLYINGHERON                   0
# 4774                  AUTUMNNIGHTINBLUELIGHTAYELLOWROSE                   0
# 4775                         WHITEDEWONTHECLOVERMOONDAY                   0
# 4777                    THECOLDWAVESHARPEDGESOFHALFPIPE                   1
# 4778  LASTDAYOFTHEYEARTRACESOFSLEDSRUSTYINTHESNOWYES...                   0
# 4779  DRIZZLESEPTEMBERSLOWFALLOFALEAFAGAINSTTHEBLACK...                   0
# 4780          SUNBEHINDTHECLOUDASMALLHOTPUMPKININMYPALM                   0
# 4781                  MUFFLEDSOUNDSSECONDSWINGSTHROTTLE                   0
# 4782   THEDANUBEFLOWSINTHEDIRECTIONOFTHEBLADEAWHITEBOAT                   0
# 4783                  COOLMORNINGBALLCHESTNUTWELLCLOSED                   0
# 4784  THETROUGHANDCRESTBUMPAGAINSTTHEROCKSTHESKYAFTE...                   0
# 4785        THESEAISCALMABUTTERFLYFLUTTERSABOVETHEROCKS                   0
# 4786  NOTBLOOMEDYETTHEFIELDOFSUNFLOWERSTHENEARLYFULL...                   0
# 4810              LIMEQUARTERANICECUBECOLLAPSESOVERJAZZ                   0
# 4845                      ASSHEYELLSSTILLNESSOFTHEFICUS                   1
# 4847        DIVORCEPROCEEDINGSOURBEDGETSBIGGERANDBIGGER                   0
# 4848        SILENTLYDAYBECOMESNIGHTINTHISCHILDLESSHOUSE                   0
#
#      0_syllables 1_syllables 2_syllables
# 3              5           5           2
# 4            2,3           5           5
# 5            3,4           4           2
# 6              5           5           4
# 7              5           3           4
# 8              3           4           4
# 9              1         6,7           3
# 10             4           7           5
# 13             5           4           4
# 14             3           4           4
# 16             3           4           5
# 17             3           4           3
# 19             2           7           4
# 20           4,5           5           3
# 21             4           8           4
# 23             3           7           4
# 25             4           7           5
# 26             2           6           3
# 27           5,6           7           4
# 31             3           7           4
# 33             6         8,7           5
# 34             3           4           5
# 35             2           7           2
# 37             2           5           5
# 38             2           6           5
# 39             2           4           1
# 40             4           5           5
# 42             3           5           2
# 43           2,3           6           3
# 44             4           7           5
# ...          ...         ...         ...
# 4757           3           3           2
# 4760           4           4           2
# 4761           5           3           6
# 4762           2           2           3
# 4763           2           5         4,5
# 4764           4           4           3
# 4766           4           5           6
# 4767           4           3           6
# 4768           2           4           3
# 4769           4           6           4
# 4770           3           6           4
# 4771           5           4           3
# 4772           2           3           4
# 4773           4           6           4
# 4774           3           3           4
# 4775           2           4           2
# 4777           3           3           3
# 4778           5           6           6
# 4779           5           5           5
# 4780           5           5           3
# 4781           3           3           2
# 4782           4           8           3
# 4783           3           3           2
# 4784           4           5           6
# 4785           4           6           4
# 4786           3           6           5
# 4810           3           6           3
# 4845           3           2           4
# 4847           5         5,6           3
# 4848           4           3           5
#
# [25886 rows x 9 columns]

# %%
all_haikus.drop(columns=['unknown_word_count', 'hash']).to_csv(str(poem_path / 'haikus.csv'), index=False)
