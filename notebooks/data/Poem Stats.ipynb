# %%
import pandas as pd

# %%
df = pd.read_csv('../../input/poems/haikus.csv')
df
# Out:
#                                    0                                 1  \
# 0                    Memorial Day --                 a shadow for each
# 1                      spring rain -              as the doctor speaks
# 2                  spring moonset --                   a rice ball for
# 3                    sunny afternoon                an old man lingers
# 4                      cinco de mayo                       horses roll
# 5                      quitting time                 the smell of rain
# 6                              waves     slowly cresting towards shore
# 7                  overnight rain --      the scent of orange blossoms
# 8                  misty summer rain                  calling pheasant
# 9                        day is done                    poppies amidst
# 10                   watching clouds                  the white petals
# 11                   mountain stream             two well placed rocks
# ...

# %%
df[
    df['0_syllables'].str.contains('^5,|,5$|,5,|^5$') &
    df['1_syllables'].str.contains('^7,|,7$|,7,|^7$') &
    df['2_syllables'].str.contains('^5,|,5$|,5,|^5$')
]
# Out:
#                                 0                                    1  \
# 34            last red in the sky       a small girl's moon face rises
# 200            christmas services           a cellular phone rings out
# 373           Passover darkness -          before the buds burst open;
# 430          Last night of Summer   the bright full moon of last night
# 434        Midnight and full moon          my neighbour asks to borrow
# 497          yellow walnut leaves          slowly appear on the lawn--
# 511        Sentinels of spring...          kites bobbing for attention
# 645        after its first flight         the young gerfalcon's talons
# 679              sultry afternoon              only the mailbox shadow
# 680     long journey back home --              a forgotten bale of hay
# 702          Autumn mist obscures           the island in the distance
# 751       snow mixes with rain --           my mother keeps calling me
# ...

# %%
725/25886
# Out:
# 0.028007417136676194
