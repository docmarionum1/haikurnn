# %%
try:
    import keras
except:
    # !pip install keras
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from pathlib import Path

import tensorflow as tf
tf_session = tf.Session()
from keras import backend as K
K.set_session(tf_session)

from sklearn.externals import joblib

# Local library with model definitions for training and generating
from models import create_training_model, Generator

# %%
# Load a copy of the training model from disk by creating a new model using the same parameters and then loading the weights.

output_dir = Path('minus_twaiku')

# Get the parameters used for creating the model
latent_dim, n_tokens, max_line_length, tokenizer = joblib.load(output_dir / 'metadata.pkl')

# Create the new placeholder model
training_model, lstm, lines, inputs, outputs = create_training_model(latent_dim, n_tokens)

# Load the specified weights
training_model.load_weights(output_dir / '2048-05-1.72.hdf5')

# %%
# Create a generator using the training model as the template

generator = Generator(lstm, lines, tf_session, tokenizer, n_tokens, max_line_length)

# %%
for i in range(50):
    generator.generate_haiku()
    print()
# Out:
# early morning sun
# from the carried garden fate
# stars at the sunset
#
# king olam spring
# a butterfly and i start
# the smell of a but
#
# king of the moon shines
# of a spring in her brow and
# the spring is here
#
# quiet and black the
# where the street lamp sparkled with
# and the shadowy stream
#
# morning stillness of snow
# and the same path of the street
# like a paper beach
#
# deep in the corner
# the spent of the old cattle
# a strange of wind
#
# king ola many day
# in the spring is a first time
# in the compost birds
#
# not an old man hard
# the sun is like a long time
# in the spring breeze
#
# your hand spirit all
# and the spring and the sun
# in the spring breeze
#
# winter solstice clouds
# a butterfly and i start
# the strange of the sky
#
# just as i walk the sand
# and the sun is like a crown
# of the spring is here
#
# xitter windows sleep
# a conversation of the
# beautiful and pige
#
# not the sun is bright
# and the soul and the spring are
# before the stars are breath
#
# family picnic
# the sun as a butterfly
# and the shadow of y
#
# your hand speaks as here
# in the great grave of the street
# like a blood red clouds
#
# red clouds at hurricane
# a contrail of a crow falls
# on the old cattle
#
# grass start over the sky
# a conversation of the street
# and the shadowy street
#
# i saw the land of
# the sun is like a creative
# shall be the same stars
#
# under the carried
# of a butterfly and me
# in the spring breeze
#
# between the storm wall
# the sun is an antion
# and the shadowy stees
#
# under the carried
# of a butterfly and the shade
# of a spring breeze
#
# valentine's day --
# a conversation of the
# between the stars beew
#
# not an old man hard
# the sun is like a long time
# in the spring breeze
#
# start the sun is bright
# and the sun is like a crow
# from the strange that hand
#
# light of the old path
# in the spring is a four hand
# stars at the sunset
#
# passing the storm clouds
# the spent of the old cattle
# a strange of the sun
#
# start traffic at the beach
# the spent of her brow and the shade
# of a butterfly
#
# the strange that had not
# because the sun is like a crow
# for the same stars that
#
# quiet and black and breast
# and the sun is like a crow
# from the stars and them
#
# family picnic
# the sound of a cocone shop
# the sunlit cattail stone
#
# deep in the corner
# the sun is an antion
# and the shadowy stream
#
# he stands at the sky
# the speak of a butterfly
# even the spring breeze
#
# just as i deeper
# i want to see a bottom
# of the spring breeze
#
# morning stillness of snow
# a butterfly and i start
# the stars and the sky
#
# a spring cloud with dawn---
# a caterpillar drinking
# from the candle's end
#
# start to the season
# a sprinter dashes the battle
# of a butterfly
#
# between twe train trails
# a sprint in her hand rises
# a strange hand truins
#
# on the care shadows
# the sprinter dashes the battle
# of a butterfly
#
# her parting star and
# she stirs the speed of heaven
# and the same shadows
#
# xit was a walking
# street and falling on the window
# stars at the starry sky
#
# your hand spirit on
# and the sun is like a crow
# for the same stars warm
#
# in the dark carpet
# of a spring in her brow
# a spring break between
#
# christmas market clouds
# a sprinter dashes the battle
# of a spring breeze
#
# a spring cloudless sunlight
# the sun is like a book and fire
# and the shadowy stream
#
# the strange that had not
# by the sunset whole we speak
# of the spring breeze
#
# zandard crescent moon
# the smell of a coconut
# with a parking lot
#
# a spring cloudless sunlight
# the sun is like a beautiful
# with a barbarow
#
# not an old man hard
# the sun is like a long time
# in the spring breeze
#
# i saw the last light
# of the spring and the sunset
# like a perform there
#
# candles flicker in lamp
# in the spring is a first the
# what is the same cloud

# %%
for i in range(50):
    generator.generate_haiku([3, 5, 3])
    print()
# Out:
# on the street
# a sprinter dashes
# the strawberr
#
# deep winter
# i wash the shadow
# of the street
#
# red pappies
# the strange the children
# of the stars
#
# spring sunshine
# the smell of waters
# from the stars
#
# deep winter
# the smell of a crow
# from the stars
#
# you are me
# i was a beauty
# i will not
#
# grass standing
# the smell of a country
# spring sunset
#
# village street
# a butterfly flips
# in the sky
#
# winter sun
# the smell of children
# in the sky
#
# red pappies
# the smell of a child
# with the stars
#
# lingering dusk
# the smell of waters
# from the stars
#
# on the street
# a sprint in her hair
# a different shade
#
# beach to school
# the smell of water
# in the sky
#
# new year's eve
# reading the cardinal
# a strange hand
#
# in the sun
# the spent candle flames
# from the street
#
# early spring
# the smell of a first
# the strawberr
#
# early spring
# the smell of water
# in the sky
#
# xitter day
# the smell of children
# in the sky
#
# gray spring dawn-
# the smell of waters
# from the stars
#
# lingering dusk
# the smell of waters
# from the stars
#
# quiet dawn-
# i watch the sunset
# long summer
#
# quiet dawn-
# i watch the sunset
# spring sunset
#
# you are me
# i was a beauty
# i can see.
#
# just evening
# the sound of a construct
# of a breath
#
# under the house
# the sprinter dashes
# the strawberr
#
# late summer
# a child with a bottle
# between us
#
# deep winter
# i wake the way home
# a child winh
#
# her shadows
# she passes his child
# on the street
#
# in the street
# a sprint in her hair
# on the stars
#
# early spring
# the smell of a fire
# of spring rain
#
# grass started -
# the smell of children
# at the storm
#
# deep winter
# the smell of a child
# with the stars
#
# under the house
# the sprinter dashes
# the summer
#
# red pappies
# the sound of a country
# spring sunset
#
# just evening
# the smell of a cock
# of a breeze
#
# her face stream
# a sprint in her hair
# in the sky
#
# lightning stars
# a contrail crosses
# the street lamp
#
# black fireflies
# a contrail crosses
# the stars breeze
#
# spring sunshine
# the smell of a first
# the sunset
#
# in the barn
# the spent of her hand
# remain me
#
# the shadows
# of a construction . . .
# spring sunset
#
# new year's eve
# remembering the sun
# of the street
#
# red moonlight
# on the window bleeds
# a different stars
#
# on the street
# a contrail crosses
# the stars breeze
#
# zinger book
# the smell of a country
# spring sunset
#
# lingering dusk
# the smell of a cat
# from the stars
#
# the short night
# a child with a bottle
# from the street
#
# early spring
# the smell of water
# in the sun
#
# new year's eve
# remembering the sun
# of the street
#
# deep winter
# i want to see the snow
# of the street

# %%
for i in range(50):
    generator.generate_haiku([10, 10, 10])
    print()
# Out:
# like a bird out of the same pall of street
# and the soul but the spring are blowing
# with every beat of my heart i will love you
#
# the strange that have been one say he said to hear
# and the sun is like a long time in the sun
# of the spring is leave the sunset land
#
# down the strange the stars and the barning crowd
# and the soul and the spring are blowing
# with a barn of wind that shade you groan with you
#
# strange the stars and the barning of the stars
# and the soul and the spring and the sun
# in the spring will not be an eye and we
#
# i want to be satinft in the shadowy
# the sun is an interesting searching
# the sun is an another spring
#
# god listening must have overheard
# the friendliness of the spring are blowing
# with every beat of my heart i will love you
#
# past the stars and the stars and the grass and the
# street and the spring of freedom's being and dead
# and the sun stared at our signs thou shalt not kill
#
# kindle of the stars and the beauty of the
# still with silver streets and the spring are blowing
# with every beat of my heart i will love you
#
# vainly still the strange the stars and the stars
# the speed of the spring are blowing with the sparrow
# of the spring is here and the shadowy
#
# for he the sees when stars were starting
# the sun is like a long time in the spring
# i am a new priam of our life
#
# strange that he shall come back to the sun is bright
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# he shall guide us through this dark not by new-blown glories
# but they are free from his orn or hall
# and the sign of an only and all theer lives
#
# upon the wall with the stars and the stars
# the sun is green in the wind and the window
# some strong and the shadowy stays of the sun
#
# i want to tell you the stars and the bride
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# only the sun is bright as high and sparrow
# she shows the sun is like a long time with
# and the shadowy stay the strandle shadow
#
# just as the street lamp spake the sun is bright
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# standing the stars and the sun is bright
# and the heart can understand the sun
# in the shadowy state of the spring
#
# just as it was a sinkle bear back
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# my heart is the barring of the boys of the street
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# your strange that he said to the sunset hall
# and the soul and the wind who strikes his hand
# and the same stars and the shadowy street
#
# queer the great love of a little story
# the heart that didn't love and fair and fair
# the shadowy stay that shall be bloom dead
#
# passing the stars and the sun is bright
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# your strange that he said to his heart and heart
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# come my love my lover my friend of mone
# she knew such a strong and the sunset whole it
# in the shadowy state of an angels
#
# and the wind cumbing at the carpenter
# where the farmor of the spring are blowing
# with every beat of my heart i will love you
#
# my heart is a precious place and blast and sleep
# and the sun is like a long time in the street
# and the shadowy chair with a beautiful wind
#
# he shall guide us through this dark not by new-blown glories
# but they are flesh in love and blood and stars
# with every beat of my heart i will love you
#
# january not the sun is bright
# the heart can understand with a small speed
# of the spring is left us only sleep
#
# my heart is the barring of the blood red snow
# in the spring are blowing with the spring
# i sat six you and the water was lifted
#
# upon the world that stretched all the grass and the
# strengthened by the spring are blowing will not see
# the sun stared at our signs thou shalt not kill
#
# come my love my love my lover my friend
# our start the shadow cheered when our fatsers
# with every beat of my heart i will love you
#
# now the strangest things to the sparrows
# of the spring is strike a dream and blood
# red the stars that shade you groan with light
#
# just as the storm was cold and blood and blow
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# red more clear the street lamp spake the sun
# in the spring are blowing with the spring
# in the sunset all men silently to their souls
#
# passing the stars and the spring is changed
# and the soul but sings a strange that have been
# and the same thing that we have to death
#
# passing the stars and the stars and the stars
# the hour and the wind will be on your back
# and the sign of an only and till them
#
# my heart is wasted and fair to the stars
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# my heart is so much as an angel fall
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# nor am i inherent in the vedas
# nor am i intrinsic in the pure/impure
# nor am i of water nor of land
#
# i want the sand and song and lifted the
# strengthen and falling from the spring are blowing
# with every sill we stare to the world
#
# god listening must have overheard
# the heart can understand what it is that in
# and the sign of an old man to the sea
#
# he shall guide us through this dark not by new-blown glories
# but they are free from his orn or half
# and the sign fram spring as her father's grace
#
# can you see the parting of the sun
# i want to see the passing of the sun
# in the spring is left of the sunset sky
#
# my heart is so much day and not one star
# the sun is like a long time in the spring
# i have forgotten you and not the same
#
# start the strange the stars and the sun is bring
# the heart can understand with a small spide
# of the spring is left us only sleep
#
# zan and start and blood and blood and blood in his strowl
# the friendly flame of the spring are blowing
# with every beat of my heart i will love you
#
# earth with beautiful and blood and blood in his braid
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# just a little wind that speaks of meaning
# and the soul and the wind which in the spring
# i have been good i get an orange after food
#
# i saw the strange that he said to the shore
# and the soul and the spring are blowing
# with every beat of my heart i will love you
#
# passing the stars and the spring is a the
# she knew such a fam of and a family friend
# of the spring is here and the shadowy

# %%
for i in range(50):
    generator.generate_haiku(temperature=.3)
    print()
# Out:
# not the sun showers
# she leaves a painted rose spread
# and the shadowy street
#
# spring evening breakfast
# a butterfly and i saw
# her face to the sea
#
# early morning sun
# the sun like the windows she still
# she still falls asound
#
# family picnic
# the children standing off the snow
# in the shadow bag
#
# kingling through the grass
# a child with the abone walls
# in the candle's flame
#
# love is a spring
# i am come i am come
# i cannot close mine eyes
#
# like a bird out of the
# leave the street lamp small brows flowers
# and the same clouds close
#
# the strange that has been
# by the spring against the street
# light of a new prine
#
# quiet and black the stream
# and the sparrows of the street
# and the same sallies
#
# what is the heart of
# the world of the great stars and the
# were the same shadowy
#
# family picnic
# the sun and song in the sun
# in the spring breeze
#
# family picnic
# the scent of freezing of snow
# on the spring breeze
#
# under the cattle tree
# a strange the candle flames flicker
# the spring break between
#
# january dawn
# the sound of a moth cleaning
# on the old path tree
#
# chair market over
# the sound of a mother's hand
# remembering summer
#
# your wall that spring is
# and the sun is growing on
# and the heart side shall
#
# need of the storm clouds
# the sprinter dashes the ground
# in the carden ware
#
# the wall in the barn
# the spirit of a bottle
# falls from the path bell
#
# zany afternoon
# in the moon and the contrails
# of the spring breeze
#
# quick steady sunshine
# the sun is break and blood red light
# on the spring breeze
#
# xundred years ago
# the stars of the man of the
# line of the line of men
#
# early spring day
# a butterfly and is on
# early morning sun
#
# valentine's day --
# a butterfly and i stood
# on the hand playmouth
#
# under the care bark
# the spent of her middle bees
# and come to planted
#
# under the shortest day
# a cattle of a mother
# of a spring breeze
#
# on the water day
# a little bird on the wind
# stars at the back look
#
# kits heaven and bride
# and of the soul and the world
# i can be happy
#
# on the cardinal -
# the smell of a child wakes before
# the spring is here
#
# from the barrel cold
# a conversation of the
# with a world of may
#
# god is with us
# the sun is like a carding
# and the silent grave
#
# like the burning cold
# a bead of winter sunset
# lingering day ourselv
#
# her partical past
# the sound of a small boy stops
# the sunset moon rise
#
# in the corner sand
# and the white heart comes out
# from the strange of man
#
# red bear squabbed with light
# and the girl in the world's speed
# and the same cloud of green
#
# graduation slips
# a painted crass of curled up
# in the sunset light
#
# xating and freezing
# a butterfly and the green
# of a hot if spring
#
# on the window sill
# i remember the graveyard
# of a spring breeze
#
# what shall i then love
# her father's hand upon the street
# and the shadowy stream
#
# garden two dragon
# leaves on the water lands and
# dead lady and gold
#
# mountain thunderstorm
# the carved graffiti lines
# on the spring breeze
#
# on the cattle tree
# and the hand of a fire
# and the only carp
#
# under the sunset
# the silence between the sound
# of a newspaper
#
# deep in the beach street
# a candle of a crow flies
# from the contrails street
#
# start the sun is bright
# and the sunset child in the
# but in the shadowy
#
# kissing her brown skin
# the sound of a mother's hour
# under the careful
#
# power of the street
# a bear of wind and the scent
# of a butterfly
#
# winter solstice shadows
# the sun is an inside of stones
# in the spring breeze
#
# between two halls steep
# and the sun is like a bear
# beside the tongue
#
# starry stone walls
# the cat can see a beautiful
# when the stars are flow
#
# passive in the air
# and you and i was a beauty
# i have fettered it

# %%
for i in range(50):
    generator.generate_haiku(temperature=.5)
    print()
# Out:
# every slam had streek
# and they in the harkest mans
# she did not stay with last
#
# your hand herpers fall
# and the wind will not see the sound
# of the near your hand
#
# zanua a gazzer
# a caterpillar passes
# between two barghing
#
# your offering faith
# in the spring is were there
# she was her eyes close
#
# young should i live it
# light flow of an my sweet ast
# unreed to the wind
#
# memorial day ...
# needle on the antler light
# of a bear butterfly
#
# even the our pain
# in the garden grassy green
# looked up in the fire
#
# candles flicker in the
# even the gentle things of the beard
# of the golden window
#
# gathering the grass
# the sprinter dashes his ways
# in the wool to seed
#
# how cried him from the
# sweet the far and the sunset
# of the story chair
#
# keep off the highway
# a thousand distant village
# summer to the sea
#
# it is the only day
# in the street all the with night
# of a beautiful shell
#
# our place our cause
# god help us and mare streng
# in air as parenge
#
# under the cattle tree
# the strange that flattens the sun
# in the spring is here
#
# earths of her brave stars
# the such sunlight of a fair
# his sand in his eyes
#
# every wift of sleep
# and fall from his orning hand
# and the same pillow
#
# zan prayers in stoop
# press of the street light on the
# shaked the sunlit mind
#
# red tiped of a true
# in the small boy and i do
# faded into the sale
#
# under the barrel wall
# my chalk of covered windows
# in the coffee cup
#
# under the cotton
# of the personal hours
# on the compuse light
#
# drifting bourband flight
# on the charn grave a space but
# of cale of the storm
#
# no man is an bar
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-f82221fe6267> in <module>()
#       1 for i in range(50):
# ----> 2     generator.generate_haiku(temperature=.5)
#       3     print()
#
# /storage/Notebooks/v1/models.py in generate_haiku(self, syllables, temperature, first_char)
#     139                             np_utils.to_categorical(
#     140                                 line_output[-1],
# --> 141                                 num_classes=self.n_tokens
#     142                             )
#     143                         ]],
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      23         is placed last.
#      24     """
# ---> 25     y = np.array(y, dtype='int')
#      26     input_shape = y.shape
#      27     if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
for i in range(50):
    generator.generate_haiku(temperature=1)
    print()
# Out:
# vellanga of spring
# the cletter dump sutcanticy
# her grave interlets
#
# deceation scottle
# mary many i knew of swat
# in mine earming dud
#
# zandest dauboler
# i went to pause a peen's sawl
# candles fall nittle
#
# bridgeture you gave
# beautiful young caive, a voice of
# yeercholy youth drinking
#
# how creaturen as
# the seat that ohe out of each
# of which we lay and
#
# midsummer heat troe
# the golden honking of gravey
# rounds whisper than me
#
# xwhistering thinder
# fix conscious only on the hill
# across the protect
#
# the winter slapped,
# at sident pacents
# the smell of winter
#
# patter of rises
# a fullim wirgs overflows
# that my impoint cloud
#
# processionator
# t sxare saill heave be as conside
# and search for her mile
#
# zold past last buster?
# i never yearned mountain
# the winter taples
#
# mruse in a shacken
# then compose their choise touches
# our namas nileas
#
# foggoner windows
# lest intaptions falling
# piped-tto the starry fields
#
# rive in all men bark
# your nothing music the mind?
# again in yellow
#
# each other lideroubs
# all the brive defications
# over the rementer
#
# new trills filler when were
# in every sold in it
# says that i've been good
#
# speat from the morning
# a cagablace bods out
# thoughts the sunlit break
#
# jaggadande glad
# each cat qunet her narebeat
# brike troubling the wir
#
# near, in the land of
# con't ox brueh, "etha bitter feet,
# it mey become.
#
# jadaneam of red
# fall as c unsetan willoom
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-fddfd81a52b0> in <module>()
#       1 for i in range(50):
# ----> 2     generator.generate_haiku(temperature=1)
#       3     print()
#
# /storage/Notebooks/v1/models.py in generate_haiku(self, syllables, temperature, first_char)
#     139                             np_utils.to_categorical(
#     140                                 line_output[-1],
# --> 141                                 num_classes=self.n_tokens
#     142                             )
#     143                         ]],
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      23         is placed last.
#      24     """
# ---> 25     y = np.array(y, dtype='int')
#      26     input_shape = y.shape
#      27     if input_shape and input_shape[-1] == 1 and len(input_shape) > 1:
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %%
for i in range(50):
    generator.generate_haiku([3, 3, 3], temperature=.3)
    print()
# Out:
# winter sun
# the sprint sings
# of the stars
#
# zinnia sky
# a crow falls
# on the clouds
#
# autumn sun
# the scent of
# still for me
#
# xin blossoms
# my boots creak
# in the sun
#
# early spring
# the child washed
# the shadows
#
# early spring
# a black fich
# rising sun
#
# darkening sky
# a child's grave
# in the stars
#
# a spring cloud
# the smell of
# autumn sun
#
# unanswered
# the sunset
# comes out of
#
# red clouds pain
# in the wind
# spring sunset
#
# day after . . .
# the shadow
# of a bark
#
# kits of spring
# i wake the worm
# in the tree
#
# early spring
# the stone budd
# at the storm
#
# zarment prayer
# the first step
# in the sky
#
# deep winter
# the smell of
# at the storm
#
# xinger clouds
# a child's grave
# on the stars
#
# our country
# steaming on
# a child will
#
# morning fush
# the sunset
# closer time
#
# fireflies
# my children
# in the barn
#
# parting clouds
# a fire front
# on the street
#
# village street
# a child's call
# in the sky
#
# long winter
# the wind chimes
# of the sun
#
# spring sunshine
# the shadows
# of the bridge
#
# red clouds break
# a fire tarning
# the strawberr
#
# deep winter
# a child's change
# the shadows
#
# xating days
# the sun is
# at the sunset
#
# bright winter
# the park bench
# in the sun
#
# o find they
# and the sea
# and the stars
#
# kits of bar
# her parting
# the sunset
#
# falling leaves
# the short stones
# the strawberr
#
# grass starred by
# the sprint river
# the moon rise
#
# kitten soul
# still bears and
# in the barn
#
# winter sun
# the sun rounds
# on the stone
#
# early spring
# the shadows
# of the stream
#
# morning sun
# the smell of
# and the shore
#
# kitchen mose
# the sprint silence
# of blue sky
#
# zarmand creek
# the shadow
# of a spring
#
# lifting off . . .
# the sunset
# color but
#
# new year's eve
# the street lamp
# of a breath
#
# autumn sun
# the strawbrings
# of a stream
#
# a cloud of grass
# starting through
# the summer
#
# red clouds break
# a child's change
# through the sky
#
# years shower
# a small blun
# at the board
#
# veteran's day --
# the scent of
# a thousand
#
# red clouds . . .
# the grass blows
# of spring rain
#
# autumn dusk
# the sunset
# the bull brows
#
# spring sunshine
# the short breaks
# of the side
#
# the sound of
# a small bloom
# the shadows
#
# on the wind
# the shadow
# of a bowl
#
# mountain stream
# a white stone
# still marching

# %%
for i in range(50):
    generator.generate_haiku([3, 3, 3], temperature=.75)
    print()
# Out:
# perched on a fated
# floating drops
# of stuck break
#
# xily dawn---
# a couple wripped
# to the stars
#
# kneck on the leaf
# year wind white
# my feet the
#
# mile after mile
# of your heart
# in the dead
#
# zazening that
# how up though
# your stick fall
#
# prayer is right
# my daughter's
# eye inkills
#
# end of summer -
# the hauntist
# in all our
#
# ye shall mive
# what our sweetheastars
# comes formide
#
# crossing waves . . .
# the faint talk
# traffic can
#
# popling cools...
# red papping
# in a breeze
#
# morning wind
# the shadow
# the window
#
#  on meet house
# she must bo
# beauty they
#
# by the voice
# of his ice
# break and beam
#
# quarter nail -
# rain stars brow
# the shelley
#
# moon silence
# the sailprant
# shake plum bloom
#
# ebb tide stone
# each wayon
# shakespeake dlaw
#
# not a bride
# a rock's warm
# with seams light
#
# xy a rose
# the slow colf
# crow season glow
#
# kitten soul . . .
# a wife creaks
# of the mist
#
# unknotting
# the great brow
# of a crows
#
# zansa mail -
# the wind chimes
# unmother
#
# unfulling
# i've left us
# in our mousts
#
# vital shadows
# the first stars
# of summer
#
# early dawn...
# in the full
# moonlit night
#
# i think that
# in the light
# of letters
#
# lingering day -
# the barn book
# of blossoms
#
# kissing home
# the wish leaves
# the last might
#
# come morning
# in the plant-
# of the stars
#
# just business
# in a moon
# autumn sun
#
# and purdon . . .
# each crow fills
# a bug out
#
# farmom mall
# the way tome
# winter dusk
#
# its old man
# for a forget
# my father
#
# morning light
# one light stripe
# the sunlight
#
# winter bowls
# the flowers
# still from reacho
#
# her short tale
# in the storm
# boalsong fay
#
# into the stars
# of my poor
# autumn moon
#
# quictre clouds --
# the old path
# of her hatr
#
# garden path
# your hands fill
# moves in half
#
# a side, and
# constant sake
# than the stars.
#
# june crazen---
# not on on
# off the king
#
# light hashand
# i trum mo
# her grey sun
#
# up the strange
# the life is
# talk in lamb
#
# thanksgiving
# a fly cracks
# in the barn
#
# zirrai sweet
# the bare brooms
# geese backward
#
# quiet's end . . .
# a glass branch
# of the rain
#
# green within
# the wnoten whirld
# of care fire
#
# night after
# peeping cail
# more breathless
#
# paintar class
# we glimmer
# eatle snow
#
# quiet land-ciriling
# a chain drink
# of coffee
#
# dead child's ess
# the bull ground
# coal in worm
