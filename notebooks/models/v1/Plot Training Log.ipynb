# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('training_log.csv')
df
# Out:
#    epoch      loss  output_line_0_loss  output_line_1_loss  \
# 0      0  3.409218            1.064050            1.265532
# 1      1  1.943806            0.619642            0.724296
# 2      2  1.508640            0.481149            0.570137
# 3      3  1.317683            0.419871            0.500788
# 4      4  1.161887            0.370159            0.443572
# 5      5  1.016664            0.323609            0.389536
# 6      6  0.884197            0.281249            0.338470
# 7      7  0.769973            0.245769            0.293594
# 8      8  0.677885            0.217987            0.256488
# 9      9  0.607021            0.197935            0.227230
#
#    output_line_2_loss  val_loss  val_output_line_0_loss  \
# 0            1.079636  7.362709                1.352279
# 1            0.599868  1.922435                0.575843
# 2            0.457354  1.752615                0.525439
# 3            0.397023  1.719601                0.515174
# 4            0.348156  1.718698                0.518401
# 5            0.303519  1.769951                0.535983
# 6            0.264478  1.856679                0.561013
# 7            0.230611  1.933084                0.582824
# 8            0.203410  2.045130                0.613790
# 9            0.181856  2.136492                0.639025
#
#    val_output_line_1_loss  val_output_line_2_loss
# 0                2.304232                3.706198
# 1                0.799883                0.546708
# 2                0.731705                0.495470
# 3                0.722102                0.482325
# 4                0.720510                0.479787
# 5                0.745147                0.488820
# 6                0.777501                0.518165
# 7                0.815058                0.535202
# 8                0.863367                0.567973
# 9                0.906341                0.591126

# %%
figure, ax = plt.subplots(figsize=(16,8))
df.rename(columns={
    'loss': 'Training Loss', 'val_loss': 'Validation Loss'
}).plot('epoch', ['Training Loss', 'Validation Loss'], ax=ax)
ax.set_title('Training Loss and Validation Loss over Time (Lower is Better)')
ax.set_ylabel('Loss Value')
ax.set_xlabel('Epoch')
# Out:
# Text(0.5, 0, 'Epoch')
