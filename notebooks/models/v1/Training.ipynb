# %%
try:
    import keras
except:
    # !pip install keras
# Out:
# Using TensorFlow backend.

# %%
from pathlib import Path

import tensorflow as tf
tf_session = tf.Session()
from keras import backend as K
K.set_session(tf_session)

from keras.callbacks import ModelCheckpoint,  CSVLogger
from keras.layers import Add, Dense, Input, LSTM
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils

import numpy as np
import pandas as pd
from sklearn.externals import joblib

# Local library with model definitions for training and generating
from models import Generator, create_training_model

# %% [markdown]
# # Load Input

# %%
# Settings

# Percent of samples to use for training, might be necessary if you're running out of memory
sample_size = .05

# The latent dimension of the LSTM
latent_dim = 4

root_path = Path('../../..')
input_path = root_path / 'input'
poem_path = input_path / 'poems'
haiku_path = poem_path / 'haikus.csv'

output_dir = Path('all_data_test')
output_dir.mkdir()

# %%
df = pd.read_csv(str(haiku_path))
df = df.sample(frac=sample_size)
df
# Out:
#                                                         0  \
# 28137                              He damned the sun, and
# 101751                                Bitches be out here
# 56112                               That Fat Bastard wine
# 97737                                I'd swallow the moon
# 12730   in the market-place of bruges stands the belfr...
# 96802                                   It's important to
# 126889                               The less people know
# 717                                     Gandhi's birthday
# 137631                                   ashton irwin the
# 78872                                      isn't it crazy
# 87811                                   i just wanna know
# 3196                                          They share
# 81175                                     are we alive or
# 83302                              Brooklyn nine nine has
# 44664                               Don't expect too much
# 57046                             It's nice having strong
# 121960                                  Wallace road is a
# 6411                                                  see
# 105615                                      sakuma bro in
# 2796                                        steady rain~~
# 12317                                                   j
# 74123                                 Knowing how to deal
# 142008                                    Really debating
# 81421                                  Sir when in public
# 124061                              I glanced outside saw
# 67407                                  Liverpool have won
# 53312                               chris pine really has
# 58440                                  I really just want
# 21085                                      prairie stream
# 14467                                          lawrence j
# ...                                                   ...
# 137907                                  My favorite songs
# 84196                                 Almost stepped on a
# 103752                                 If someone doesn't
# 64532                                 Who wanna hear this
# 12481                                fair dreams farewell
# 80963                                  When I was younger
# 73427                                      Ranger v Astro
# 49768                                    Is find a rousey
# 3253                                       steam train...
# 19832                                   old car graveyard
# 63415                                 I am convinced that
# 24866                                 After the dispute -
# 103610                              Oh You should've just
# 38476                                     Whose available
# 22085                                         winter tide
# 105840                                  Did you even what
# 133445                                       Andy Polo is
# 36387                                    We said our last
# 25849                                  Bouquet of flowers
# 56545                                 Why are some people
# 62465                                 Feel like I'm doing
# 6617           poor little earthy house-inhabiting osiris
# 90520                                     I saw a sparrow
# 140555                              What is this snapchat
# 117474                          Scared your Twitter Crush
# 95575                                    I've never hated
# 73437                                   for the city that
# 90869                                    I'll be so happy
# 28737                                           While she
# 93965                                 The Hardest Part is
#
#                                                         1  \
# 28137                 he damned the stars, And he blasted
# 101751                         shameless Got me wondering
# 56112                             is really not very nice
# 97737                        and the stars just to follow
# 12730   thrice consumed and thrice rebuilded still it ...
# 96802                        realize that some things are
# 126889                          about me and my moves the
# 717                         constantly relighting candles
# 137631                      love you have for the fans is
# 78872                         that we now live in a world
# 87811                     what Ruth Bader Ginsburg thinks
# 3196                                      a bruised apple
# 81175                           are we dreaming after the
# 83302                              been bought out by NBC
# 44664                           Because expectations lead
# 57046                          people like you around Can
# 121960                            long road Rough idea of
# 6411              and confess one comfort still must rise
# 105615                            a pic together just two
# 2796                             she rants about her boss
# 12317                                                   g
# 74123                                      w you emotions
# 142008                          driving my mums car to go
# 81421                            life be humble otherwise
# 124061                          snow falling I considered
# 67407                      this season's Champions league
# 53312                           me watching outlaw king i
# 58440                       to practice and play baseball
# 21085                         what i know about mountains
# 14467   gomme: italy in arms by clinton scollard from ...
# ...                                                   ...
# 137907                               My favorite TV shows
# 84196                          scorpion with my bare feet
# 103752                           fucking pull out uno and
# 64532                            new wave of production i
# 12481                         so in life's stir and pride
# 80963                      I never thought eyebrows would
# 73427                      game at the end of march think
# 49768                               judo champion or just
# 3253                                   just over the wall
# 19832                              mama moves her kittens
# 63415                       fill in the blank PowerPoints
# 24866                                the plates are still
# 103610                         told me I'm always willing
# 38476                         for a short film today like
# 22085                                    an abalone shell
# 105840                     Star Wars was when you where a
# 133445                   start at Rentschler Field I'm so
# 36387                       goodbyes so let's just try to
# 25849                                Filed against a tree
# 56545                               so able to settle for
# 62465                       the right thing but I tend to
# 6617    the mysterious bull tore him at adolescence in...
# 90520                           At this hour tyrants burn
# 140555                       update What happened I don't
# 117474                       might see your answer You on
# 95575                                anyone in my life as
# 73437                        never sleeps it sure does do
# 90869                        when I don't have to wake up
# 28737                               danced I was crushing
# 93965                      forgetting those you swore you
#
#                                                         2       source  \
# 28137                               the winds in the sky.    gutenberg
# 101751                            where their parents are       twaiku
# 56112                                   Sour blackberries       twaiku
# 97737                              the beat of your heart       twaiku
# 12730                                                town    img2poems
# 96802                                 out of your control       twaiku
# 126889                                  better my life is       twaiku
# 717                                during the peace March  tempslibres
# 137631                                 so pure i love you       twaiku
# 78872                                where come on exists       twaiku
# 87811                                 about all this shit       twaiku
# 3196                                moonlit feast for two  tempslibres
# 81175                                ride are you leaving       twaiku
# 83302                              Life makes sense again       twaiku
# 44664                                  to disappointments       twaiku
# 57046                                we team up next time       twaiku
# 121960                                  termination point       twaiku
# 6411       'tis this: though man's a fool yet god is wise    img2poems
# 105615                                    of them finally       twaiku
# 2796                                   all through supper  tempslibres
# 12317                                            whittier    img2poems
# 74123                                 versus masking them       twaiku
# 142008                            get jade from her house       twaiku
# 81421                              you will get messed up       twaiku
# 124061                                    crying honestly       twaiku
# 67407                             just make peace with it       twaiku
# 53312                           stan the best white chris       twaiku
# 58440                               right now and I can't       twaiku
# 21085                               in these small stones      sballas
# 14467                                arms and other poems    img2poems
# ...                                                   ...          ...
# 137907                                   are never ending       twaiku
# 84196                                Not sleeping tonight       twaiku
# 103752                                make the best of it       twaiku
# 64532                                     got in the oven       twaiku
# 12481           you fade and leave the treasure of a tear    img2poems
# 80963                                   be this important       twaiku
# 73427                             it's time to make plans       twaiku
# 49768                             one worlds best fighter       twaiku
# 3253                            a winter-flowering cherry  tempslibres
# 19832                                    to the back seat      sballas
# 63415                                    are of the devil       twaiku
# 24866                                               dirty     haikuzao
# 103610                          to help with those things       twaiku
# 38476                                       available now       twaiku
# 22085                                   too deep to reach      sballas
# 105840                                  kid honest answer       twaiku
# 133445                               sad I can't be there       twaiku
# 36387                                 end it with a smile       twaiku
# 25849                                         In the rain     haikuzao
# 56545                                          mediocrity       twaiku
# 62465                                 second guess myself       twaiku
# 6617    and he must struggle after reconstruction igno...    img2poems
# 90520                                 Anger always pleads       twaiku
# 140555                                 think mine updated       twaiku
# 117474                           that stopped caring hoop       twaiku
# 95575                                  much as I hate you       twaiku
# 73437                                   a lot of sleeping       twaiku
# 90869                              and clock in somewhere       twaiku
# 28737                                         his throat.    gutenberg
# 93965                                  would never forget       twaiku
#
#        0_syllables 1_syllables 2_syllables
# 28137            5           8           5
# 101751           5           7           5
# 56112            5           7         4,5
# 97737            5           7           5
# 12730        13,14          15           1
# 96802            5           7           5
# 126889           5           7           5
# 717              4           8           5
# 137631           5           7           5
# 78872            5           7           5
# 87811            5           7           5
# 3196             2           4           5
# 81175            5           7           5
# 83302            5           7           5
# 44664            5           7           5
# 57046            5           7           5
# 121960           5           7           5
# 6411             1           9          10
# 105615           5           7           5
# 2796             3           6           4
# 12317            1           1           3
# 74123            5           7           5
# 142008           5           7           5
# 81421            5           7           5
# 124061           5           7           5
# 67407            5           7           5
# 53312            5           7           5
# 58440            5           7           5
# 21085            3           7           4
# 14467            3          16           6
# ...            ...         ...         ...
# 137907         4,5     8,9,6,7           5
# 84196            5           7           5
# 103752           5           7           5
# 64532            5           7           5
# 12481            4           6          10
# 80963            5           7           5
# 73427            5           7           5
# 49768            5           7           5
# 3253             2           5           5
# 19832            4           6           4
# 63415          5,6           7           5
# 24866            5           4           2
# 103610           5           7           5
# 38476            5           7           5
# 22085            3           6           4
# 105840           5           7           5
# 133445           5           7           5
# 36387          4,5           7           5
# 25849            5           5           3
# 56545            5           7           5
# 62465            5           7           5
# 6617             9          17          18
# 90520            5         6,7           5
# 140555           5           7           5
# 117474           5           7           5
# 95575            5           7           5
# 73437            5           7           5
# 90869            5           7           5
# 28737            2           5           2
# 93965            5           7           5
#
# [7157 rows x 7 columns]

# %% [markdown]
# # Format Input for Training

# %%
# Duplicate lines with ambiguous syllable counts
# (syllable counts where there is a comma because
# multiple pronounciations are acceptable)

lines = set([0, 1, 2])

for i in range(3):
    lines.remove(i)
    df = df[[
        '0', '1', '2',
        #'1_syllables', '2_syllables'
    ] + ['%s_syllables' % j for j in lines]].join(
        df['%s_syllables' % i].str.split(
            ',', expand=True
        ).stack(-1).reset_index(
            level=1, drop=True
        ).rename('%s_syllables' % i)
    ).drop_duplicates()
    lines.add(i)

df
# Out:
#                                      0                                    1  \
# 8                    misty summer rain                     calling pheasant
# 16                         nobody here              a table in the mountain
# 30                    smells of spring            adrift in the morning air
# 30                    smells of spring            adrift in the morning air
# 31                      Spring morning               your hand on my breast
# 31                      Spring morning               your hand on my breast
# 42                       folding chair               the newborn colt tries
# 58                        husband away                    washing his socks
# 91                     morning glories            find their way to the sun
# 91                     morning glories            find their way to the sun
# 94                         more rain -                        mildew colors
# 114                          the smell                    of many campfires
# 127                  deep in the night            my computer turned off --
# 128                        no more war                 two fighting beetles
# 179                           a teacup                              to fill
# 242             windswept afternoon---                            tea scent
# 255                  chirping birds --                  the instant I press
# 272              Last day of September               bay and islands in fog
# 301                    kitchen embrace                 the smell of her hot
# 302                   farewell embrace                      a faint essence
# 309                       Twin Towers-               where once two shadows
# 342                      On a grey day                     a spot of colour
# 360               new year's day . . .                 spent bottle-rockets
# 377                street light sway ~                 dreams of her linger
# 391                        coffee cold               she clips the obituary
# 466     my daughter's 18th birthday --                 the warming sunshine
# 497               yellow walnut leaves          slowly appear on the lawn--
# 529                    morning haze --                    ice drifts around
# 532                a bright morning --                   the mud pulls away
# 541                 the empty bench --                       spilled coffee
# ...                                ...                                  ...
# 142777                are we defending        the white race now oh no this
# 142806               okay but have you             seen Pedro Pascal with a
# 142813               I need someone to            fix my wig because I dead
# 142838              to the people with            the cooler PUT SOME WATER
# 142848           Baseball and softball          games today with Washington
# 142851            it's awful Paige you         don't wanna see the things I
# 142854                 Pero it doesn't             hurt me anymore like the
# 142857           loved her live update            from Brussels informative
# 142876                 Waking up early         just for the sake of the low
# 142894      There's some steps Firstly             you have to open Setting
# 142937               Was colder than a         well diggers ass back on the
# 142940            If people don't like       you for who you are change the
# 142977                   im so tired i              wanna take a nap before
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143024               Bullshit Any team             other than Saracens that
# 143026           they won't be student       athletes they will be dropouts
# 143041             When someone in the          same car as me waves i just
# 143042             Audrey keeps asking               me if we can go to the
# 143052                I get so annoyed               when this idiot is all
# 143060              I believe that was             a bit of the Marth in me
# 143064                 An old lady was             staring at me in the bus
# 143087               Rob having a rave              at a bus stop in County
# 143090                  my family woke             me up with miranda's new
# 143090                  my family woke             me up with miranda's new
# 143095               I have a headache              Why do Italians have to
# 143106               all possible wigs   are now gone dead snatched ducking
# 143135                is doing a great             job turning Independents
#
#                                 2 0_syllables 1_syllables 2_syllables
# 8                   in Zen temple           5           4           4
# 16           speckled with petals           4           7           5
# 30              bubbles under ice           3           7           5
# 30              bubbles under ice           4           7           5
# 31                         a bird           3           5           2
# 31                         a bird           4           5           2
# 42                       to stand           3           5           2
# 58                        by hand           4           4           2
# 91                 on barbed wire           4           6           3
# 91                 on barbed wire           4           6           4
# 94                   the old roof           2           4           3
# 114     in this old hunting shirt           2           6           6
# 127          sound of autumn rain           4           6           5
# 128                on a tombstone           3           5           4
# 179                  my afternoon           3           2           4
# 242                  on my tongue           5           2           3
# 255               the stop button           3           5           4
# 272               aroma of coffee           6           6           6
# 301                     apple pie           4           5           3
# 302                  of mothballs           4           4           3
# 309                  now only sun           3           5           4
# 342                  his red hair           4           5           3
# 360                   in the road           3           3           3
# 377                with the storm           3           5           3
# 391              from many papers           3           8           5
# 466                   in her hair           7           5           3
# 497           early morning light           5           7           5
# 529              the river stones           3           4           4
# 532           from a frosty stone           4           5           5
# 541                 turned to ice           4           3           3
# ...                           ...         ...         ...         ...
# 142777           is getting hairy           5           7           5
# 142806        lasso that shit hot           5           7           5
# 142813      don't know what to do           5           7           5
# 142838    IN THAT BITCH NEXT TIME           5           7           5
# 142848    Court House is canceled           5           7           5
# 142851        have to see up here           5           7           5
# 142854        way it hurts before           5           7           5
# 142857           and entertaining           5           7           5
# 142876           water supply ugh           5           7           5
# 142894            and go to Users           5           7           5
# 142937          mountain this a m           5           7           5
# 142940        people not yourself           5           7           5
# 142977          i gotta leave but           5           7           5
# 143015             only in theory           5           8           5
# 143015             only in theory           5           8           6
# 143015             only in theory           5           7           5
# 143015             only in theory           5           7           6
# 143024           try gets awarded           5           7           5
# 143026           following a fool           5           7           5
# 143041     slip them one of these           5           7           5
# 143042   beach and get fish crabs           5           7           5
# 143052           over my timeline           5           7           5
# 143060     that came out just now           5           7           5
# 143064    judging my ripped jeans           5           7           5
# 143087     Cork TUNES ARE BANGING           5           7           5
# 143090    thanksgiving song bless           4           7           5
# 143090    thanksgiving song bless           5           7           5
# 143095        be so damn loud for           5           7           5
# 143106                 eVAPORATED           5           7           5
# 143135             into Democrats           5           7           5
#
# [8613 rows x 6 columns]

# %%
# Drop samples that are longer that the 99th percentile of length

max_line_length = int(max([df['%s' % i].str.len().quantile(.99) for i in range(3)]))
df = df[
    (df['0'].str.len() <= max_line_length) & 
    (df['1'].str.len() <= max_line_length) & 
    (df['2'].str.len() <= max_line_length)
].copy()
df
# Out:
#                                      0                                    1  \
# 8                    misty summer rain                     calling pheasant
# 16                         nobody here              a table in the mountain
# 30                    smells of spring            adrift in the morning air
# 30                    smells of spring            adrift in the morning air
# 31                      Spring morning               your hand on my breast
# 31                      Spring morning               your hand on my breast
# 42                       folding chair               the newborn colt tries
# 58                        husband away                    washing his socks
# 91                     morning glories            find their way to the sun
# 91                     morning glories            find their way to the sun
# 94                         more rain -                        mildew colors
# 114                          the smell                    of many campfires
# 127                  deep in the night            my computer turned off --
# 128                        no more war                 two fighting beetles
# 179                           a teacup                              to fill
# 242             windswept afternoon---                            tea scent
# 255                  chirping birds --                  the instant I press
# 272              Last day of September               bay and islands in fog
# 301                    kitchen embrace                 the smell of her hot
# 302                   farewell embrace                      a faint essence
# 309                       Twin Towers-               where once two shadows
# 342                      On a grey day                     a spot of colour
# 360               new year's day . . .                 spent bottle-rockets
# 377                street light sway ~                 dreams of her linger
# 391                        coffee cold               she clips the obituary
# 466     my daughter's 18th birthday --                 the warming sunshine
# 497               yellow walnut leaves          slowly appear on the lawn--
# 529                    morning haze --                    ice drifts around
# 532                a bright morning --                   the mud pulls away
# 541                 the empty bench --                       spilled coffee
# ...                                ...                                  ...
# 142777                are we defending        the white race now oh no this
# 142806               okay but have you             seen Pedro Pascal with a
# 142813               I need someone to            fix my wig because I dead
# 142838              to the people with            the cooler PUT SOME WATER
# 142848           Baseball and softball          games today with Washington
# 142851            it's awful Paige you         don't wanna see the things I
# 142854                 Pero it doesn't             hurt me anymore like the
# 142857           loved her live update            from Brussels informative
# 142876                 Waking up early         just for the sake of the low
# 142894      There's some steps Firstly             you have to open Setting
# 142937               Was colder than a         well diggers ass back on the
# 142940            If people don't like       you for who you are change the
# 142977                   im so tired i              wanna take a nap before
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143024               Bullshit Any team             other than Saracens that
# 143026           they won't be student       athletes they will be dropouts
# 143041             When someone in the          same car as me waves i just
# 143042             Audrey keeps asking               me if we can go to the
# 143052                I get so annoyed               when this idiot is all
# 143060              I believe that was             a bit of the Marth in me
# 143064                 An old lady was             staring at me in the bus
# 143087               Rob having a rave              at a bus stop in County
# 143090                  my family woke             me up with miranda's new
# 143090                  my family woke             me up with miranda's new
# 143095               I have a headache              Why do Italians have to
# 143106               all possible wigs   are now gone dead snatched ducking
# 143135                is doing a great             job turning Independents
#
#                                 2 0_syllables 1_syllables 2_syllables
# 8                   in Zen temple           5           4           4
# 16           speckled with petals           4           7           5
# 30              bubbles under ice           3           7           5
# 30              bubbles under ice           4           7           5
# 31                         a bird           3           5           2
# 31                         a bird           4           5           2
# 42                       to stand           3           5           2
# 58                        by hand           4           4           2
# 91                 on barbed wire           4           6           3
# 91                 on barbed wire           4           6           4
# 94                   the old roof           2           4           3
# 114     in this old hunting shirt           2           6           6
# 127          sound of autumn rain           4           6           5
# 128                on a tombstone           3           5           4
# 179                  my afternoon           3           2           4
# 242                  on my tongue           5           2           3
# 255               the stop button           3           5           4
# 272               aroma of coffee           6           6           6
# 301                     apple pie           4           5           3
# 302                  of mothballs           4           4           3
# 309                  now only sun           3           5           4
# 342                  his red hair           4           5           3
# 360                   in the road           3           3           3
# 377                with the storm           3           5           3
# 391              from many papers           3           8           5
# 466                   in her hair           7           5           3
# 497           early morning light           5           7           5
# 529              the river stones           3           4           4
# 532           from a frosty stone           4           5           5
# 541                 turned to ice           4           3           3
# ...                           ...         ...         ...         ...
# 142777           is getting hairy           5           7           5
# 142806        lasso that shit hot           5           7           5
# 142813      don't know what to do           5           7           5
# 142838    IN THAT BITCH NEXT TIME           5           7           5
# 142848    Court House is canceled           5           7           5
# 142851        have to see up here           5           7           5
# 142854        way it hurts before           5           7           5
# 142857           and entertaining           5           7           5
# 142876           water supply ugh           5           7           5
# 142894            and go to Users           5           7           5
# 142937          mountain this a m           5           7           5
# 142940        people not yourself           5           7           5
# 142977          i gotta leave but           5           7           5
# 143015             only in theory           5           8           5
# 143015             only in theory           5           8           6
# 143015             only in theory           5           7           5
# 143015             only in theory           5           7           6
# 143024           try gets awarded           5           7           5
# 143026           following a fool           5           7           5
# 143041     slip them one of these           5           7           5
# 143042   beach and get fish crabs           5           7           5
# 143052           over my timeline           5           7           5
# 143060     that came out just now           5           7           5
# 143064    judging my ripped jeans           5           7           5
# 143087     Cork TUNES ARE BANGING           5           7           5
# 143090    thanksgiving song bless           4           7           5
# 143090    thanksgiving song bless           5           7           5
# 143095        be so damn loud for           5           7           5
# 143106                 eVAPORATED           5           7           5
# 143135             into Democrats           5           7           5
#
# [8475 rows x 6 columns]

# %%
# Pad the lines to the max line length with new lines
for i in range(3):
    # For input, duplicate the first character
    # TODO - Why?
    df['%s_in' % i] = (df[str(i)].str[0] + df[str(i)]).str.pad(max_line_length+2, 'right', '\n')
    
    # 
    #df['%s_out' % i] = df[str(i)].str.pad(max_line_len, 'right', '\n') + ('\n' if i == 2 else df[str(i+1)].str[0])
    
    # TODO - trying to add the next line's first character before the line breaks
    if i == 2: # If it's the last line
        df['%s_out' % i] = df[str(i)].str.pad(max_line_length+2, 'right', '\n')
    else: 
        # If it's the first or second line, add the first character of the next line to the end of this line.
        # This helps with training so that the next RNN has a better chance of getting the first character right.
        df['%s_out' % i] = (df[str(i)] + '\n' + df[str(i+1)].str[0]).str.pad(max_line_length+2, 'right', '\n')
    
max_line_length += 2

df
# Out:
#                                      0                                    1  \
# 8                    misty summer rain                     calling pheasant
# 16                         nobody here              a table in the mountain
# 30                    smells of spring            adrift in the morning air
# 30                    smells of spring            adrift in the morning air
# 31                      Spring morning               your hand on my breast
# 31                      Spring morning               your hand on my breast
# 42                       folding chair               the newborn colt tries
# 58                        husband away                    washing his socks
# 91                     morning glories            find their way to the sun
# 91                     morning glories            find their way to the sun
# 94                         more rain -                        mildew colors
# 114                          the smell                    of many campfires
# 127                  deep in the night            my computer turned off --
# 128                        no more war                 two fighting beetles
# 179                           a teacup                              to fill
# 242             windswept afternoon---                            tea scent
# 255                  chirping birds --                  the instant I press
# 272              Last day of September               bay and islands in fog
# 301                    kitchen embrace                 the smell of her hot
# 302                   farewell embrace                      a faint essence
# 309                       Twin Towers-               where once two shadows
# 342                      On a grey day                     a spot of colour
# 360               new year's day . . .                 spent bottle-rockets
# 377                street light sway ~                 dreams of her linger
# 391                        coffee cold               she clips the obituary
# 466     my daughter's 18th birthday --                 the warming sunshine
# 497               yellow walnut leaves          slowly appear on the lawn--
# 529                    morning haze --                    ice drifts around
# 532                a bright morning --                   the mud pulls away
# 541                 the empty bench --                       spilled coffee
# ...                                ...                                  ...
# 142777                are we defending        the white race now oh no this
# 142806               okay but have you             seen Pedro Pascal with a
# 142813               I need someone to            fix my wig because I dead
# 142838              to the people with            the cooler PUT SOME WATER
# 142848           Baseball and softball          games today with Washington
# 142851            it's awful Paige you         don't wanna see the things I
# 142854                 Pero it doesn't             hurt me anymore like the
# 142857           loved her live update            from Brussels informative
# 142876                 Waking up early         just for the sake of the low
# 142894      There's some steps Firstly             you have to open Setting
# 142937               Was colder than a         well diggers ass back on the
# 142940            If people don't like       you for who you are change the
# 142977                   im so tired i              wanna take a nap before
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143015           Summer's one of those          things I like in theory And
# 143024               Bullshit Any team             other than Saracens that
# 143026           they won't be student       athletes they will be dropouts
# 143041             When someone in the          same car as me waves i just
# 143042             Audrey keeps asking               me if we can go to the
# 143052                I get so annoyed               when this idiot is all
# 143060              I believe that was             a bit of the Marth in me
# 143064                 An old lady was             staring at me in the bus
# 143087               Rob having a rave              at a bus stop in County
# 143090                  my family woke             me up with miranda's new
# 143090                  my family woke             me up with miranda's new
# 143095               I have a headache              Why do Italians have to
# 143106               all possible wigs   are now gone dead snatched ducking
# 143135                is doing a great             job turning Independents
#
#                                 2 0_syllables 1_syllables 2_syllables  \
# 8                   in Zen temple           5           4           4
# 16           speckled with petals           4           7           5
# 30              bubbles under ice           3           7           5
# 30              bubbles under ice           4           7           5
# 31                         a bird           3           5           2
# 31                         a bird           4           5           2
# 42                       to stand           3           5           2
# 58                        by hand           4           4           2
# 91                 on barbed wire           4           6           3
# 91                 on barbed wire           4           6           4
# 94                   the old roof           2           4           3
# 114     in this old hunting shirt           2           6           6
# 127          sound of autumn rain           4           6           5
# 128                on a tombstone           3           5           4
# 179                  my afternoon           3           2           4
# 242                  on my tongue           5           2           3
# 255               the stop button           3           5           4
# 272               aroma of coffee           6           6           6
# 301                     apple pie           4           5           3
# 302                  of mothballs           4           4           3
# 309                  now only sun           3           5           4
# 342                  his red hair           4           5           3
# 360                   in the road           3           3           3
# 377                with the storm           3           5           3
# 391              from many papers           3           8           5
# 466                   in her hair           7           5           3
# 497           early morning light           5           7           5
# 529              the river stones           3           4           4
# 532           from a frosty stone           4           5           5
# 541                 turned to ice           4           3           3
# ...                           ...         ...         ...         ...
# 142777           is getting hairy           5           7           5
# 142806        lasso that shit hot           5           7           5
# 142813      don't know what to do           5           7           5
# 142838    IN THAT BITCH NEXT TIME           5           7           5
# 142848    Court House is canceled           5           7           5
# 142851        have to see up here           5           7           5
# 142854        way it hurts before           5           7           5
# 142857           and entertaining           5           7           5
# 142876           water supply ugh           5           7           5
# 142894            and go to Users           5           7           5
# 142937          mountain this a m           5           7           5
# 142940        people not yourself           5           7           5
# 142977          i gotta leave but           5           7           5
# 143015             only in theory           5           8           5
# 143015             only in theory           5           8           6
# 143015             only in theory           5           7           5
# 143015             only in theory           5           7           6
# 143024           try gets awarded           5           7           5
# 143026           following a fool           5           7           5
# 143041     slip them one of these           5           7           5
# 143042   beach and get fish crabs           5           7           5
# 143052           over my timeline           5           7           5
# 143060     that came out just now           5           7           5
# 143064    judging my ripped jeans           5           7           5
# 143087     Cork TUNES ARE BANGING           5           7           5
# 143090    thanksgiving song bless           4           7           5
# 143090    thanksgiving song bless           5           7           5
# 143095        be so damn loud for           5           7           5
# 143106                 eVAPORATED           5           7           5
# 143135             into Democrats           5           7           5
#
#                                                      0_in  \
# 8       mmisty summer rain\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      nnobody here\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 30      ssmells of spring\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 30      ssmells of spring\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      SSpring morning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      SSpring morning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 42      ffolding chair\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 58      hhusband away\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 91      mmorning glories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      mmorning glories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 94      mmore rain -\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 114     tthe smell\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 127     ddeep in the night\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 128     nno more war\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 179     aa teacup\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 242     wwindswept afternoon---\n\n\n\n\n\n\n\n\n\n\n\...
# 255     cchirping birds --\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 272     LLast day of September\n\n\n\n\n\n\n\n\n\n\n\n...
# 301     kkitchen embrace\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 302     ffarewell embrace\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 309     TTwin Towers-\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 342     OOn a grey day\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 360     nnew year's day . . .\n\n\n\n\n\n\n\n\n\n\n\n\...
# 377     sstreet light sway ~\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 391     ccoffee cold\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 466     mmy daughter's 18th birthday --\n\n\n\n\n\n\n\...
# 497     yyellow walnut leaves\n\n\n\n\n\n\n\n\n\n\n\n\...
# 529     mmorning haze --\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 532     aa bright morning --\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 541     tthe empty bench --\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 142777  aare we defending\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142806  ookay but have you\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142813  II need someone to\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142838  tto the people with\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142848  BBaseball and softball\n\n\n\n\n\n\n\n\n\n\n\n...
# 142851  iit's awful Paige you\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142854  PPero it doesn't\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142857  lloved her live update\n\n\n\n\n\n\n\n\n\n\n\n...
# 142876  WWaking up early\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142894  TThere's some steps Firstly\n\n\n\n\n\n\n\n\n\...
# 142937  WWas colder than a\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142940  IIf people don't like\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142977  iim so tired i\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  SSummer's one of those\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  SSummer's one of those\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  SSummer's one of those\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  SSummer's one of those\n\n\n\n\n\n\n\n\n\n\n\n...
# 143024  BBullshit Any team\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143026  tthey won't be student\n\n\n\n\n\n\n\n\n\n\n\n...
# 143041  WWhen someone in the\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143042  AAudrey keeps asking\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143052  II get so annoyed\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143060  II believe that was\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143064  AAn old lady was\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143087  RRob having a rave\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143090  mmy family woke\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143090  mmy family woke\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143095  II have a headache\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143106  aall possible wigs\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143135  iis doing a great\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                     0_out  \
# 8       misty summer rain\nc\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      nobody here\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 30      smells of spring\na\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 30      smells of spring\na\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      Spring morning\ny\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      Spring morning\ny\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 42      folding chair\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 58      husband away\nw\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 91      morning glories\nf\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      morning glories\nf\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 94      more rain -\nm\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 114     the smell\no\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 127     deep in the night\nm\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 128     no more war\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 179     a teacup\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 242     windswept afternoon---\nt\n\n\n\n\n\n\n\n\n\n\...
# 255     chirping birds --\nt\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 272     Last day of September\nb\n\n\n\n\n\n\n\n\n\n\n...
# 301     kitchen embrace\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 302     farewell embrace\na\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 309     Twin Towers-\nw\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 342     On a grey day\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 360     new year's day . . .\n \n\n\n\n\n\n\n\n\n\n\n\...
# 377     street light sway ~\nd\n\n\n\n\n\n\n\n\n\n\n\n...
# 391     coffee cold\ns\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 466     my daughter's 18th birthday --\nt\n\n\n\n\n\n\...
# 497     yellow walnut leaves\ns\n\n\n\n\n\n\n\n\n\n\n\...
# 529     morning haze --\ni\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 532     a bright morning --\nt\n\n\n\n\n\n\n\n\n\n\n\n...
# 541     the empty bench --\ns\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 142777  are we defending\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142806  okay but have you\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142813  I need someone to\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142838  to the people with\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 142848  Baseball and softball\n \n\n\n\n\n\n\n\n\n\n\n...
# 142851  it's awful Paige you\n \n\n\n\n\n\n\n\n\n\n\n\...
# 142854  Pero it doesn't\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142857  loved her live update\n \n\n\n\n\n\n\n\n\n\n\n...
# 142876  Waking up early\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142894  There's some steps Firstly\n \n\n\n\n\n\n\n\n\...
# 142937  Was colder than a\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142940  If people don't like\n \n\n\n\n\n\n\n\n\n\n\n\...
# 142977  im so tired i\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  Summer's one of those\n \n\n\n\n\n\n\n\n\n\n\n...
# 143015  Summer's one of those\n \n\n\n\n\n\n\n\n\n\n\n...
# 143015  Summer's one of those\n \n\n\n\n\n\n\n\n\n\n\n...
# 143015  Summer's one of those\n \n\n\n\n\n\n\n\n\n\n\n...
# 143024  Bullshit Any team\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143026  they won't be student\n \n\n\n\n\n\n\n\n\n\n\n...
# 143041  When someone in the\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143042  Audrey keeps asking\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143052  I get so annoyed\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143060  I believe that was\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143064  An old lady was\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143087  Rob having a rave\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143090  my family woke\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143090  my family woke\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143095  I have a headache\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143106  all possible wigs\n \n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143135  is doing a great\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                      1_in  \
# 8       ccalling pheasant\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 16      aa table in the mountain\n\n\n\n\n\n\n\n\n\n\n...
# 30      aadrift in the morning air\n\n\n\n\n\n\n\n\n\n...
# 30      aadrift in the morning air\n\n\n\n\n\n\n\n\n\n...
# 31      yyour hand on my breast\n\n\n\n\n\n\n\n\n\n\n\...
# 31      yyour hand on my breast\n\n\n\n\n\n\n\n\n\n\n\...
# 42      tthe newborn colt tries\n\n\n\n\n\n\n\n\n\n\n\...
# 58      wwashing his socks\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      ffind their way to the sun\n\n\n\n\n\n\n\n\n\n...
# 91      ffind their way to the sun\n\n\n\n\n\n\n\n\n\n...
# 94      mmildew colors\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 114     oof many campfires\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 127     mmy computer turned off --\n\n\n\n\n\n\n\n\n\n...
# 128     ttwo fighting beetles\n\n\n\n\n\n\n\n\n\n\n\n\...
# 179     tto fill\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 242     ttea scent\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 255     tthe instant I press\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 272     bbay and islands in fog\n\n\n\n\n\n\n\n\n\n\n\...
# 301     tthe smell of her hot\n\n\n\n\n\n\n\n\n\n\n\n\...
# 302     aa faint essence\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 309     wwhere once two shadows\n\n\n\n\n\n\n\n\n\n\n\...
# 342     aa spot of colour\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 360           spent bottle-rockets\n\n\n\n\n\n\n\n\n\n...
# 377     ddreams of her linger\n\n\n\n\n\n\n\n\n\n\n\n\...
# 391     sshe clips the obituary\n\n\n\n\n\n\n\n\n\n\n\...
# 466     tthe warming sunshine\n\n\n\n\n\n\n\n\n\n\n\n\...
# 497     sslowly appear on the lawn--\n\n\n\n\n\n\n\n\n...
# 529     iice drifts around\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 532     tthe mud pulls away\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 541     sspilled coffee\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 142777    the white race now oh no this\n\n\n\n\n\n\n\...
# 142806    seen Pedro Pascal with a\n\n\n\n\n\n\n\n\n\n...
# 142813    fix my wig because I dead\n\n\n\n\n\n\n\n\n\...
# 142838    the cooler PUT SOME WATER\n\n\n\n\n\n\n\n\n\...
# 142848    games today with Washington\n\n\n\n\n\n\n\n\...
# 142851    don't wanna see the things I\n\n\n\n\n\n\n\n...
# 142854    hurt me anymore like the\n\n\n\n\n\n\n\n\n\n...
# 142857    from Brussels informative\n\n\n\n\n\n\n\n\n\...
# 142876    just for the sake of the low\n\n\n\n\n\n\n\n...
# 142894    you have to open Setting\n\n\n\n\n\n\n\n\n\n...
# 142937    well diggers ass back on the\n\n\n\n\n\n\n\n...
# 142940    you for who you are change the\n\n\n\n\n\n\n...
# 142977    wanna take a nap before\n\n\n\n\n\n\n\n\n\n\...
# 143015    things I like in theory And\n\n\n\n\n\n\n\n\...
# 143015    things I like in theory And\n\n\n\n\n\n\n\n\...
# 143015    things I like in theory And\n\n\n\n\n\n\n\n\...
# 143015    things I like in theory And\n\n\n\n\n\n\n\n\...
# 143024    other than Saracens that\n\n\n\n\n\n\n\n\n\n...
# 143026    athletes they will be dropouts\n\n\n\n\n\n\n...
# 143041    same car as me waves i just\n\n\n\n\n\n\n\n\...
# 143042    me if we can go to the\n\n\n\n\n\n\n\n\n\n\n...
# 143052    when this idiot is all\n\n\n\n\n\n\n\n\n\n\n...
# 143060    a bit of the Marth in me\n\n\n\n\n\n\n\n\n\n...
# 143064    staring at me in the bus\n\n\n\n\n\n\n\n\n\n...
# 143087    at a bus stop in County\n\n\n\n\n\n\n\n\n\n\...
# 143090    me up with miranda's new\n\n\n\n\n\n\n\n\n\n...
# 143090    me up with miranda's new\n\n\n\n\n\n\n\n\n\n...
# 143095    Why do Italians have to\n\n\n\n\n\n\n\n\n\n\...
# 143106    are now gone dead snatched ducking\n\n\n\n\n...
# 143135    job turning Independents\n\n\n\n\n\n\n\n\n\n...
#
#                                                     1_out  \
# 8       calling pheasant\ni\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 16      a table in the mountain\ns\n\n\n\n\n\n\n\n\n\n...
# 30      adrift in the morning air\nb\n\n\n\n\n\n\n\n\n...
# 30      adrift in the morning air\nb\n\n\n\n\n\n\n\n\n...
# 31      your hand on my breast\na\n\n\n\n\n\n\n\n\n\n\...
# 31      your hand on my breast\na\n\n\n\n\n\n\n\n\n\n\...
# 42      the newborn colt tries\nt\n\n\n\n\n\n\n\n\n\n\...
# 58      washing his socks\nb\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      find their way to the sun\no\n\n\n\n\n\n\n\n\n...
# 91      find their way to the sun\no\n\n\n\n\n\n\n\n\n...
# 94      mildew colors\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 114     of many campfires\ni\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 127     my computer turned off --\ns\n\n\n\n\n\n\n\n\n...
# 128     two fighting beetles\no\n\n\n\n\n\n\n\n\n\n\n\...
# 179     to fill\nm\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 242     tea scent\no\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 255     the instant I press\nt\n\n\n\n\n\n\n\n\n\n\n\n...
# 272     bay and islands in fog\na\n\n\n\n\n\n\n\n\n\n\...
# 301     the smell of her hot\na\n\n\n\n\n\n\n\n\n\n\n\...
# 302     a faint essence\no\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 309     where once two shadows\nn\n\n\n\n\n\n\n\n\n\n\...
# 342     a spot of colour\nh\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 360          spent bottle-rockets\n \n\n\n\n\n\n\n\n\n...
# 377     dreams of her linger\nw\n\n\n\n\n\n\n\n\n\n\n\...
# 391     she clips the obituary\nf\n\n\n\n\n\n\n\n\n\n\...
# 466     the warming sunshine\ni\n\n\n\n\n\n\n\n\n\n\n\...
# 497     slowly appear on the lawn--\ne\n\n\n\n\n\n\n\n...
# 529     ice drifts around\nt\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 532     the mud pulls away\nf\n\n\n\n\n\n\n\n\n\n\n\n\...
# 541     spilled coffee\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 142777   the white race now oh no this\ni\n\n\n\n\n\n\...
# 142806   seen Pedro Pascal with a\nl\n\n\n\n\n\n\n\n\n...
# 142813   fix my wig because I dead\nd\n\n\n\n\n\n\n\n\...
# 142838   the cooler PUT SOME WATER\nI\n\n\n\n\n\n\n\n\...
# 142848   games today with Washington\nC\n\n\n\n\n\n\n\...
# 142851   don't wanna see the things I\nh\n\n\n\n\n\n\n...
# 142854   hurt me anymore like the\nw\n\n\n\n\n\n\n\n\n...
# 142857   from Brussels informative\na\n\n\n\n\n\n\n\n\...
# 142876   just for the sake of the low\nw\n\n\n\n\n\n\n...
# 142894   you have to open Setting\na\n\n\n\n\n\n\n\n\n...
# 142937   well diggers ass back on the\nm\n\n\n\n\n\n\n...
# 142940   you for who you are change the\np\n\n\n\n\n\n...
# 142977   wanna take a nap before\ni\n\n\n\n\n\n\n\n\n\...
# 143015   things I like in theory And\no\n\n\n\n\n\n\n\...
# 143015   things I like in theory And\no\n\n\n\n\n\n\n\...
# 143015   things I like in theory And\no\n\n\n\n\n\n\n\...
# 143015   things I like in theory And\no\n\n\n\n\n\n\n\...
# 143024   other than Saracens that\nt\n\n\n\n\n\n\n\n\n...
# 143026   athletes they will be dropouts\nf\n\n\n\n\n\n...
# 143041   same car as me waves i just\ns\n\n\n\n\n\n\n\...
# 143042   me if we can go to the\nb\n\n\n\n\n\n\n\n\n\n...
# 143052   when this idiot is all\no\n\n\n\n\n\n\n\n\n\n...
# 143060   a bit of the Marth in me\nt\n\n\n\n\n\n\n\n\n...
# 143064   staring at me in the bus\nj\n\n\n\n\n\n\n\n\n...
# 143087   at a bus stop in County\nC\n\n\n\n\n\n\n\n\n\...
# 143090   me up with miranda's new\nt\n\n\n\n\n\n\n\n\n...
# 143090   me up with miranda's new\nt\n\n\n\n\n\n\n\n\n...
# 143095   Why do Italians have to\nb\n\n\n\n\n\n\n\n\n\...
# 143106   are now gone dead snatched ducking\ne\n\n\n\n...
# 143135   job turning Independents\ni\n\n\n\n\n\n\n\n\n...
#
#                                                      2_in  \
# 8       iin Zen temple\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      sspeckled with petals\n\n\n\n\n\n\n\n\n\n\n\n\...
# 30      bbubbles under ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 30      bbubbles under ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 31      aa bird\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      aa bird\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 42      tto stand\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 58      bby hand\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      oon barbed wire\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 91      oon barbed wire\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 94      tthe old roof\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 114     iin this old hunting shirt\n\n\n\n\n\n\n\n\n\n...
# 127     ssound of autumn rain\n\n\n\n\n\n\n\n\n\n\n\n\...
# 128     oon a tombstone\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 179     mmy afternoon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 242     oon my tongue\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 255     tthe stop button\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 272     aaroma of coffee\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 301     aapple pie\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 302     oof mothballs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 309     nnow only sun\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 342     hhis red hair\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 360                 in the road\n\n\n\n\n\n\n\n\n\n\n\...
# 377     wwith the storm\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 391     ffrom many papers\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 466     iin her hair\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 497     eearly morning light\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 529     tthe river stones\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 532     ffrom a frosty stone\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 541     tturned to ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 142777  iis getting hairy\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142806  llasso that shit hot\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142813  ddon't know what to do\n\n\n\n\n\n\n\n\n\n\n\n...
# 142838  IIN THAT BITCH NEXT TIME\n\n\n\n\n\n\n\n\n\n\n...
# 142848  CCourt House is canceled\n\n\n\n\n\n\n\n\n\n\n...
# 142851  hhave to see up here\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142854  wway it hurts before\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142857  aand entertaining\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142876  wwater supply ugh\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142894  aand go to Users\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142937  mmountain this a m\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142940  ppeople not yourself\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142977  ii gotta leave but\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  oonly in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143015  oonly in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143015  oonly in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143015  oonly in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143024  ttry gets awarded\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143026  ffollowing a fool\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143041  sslip them one of these\n\n\n\n\n\n\n\n\n\n\n\...
# 143042  bbeach and get fish crabs\n\n\n\n\n\n\n\n\n\n\...
# 143052  oover my timeline\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143060  tthat came out just now\n\n\n\n\n\n\n\n\n\n\n\...
# 143064  jjudging my ripped jeans\n\n\n\n\n\n\n\n\n\n\n...
# 143087  CCork TUNES ARE BANGING\n\n\n\n\n\n\n\n\n\n\n\...
# 143090  tthanksgiving song bless\n\n\n\n\n\n\n\n\n\n\n...
# 143090  tthanksgiving song bless\n\n\n\n\n\n\n\n\n\n\n...
# 143095  bbe so damn loud for\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143106  eeVAPORATED\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143135  iinto Democrats\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                     2_out
# 8       in Zen temple\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 16      speckled with petals\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 30      bubbles under ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 30      bubbles under ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 31      a bird\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 31      a bird\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 42      to stand\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 58      by hand\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 91      on barbed wire\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 91      on barbed wire\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 94      the old roof\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 114     in this old hunting shirt\n\n\n\n\n\n\n\n\n\n\...
# 127     sound of autumn rain\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 128     on a tombstone\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 179     my afternoon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 242     on my tongue\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 255     the stop button\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 272     aroma of coffee\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 301     apple pie\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 302     of mothballs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 309     now only sun\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 342     his red hair\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 360                in the road\n\n\n\n\n\n\n\n\n\n\n\n...
# 377     with the storm\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 391     from many papers\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 466     in her hair\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 497     early morning light\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 529     the river stones\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 532     from a frosty stone\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 541     turned to ice\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 142777  is getting hairy\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142806  lasso that shit hot\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142813  don't know what to do\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142838  IN THAT BITCH NEXT TIME\n\n\n\n\n\n\n\n\n\n\n\...
# 142848  Court House is canceled\n\n\n\n\n\n\n\n\n\n\n\...
# 142851  have to see up here\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142854  way it hurts before\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142857  and entertaining\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142876  water supply ugh\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 142894  and go to Users\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142937  mountain this a m\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142940  people not yourself\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 142977  i gotta leave but\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143015  only in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  only in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  only in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143015  only in theory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143024  try gets awarded\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143026  following a fool\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143041  slip them one of these\n\n\n\n\n\n\n\n\n\n\n\n...
# 143042  beach and get fish crabs\n\n\n\n\n\n\n\n\n\n\n...
# 143052  over my timeline\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143060  that came out just now\n\n\n\n\n\n\n\n\n\n\n\n...
# 143064  judging my ripped jeans\n\n\n\n\n\n\n\n\n\n\n\...
# 143087  Cork TUNES ARE BANGING\n\n\n\n\n\n\n\n\n\n\n\n...
# 143090  thanksgiving song bless\n\n\n\n\n\n\n\n\n\n\n\...
# 143090  thanksgiving song bless\n\n\n\n\n\n\n\n\n\n\n\...
# 143095  be so damn loud for\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143106  eVAPORATED\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143135  into Democrats\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
#
# [8475 rows x 12 columns]

# %%
inputs = df[['0_in', '1_in', '2_in']].values

tokenizer = Tokenizer(filters='', char_level=True)
tokenizer.fit_on_texts(inputs.flatten())
n_tokens = len(tokenizer.word_counts) + 1

# X is the input for each line in sequences of one-hot-encoded values
X = np_utils.to_categorical([
    tokenizer.texts_to_sequences(inputs[:,i]) for i in range(3)
], num_classes=n_tokens)

outputs = df[['0_out', '1_out', '2_out']].values

# Y is the output for each line in sequences of one-hot-encoded values
Y = np_utils.to_categorical([
    tokenizer.texts_to_sequences(outputs[:,i]) for i in range(3)
], num_classes=n_tokens)

# X_syllables is the count of syllables for each line
X_syllables = df[['0_syllables', '1_syllables', '2_syllables']].values

# %%
joblib.dump([latent_dim, n_tokens, max_line_length, tokenizer], str(output_dir / 'metadata.pkl'))
# Out:
# ['all_data_test/metadata.pkl']

# %% [markdown]
# # Training Model

# %%
training_model, lstm, lines, inputs, outputs = create_training_model(latent_dim, n_tokens)

filepath = str(output_dir / ("%s-{epoch:02d}-{val_loss:.2f}.hdf5" % latent_dim))
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

csv_logger = CSVLogger(str(output_dir / 'training_log.csv'), append=True, separator=',')

callbacks_list = [checkpoint, csv_logger]

training_model.fit([
    X[0], X_syllables[:,0], 
    X[1], X_syllables[:,1], 
    X[2], X_syllables[:,2]
], [Y[0], Y[1], Y[2]], batch_size=64, epochs=1000, validation_split=.1, callbacks=callbacks_list)
# Out:
# Train on 7627 samples, validate on 848 samples
# Epoch 1/1000
# 7627/7627 [==============================] - 17s 2ms/step - loss: 11.9142 - output_line_0_loss: 3.9937 - output_line_1_loss: 4.0066 - output_line_2_loss: 3.9138 - val_loss: 11.0474 - val_output_line_0_loss: 3.7049 - val_output_line_1_loss: 3.7780 - val_output_line_2_loss: 3.5645
#
# Epoch 00001: val_loss improved from inf to 11.04745, saving model to all_data_test/4-01-11.05.hdf5
# /home/docmario/miniconda3/envs/haiku/lib/python3.6/site-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'syllable_dense_line_0/Relu:0' shape=(?, 4) dtype=float32>, <tf.Tensor 'syllable_dense_line_0/Relu:0' shape=(?, 4) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# /home/docmario/miniconda3/envs/haiku/lib/python3.6/site-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'add_h_line_1/add:0' shape=(?, 4) dtype=float32>, <tf.Tensor 'add_c_line_1/add:0' shape=(?, 4) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# /home/docmario/miniconda3/envs/haiku/lib/python3.6/site-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'add_h_line_2/add:0' shape=(?, 4) dtype=float32>, <tf.Tensor 'add_c_line_2/add:0' shape=(?, 4) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# Epoch 2/1000
# 7627/7627 [==============================] - 15s 2ms/step - loss: 9.9088 - output_line_0_loss: 3.3111 - output_line_1_loss: 3.4329 - output_line_2_loss: 3.1648 - val_loss: 8.7653 - val_output_line_0_loss: 2.9016 - val_output_line_1_loss: 3.1132 - val_output_line_2_loss: 2.7505
#
# Epoch 00002: val_loss improved from 11.04745 to 8.76530, saving model to all_data_test/4-02-8.77.hdf5
# Epoch 3/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 7.7647 - output_line_0_loss: 2.5495 - output_line_1_loss: 2.7979 - output_line_2_loss: 2.4173 - val_loss: 6.6563 - val_output_line_0_loss: 2.1334 - val_output_line_1_loss: 2.5057 - val_output_line_2_loss: 2.0172
#
# Epoch 00003: val_loss improved from 8.76530 to 6.65627, saving model to all_data_test/4-03-6.66.hdf5
# Epoch 4/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 5.9554 - output_line_0_loss: 1.8858 - output_line_1_loss: 2.2621 - output_line_2_loss: 1.8075 - val_loss: 5.2441 - val_output_line_0_loss: 1.6079 - val_output_line_1_loss: 2.0801 - val_output_line_2_loss: 1.5561
#
# Epoch 00004: val_loss improved from 6.65627 to 5.24409, saving model to all_data_test/4-04-5.24.hdf5
# Epoch 5/1000
# 7627/7627 [==============================] - 15s 2ms/step - loss: 4.8783 - output_line_0_loss: 1.4910 - output_line_1_loss: 1.9189 - output_line_2_loss: 1.4684 - val_loss: 4.4503 - val_output_line_0_loss: 1.3228 - val_output_line_1_loss: 1.8233 - val_output_line_2_loss: 1.3042
#
# Epoch 00005: val_loss improved from 5.24409 to 4.45031, saving model to all_data_test/4-05-4.45.hdf5
# Epoch 6/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 4.3021 - output_line_0_loss: 1.2875 - output_line_1_loss: 1.7276 - output_line_2_loss: 1.2871 - val_loss: 4.0226 - val_output_line_0_loss: 1.1737 - val_output_line_1_loss: 1.6751 - val_output_line_2_loss: 1.1738
#
# Epoch 00006: val_loss improved from 4.45031 to 4.02260, saving model to all_data_test/4-06-4.02.hdf5
# Epoch 7/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 3.9610 - output_line_0_loss: 1.1700 - output_line_1_loss: 1.6107 - output_line_2_loss: 1.1804 - val_loss: 3.7606 - val_output_line_0_loss: 1.0842 - val_output_line_1_loss: 1.5849 - val_output_line_2_loss: 1.0915
#
# Epoch 00007: val_loss improved from 4.02260 to 3.76061, saving model to all_data_test/4-07-3.76.hdf5
# Epoch 8/1000
# 7627/7627 [==============================] - 16s 2ms/step - loss: 3.7537 - output_line_0_loss: 1.1025 - output_line_1_loss: 1.5392 - output_line_2_loss: 1.1119 - val_loss: 3.6065 - val_output_line_0_loss: 1.0339 - val_output_line_1_loss: 1.5344 - val_output_line_2_loss: 1.0382
#
# Epoch 00008: val_loss improved from 3.76061 to 3.60654, saving model to all_data_test/4-08-3.61.hdf5
# Epoch 9/1000
# 7627/7627 [==============================] - 16s 2ms/step - loss: 3.6357 - output_line_0_loss: 1.0650 - output_line_1_loss: 1.4998 - output_line_2_loss: 1.0710 - val_loss: 3.5180 - val_output_line_0_loss: 1.0040 - val_output_line_1_loss: 1.5056 - val_output_line_2_loss: 1.0085
#
# Epoch 00009: val_loss improved from 3.60654 to 3.51804, saving model to all_data_test/4-09-3.52.hdf5
# Epoch 10/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 3.5643 - output_line_0_loss: 1.0422 - output_line_1_loss: 1.4764 - output_line_2_loss: 1.0457 - val_loss: 3.4641 - val_output_line_0_loss: 0.9863 - val_output_line_1_loss: 1.4879 - val_output_line_2_loss: 0.9899
#
# Epoch 00010: val_loss improved from 3.51804 to 3.46414, saving model to all_data_test/4-10-3.46.hdf5
# Epoch 11/1000
# 7627/7627 [==============================] - 15s 2ms/step - loss: 3.5151 - output_line_0_loss: 1.0270 - output_line_1_loss: 1.4603 - output_line_2_loss: 1.0278 - val_loss: 3.4197 - val_output_line_0_loss: 0.9706 - val_output_line_1_loss: 1.4721 - val_output_line_2_loss: 0.9770
#
# Epoch 00011: val_loss improved from 3.46414 to 3.41975, saving model to all_data_test/4-11-3.42.hdf5
# Epoch 12/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 3.4784 - output_line_0_loss: 1.0157 - output_line_1_loss: 1.4474 - output_line_2_loss: 1.0153 - val_loss: 3.3884 - val_output_line_0_loss: 0.9613 - val_output_line_1_loss: 1.4606 - val_output_line_2_loss: 0.9665
#
# Epoch 00012: val_loss improved from 3.41975 to 3.38839, saving model to all_data_test/4-12-3.39.hdf5
# Epoch 13/1000
# 7627/7627 [==============================] - 14s 2ms/step - loss: 3.4490 - output_line_0_loss: 1.0068 - output_line_1_loss: 1.4362 - output_line_2_loss: 1.0059 - val_loss: 3.3589 - val_output_line_0_loss: 0.9516 - val_output_line_1_loss: 1.4492 - val_output_line_2_loss: 0.9581
#
# Epoch 00013: val_loss improved from 3.38839 to 3.35885, saving model to all_data_test/4-13-3.36.hdf5
# Epoch 14/1000
# 7040/7627 [==========================>...] - ETA: 1s - loss: 3.4196 - output_line_0_loss: 0.9979 - output_line_1_loss: 1.4246 - output_line_2_loss: 0.9971

# %% [markdown]
# # Test Model

# %%
generator = Generator(lstm, lines, tf_session, tokenizer, n_tokens, max_line_len)

# %%
generator.generate_haiku()
# Out:
# ho the the the thes the
# he the the the the the the the the the the
# the the the the the the the the the
# ['ho the the the thes the',
#  'he the the the the the the the the the the',
#  'the the the the the the the the the']
