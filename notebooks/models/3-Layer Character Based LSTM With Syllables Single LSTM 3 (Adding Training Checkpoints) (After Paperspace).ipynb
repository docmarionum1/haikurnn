# %%
try:
    import keras
except:
    # !pip install keras
# Out:
# Using TensorFlow backend.

# %%
from pathlib import Path

import tensorflow as tf
tf_session = tf.Session()
from keras import backend as K
K.set_session(tf_session)

from keras.callbacks import ModelCheckpoint
from keras.layers import Add, Dense, Input, LSTM
from keras.models import Model
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils

import numpy as np
import pandas as pd

# %% [markdown]
# # Load Input

# %%
output_dir = Path('all_data')
output_dir.mkdir()
root_path = Path('../..')
input_path = root_path / 'input'
poem_path = input_path / 'poems'
haiku_path = poem_path / 'haikus.csv'

# %%
df = pd.read_csv(str(haiku_path))
df
# Out:
#                                    0                                 1  \
# 0                    Memorial Day --                 a shadow for each
# 1                      spring rain -              as the doctor speaks
# 2                  spring moonset --                   a rice ball for
# 3                    sunny afternoon                an old man lingers
# 4                      cinco de mayo                       horses roll
# 5                      quitting time                 the smell of rain
# 6                              waves     slowly cresting towards shore
# 7                  overnight rain --      the scent of orange blossoms
# 8                  misty summer rain                  calling pheasant
# 9                        day is done                    poppies amidst
# 10                   watching clouds                  the white petals
# 11                   mountain stream             two well placed rocks
# 12                     night shift--     in the parking lot car lights
# 13                     a wild violet                on the sunny hill~
# 14                       a sunny day  pink haze of the cherry blossoms
# 15                   polished oak --         the freesia's shadow ends
# 16                       nobody here           a table in the mountain
# 17                        first date                 not even noticing
# 18        vanishing difference . . .         gliding geese settle onto
# 19                      distant hawk           a gust of cherry petals
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 21                    moonlessness--                      so many ways
# 22                       earth day--          even the shadows at dusk
# 23                         so cold -             a goose honks its way
# 24                  damp straw . . .       the day-old colt mesmerized
# 25                            prying               at the window . . .
# 26                  in winter's wind              the call of a friend
# 27                     rainy bridge-                 the river flowing
# 28                    spring breeze-             the balcony's shadows
# 29                    winter drizzle        all the passing faces look
# ...                              ...                               ...
# 143107            Everything happens           for a reason Only thing
# 143108            what Are you gonna   pull a George Bush and bust out
# 143109              Only a broke ass      or a spoiled fuck nugget can
# 143110         Perfect What business          is supposed to be Pay to
# 143111            I wish really wish        I get proven wrong tho But
# 143112              Would be amazing         to see the players on the
# 143113         Fireworks Tonight How       many times are these people
# 143114            he's not okay this        man is not in a good place
# 143115           My dad's okay Thank        god he didn't get murdered
# 143116               being faded and             listening to music is
# 143117                 Am I the only      person that thinks Ace has a
# 143118           One fucking comment         and my mood is ruined for
# 143119        Are you really friends      if you don't text each other
# 143120              Someone is upset      their team isn't winning the
# 143121            There's no casinos           in Texas but I can walk
# 143122           The write in Mickey    Mouse probably could have been
# 143123            It's the beginning              of October and it is
# 143124           People really don't        be having shit else better
# 143125           newt muttering this    is the worst while looking for
# 143126                I'm so excited      for the tour are y'all going
# 143127            Today is the first        day of the rest of my LIFE
# 143128              If you follow me       sure I will follow you back
# 143129              I really have no           life anymore my head is
# 143130              Honestly the kit         isn't that bad The collar
# 143131              an authorship is              a skein alphanumeric
# 143132            I'm not asking did            you say it nor clarify
# 143133               You are truly a               moron or a liar I'm
# 143134            Ain't no selfie on   this earth that's gonna make me
# 143135              is doing a great          job turning Independents
# 143136              Wanted to send a         quick follow up on if the
#
#                               2       source 0_syllables 1_syllables  \
# 0                   white cross  tempslibres           5           5
# 1             i think of lilacs  tempslibres         2,3           5
# 2                     breakfast  tempslibres         3,4           4
# 3              near the mailbox  tempslibres           5           5
# 4               in the shallows  tempslibres           5           3
# 5                  in the lobby  tempslibres           3           4
# 6                  a faint moon  tempslibres           1         6,7
# 7              in a desert town  tempslibres           4           7
# 8                 in Zen temple  tempslibres           5           4
# 9               the dying grass  tempslibres           3           4
# 10          of a crushed crocus  tempslibres           3           4
# 11                the path home  tempslibres           3           4
# 12             dim near morning  tempslibres           2           7
# 13                noon time nap  tempslibres         4,5           5
# 14                over the hill  tempslibres           4           8
# 15               in coffee foam  tempslibres           3           7
# 16         speckled with petals  tempslibres           4           7
# 17                 the new moon  tempslibres           2           6
# 18            their reflections  tempslibres         5,6           7
# 19             crosses the lawn  tempslibres           3           7
# 20         Life support machine  tempslibres           6         8,7
# 21          I want to touch you  tempslibres           3           4
# 22                  smell green  tempslibres           2           7
# 23         across the night sky  tempslibres           2           5
# 24                 by the radio  tempslibres           2           6
# 25                         wind  tempslibres           2           4
# 26           who now has cancer  tempslibres           4           5
# 27                       faster  tempslibres           3           5
# 28                   on my book  tempslibres         2,3           6
# 29                into the cafe  tempslibres           4           7
# ...                         ...          ...         ...         ...
# 143107         keeping me going       twaiku           5           7
# 143108        a weather machine       twaiku           5           7
# 143109    give you ALL his time       twaiku           5           7
# 143110   play Things cost money       twaiku           5           7
# 143111    the chances seem slim       twaiku           5           7
# 143112     bench joining in too       twaiku           5           7
# 143113           being ignorant       twaiku           5           7
# 143114        mentally speaking       twaiku           5           7
# 143115          in a back alley       twaiku           5         6,7
# 143116        my favorite thing       twaiku           5         6,7
# 143117    really high skill cap       twaiku         5,6           7
# 143118      the rest of the day       twaiku           5           7
# 143119   that you got home safe       twaiku           5           7
# 143120     Super Bowl this year       twaiku           5           7
# 143121        around with a gun       twaiku           5           7
# 143122      president this time       twaiku           5         6,7
# 143123          already snowing       twaiku           5           7
# 143124    to do with their time       twaiku           5           7
# 143125     his glasses big mood       twaiku           5           7
# 143126       to be meeting fans       twaiku           5           7
# 143127       and YES it MATTERS       twaiku           5           7
# 143128        this is a promise       twaiku           5           7
# 143129       always in my books       twaiku           5           7
# 143130       is terrible though       twaiku           5           7
# 143131        and story telling       twaiku           5           7
# 143132    what you said neither       twaiku           5           7
# 143133   inclined to think both       twaiku           5           7
# 143134         like Theresa May       twaiku           5           7
# 143135           into Democrats       twaiku           5           7
# 143136  blood is loud Talk soon       twaiku           5           7
#
#        2_syllables
# 0                2
# 1                5
# 2                2
# 3                4
# 4                4
# 5                4
# 6                3
# 7                5
# 8                4
# 9                4
# 10               5
# 11               3
# 12               4
# 13               3
# 14               4
# 15               4
# 16               5
# 17               3
# 18               4
# 19               4
# 20               5
# 21               5
# 22               2
# 23               5
# 24               5
# 25               1
# 26               5
# 27               2
# 28               3
# 29               5
# ...            ...
# 143107           5
# 143108           5
# 143109           5
# 143110           5
# 143111           5
# 143112           5
# 143113           5
# 143114           5
# 143115           5
# 143116         4,5
# 143117           5
# 143118           5
# 143119           5
# 143120           5
# 143121           5
# 143122           5
# 143123           5
# 143124           5
# 143125           5
# 143126           5
# 143127           5
# 143128           5
# 143129           5
# 143130           5
# 143131           5
# 143132           5
# 143133           5
# 143134           5
# 143135           5
# 143136           5
#
# [143137 rows x 7 columns]

# %% [markdown]
# # Format Input for Training

# %%
# Duplicate lines with ambiguous syllable counts
# (syllable counts where there is a comma because
# multiple pronounciations are acceptable)

lines = set([0, 1, 2])

for i in range(3):
    lines.remove(i)
    df = df[[
        '0', '1', '2',
        #'1_syllables', '2_syllables'
    ] + ['%s_syllables' % j for j in lines]].join(
        df['%s_syllables' % i].str.split(
            ',', expand=True
        ).stack(-1).reset_index(
            level=1, drop=True
        ).rename('%s_syllables' % i)
    ).drop_duplicates()
    lines.add(i)

df
# Out:
#                                    0                                 1  \
# 0                    Memorial Day --                 a shadow for each
# 1                      spring rain -              as the doctor speaks
# 1                      spring rain -              as the doctor speaks
# 2                  spring moonset --                   a rice ball for
# 2                  spring moonset --                   a rice ball for
# 3                    sunny afternoon                an old man lingers
# 4                      cinco de mayo                       horses roll
# 5                      quitting time                 the smell of rain
# 6                              waves     slowly cresting towards shore
# 6                              waves     slowly cresting towards shore
# 7                  overnight rain --      the scent of orange blossoms
# 8                  misty summer rain                  calling pheasant
# 9                        day is done                    poppies amidst
# 10                   watching clouds                  the white petals
# 11                   mountain stream             two well placed rocks
# 12                     night shift--     in the parking lot car lights
# 13                     a wild violet                on the sunny hill~
# 13                     a wild violet                on the sunny hill~
# 14                       a sunny day  pink haze of the cherry blossoms
# 15                   polished oak --         the freesia's shadow ends
# 16                       nobody here           a table in the mountain
# 17                        first date                 not even noticing
# 18        vanishing difference . . .         gliding geese settle onto
# 18        vanishing difference . . .         gliding geese settle onto
# 19                      distant hawk           a gust of cherry petals
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 21                    moonlessness--                      so many ways
# 22                       earth day--          even the shadows at dusk
# 23                         so cold -             a goose honks its way
# ...                              ...                               ...
# 143113         Fireworks Tonight How       many times are these people
# 143114            he's not okay this        man is not in a good place
# 143115           My dad's okay Thank        god he didn't get murdered
# 143115           My dad's okay Thank        god he didn't get murdered
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143117                 Am I the only      person that thinks Ace has a
# 143117                 Am I the only      person that thinks Ace has a
# 143118           One fucking comment         and my mood is ruined for
# 143119        Are you really friends      if you don't text each other
# 143120              Someone is upset      their team isn't winning the
# 143121            There's no casinos           in Texas but I can walk
# 143122           The write in Mickey    Mouse probably could have been
# 143122           The write in Mickey    Mouse probably could have been
# 143123            It's the beginning              of October and it is
# 143124           People really don't        be having shit else better
# 143125           newt muttering this    is the worst while looking for
# 143126                I'm so excited      for the tour are y'all going
# 143127            Today is the first        day of the rest of my LIFE
# 143128              If you follow me       sure I will follow you back
# 143129              I really have no           life anymore my head is
# 143130              Honestly the kit         isn't that bad The collar
# 143131              an authorship is              a skein alphanumeric
# 143132            I'm not asking did            you say it nor clarify
# 143133               You are truly a               moron or a liar I'm
# 143134            Ain't no selfie on   this earth that's gonna make me
# 143135              is doing a great          job turning Independents
# 143136              Wanted to send a         quick follow up on if the
#
#                               2 0_syllables 1_syllables 2_syllables
# 0                   white cross           5           5           2
# 1             i think of lilacs           2           5           5
# 1             i think of lilacs           3           5           5
# 2                     breakfast           3           4           2
# 2                     breakfast           4           4           2
# 3              near the mailbox           5           5           4
# 4               in the shallows           5           3           4
# 5                  in the lobby           3           4           4
# 6                  a faint moon           1           6           3
# 6                  a faint moon           1           7           3
# 7              in a desert town           4           7           5
# 8                 in Zen temple           5           4           4
# 9               the dying grass           3           4           4
# 10          of a crushed crocus           3           4           5
# 11                the path home           3           4           3
# 12             dim near morning           2           7           4
# 13                noon time nap           4           5           3
# 13                noon time nap           5           5           3
# 14                over the hill           4           8           4
# 15               in coffee foam           3           7           4
# 16         speckled with petals           4           7           5
# 17                 the new moon           2           6           3
# 18            their reflections           5           7           4
# 18            their reflections           6           7           4
# 19             crosses the lawn           3           7           4
# 20         Life support machine           6           8           5
# 20         Life support machine           6           7           5
# 21          I want to touch you           3           4           5
# 22                  smell green           2           7           2
# 23         across the night sky           2           5           5
# ...                         ...         ...         ...         ...
# 143113           being ignorant           5           7           5
# 143114        mentally speaking           5           7           5
# 143115          in a back alley           5           6           5
# 143115          in a back alley           5           7           5
# 143116        my favorite thing           5           6           4
# 143116        my favorite thing           5           6           5
# 143116        my favorite thing           5           7           4
# 143116        my favorite thing           5           7           5
# 143117    really high skill cap           5           7           5
# 143117    really high skill cap           6           7           5
# 143118      the rest of the day           5           7           5
# 143119   that you got home safe           5           7           5
# 143120     Super Bowl this year           5           7           5
# 143121        around with a gun           5           7           5
# 143122      president this time           5           6           5
# 143122      president this time           5           7           5
# 143123          already snowing           5           7           5
# 143124    to do with their time           5           7           5
# 143125     his glasses big mood           5           7           5
# 143126       to be meeting fans           5           7           5
# 143127       and YES it MATTERS           5           7           5
# 143128        this is a promise           5           7           5
# 143129       always in my books           5           7           5
# 143130       is terrible though           5           7           5
# 143131        and story telling           5           7           5
# 143132    what you said neither           5           7           5
# 143133   inclined to think both           5           7           5
# 143134         like Theresa May           5           7           5
# 143135           into Democrats           5           7           5
# 143136  blood is loud Talk soon           5           7           5
#
# [172759 rows x 6 columns]

# %%
# Drop samples that are longer that the 99th percentile of length

max_line_len = int(max([df['%s' % i].str.len().quantile(.99) for i in range(3)]))
df = df[
    (df['0'].str.len() <= max_line_len) & 
    (df['1'].str.len() <= max_line_len) & 
    (df['2'].str.len() <= max_line_len)
].copy()
df
# Out:
#                                    0                                 1  \
# 0                    Memorial Day --                 a shadow for each
# 1                      spring rain -              as the doctor speaks
# 1                      spring rain -              as the doctor speaks
# 2                  spring moonset --                   a rice ball for
# 2                  spring moonset --                   a rice ball for
# 3                    sunny afternoon                an old man lingers
# 4                      cinco de mayo                       horses roll
# 5                      quitting time                 the smell of rain
# 6                              waves     slowly cresting towards shore
# 6                              waves     slowly cresting towards shore
# 7                  overnight rain --      the scent of orange blossoms
# 8                  misty summer rain                  calling pheasant
# 9                        day is done                    poppies amidst
# 10                   watching clouds                  the white petals
# 11                   mountain stream             two well placed rocks
# 12                     night shift--     in the parking lot car lights
# 13                     a wild violet                on the sunny hill~
# 13                     a wild violet                on the sunny hill~
# 14                       a sunny day  pink haze of the cherry blossoms
# 15                   polished oak --         the freesia's shadow ends
# 16                       nobody here           a table in the mountain
# 17                        first date                 not even noticing
# 18        vanishing difference . . .         gliding geese settle onto
# 18        vanishing difference . . .         gliding geese settle onto
# 19                      distant hawk           a gust of cherry petals
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 21                    moonlessness--                      so many ways
# 22                       earth day--          even the shadows at dusk
# 23                         so cold -             a goose honks its way
# ...                              ...                               ...
# 143113         Fireworks Tonight How       many times are these people
# 143114            he's not okay this        man is not in a good place
# 143115           My dad's okay Thank        god he didn't get murdered
# 143115           My dad's okay Thank        god he didn't get murdered
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143117                 Am I the only      person that thinks Ace has a
# 143117                 Am I the only      person that thinks Ace has a
# 143118           One fucking comment         and my mood is ruined for
# 143119        Are you really friends      if you don't text each other
# 143120              Someone is upset      their team isn't winning the
# 143121            There's no casinos           in Texas but I can walk
# 143122           The write in Mickey    Mouse probably could have been
# 143122           The write in Mickey    Mouse probably could have been
# 143123            It's the beginning              of October and it is
# 143124           People really don't        be having shit else better
# 143125           newt muttering this    is the worst while looking for
# 143126                I'm so excited      for the tour are y'all going
# 143127            Today is the first        day of the rest of my LIFE
# 143128              If you follow me       sure I will follow you back
# 143129              I really have no           life anymore my head is
# 143130              Honestly the kit         isn't that bad The collar
# 143131              an authorship is              a skein alphanumeric
# 143132            I'm not asking did            you say it nor clarify
# 143133               You are truly a               moron or a liar I'm
# 143134            Ain't no selfie on   this earth that's gonna make me
# 143135              is doing a great          job turning Independents
# 143136              Wanted to send a         quick follow up on if the
#
#                               2 0_syllables 1_syllables 2_syllables
# 0                   white cross           5           5           2
# 1             i think of lilacs           2           5           5
# 1             i think of lilacs           3           5           5
# 2                     breakfast           3           4           2
# 2                     breakfast           4           4           2
# 3              near the mailbox           5           5           4
# 4               in the shallows           5           3           4
# 5                  in the lobby           3           4           4
# 6                  a faint moon           1           6           3
# 6                  a faint moon           1           7           3
# 7              in a desert town           4           7           5
# 8                 in Zen temple           5           4           4
# 9               the dying grass           3           4           4
# 10          of a crushed crocus           3           4           5
# 11                the path home           3           4           3
# 12             dim near morning           2           7           4
# 13                noon time nap           4           5           3
# 13                noon time nap           5           5           3
# 14                over the hill           4           8           4
# 15               in coffee foam           3           7           4
# 16         speckled with petals           4           7           5
# 17                 the new moon           2           6           3
# 18            their reflections           5           7           4
# 18            their reflections           6           7           4
# 19             crosses the lawn           3           7           4
# 20         Life support machine           6           8           5
# 20         Life support machine           6           7           5
# 21          I want to touch you           3           4           5
# 22                  smell green           2           7           2
# 23         across the night sky           2           5           5
# ...                         ...         ...         ...         ...
# 143113           being ignorant           5           7           5
# 143114        mentally speaking           5           7           5
# 143115          in a back alley           5           6           5
# 143115          in a back alley           5           7           5
# 143116        my favorite thing           5           6           4
# 143116        my favorite thing           5           6           5
# 143116        my favorite thing           5           7           4
# 143116        my favorite thing           5           7           5
# 143117    really high skill cap           5           7           5
# 143117    really high skill cap           6           7           5
# 143118      the rest of the day           5           7           5
# 143119   that you got home safe           5           7           5
# 143120     Super Bowl this year           5           7           5
# 143121        around with a gun           5           7           5
# 143122      president this time           5           6           5
# 143122      president this time           5           7           5
# 143123          already snowing           5           7           5
# 143124    to do with their time           5           7           5
# 143125     his glasses big mood           5           7           5
# 143126       to be meeting fans           5           7           5
# 143127       and YES it MATTERS           5           7           5
# 143128        this is a promise           5           7           5
# 143129       always in my books           5           7           5
# 143130       is terrible though           5           7           5
# 143131        and story telling           5           7           5
# 143132    what you said neither           5           7           5
# 143133   inclined to think both           5           7           5
# 143134         like Theresa May           5           7           5
# 143135           into Democrats           5           7           5
# 143136  blood is loud Talk soon           5           7           5
#
# [170155 rows x 6 columns]

# %%
# Pad the lines to the max line length with new lines
for i in range(3):
    # For input, duplicate the first character
    # TODO - Why?
    df['%s_in' % i] = (df[str(i)].str[0] + df[str(i)]).str.pad(max_line_len+2, 'right', '\n')
    
    # 
    #df['%s_out' % i] = df[str(i)].str.pad(max_line_len, 'right', '\n') + ('\n' if i == 2 else df[str(i+1)].str[0])
    
    # TODO - trying to add the next line's first character before the line breaks
    if i == 2: # If it's the last line
        df['%s_out' % i] = df[str(i)].str.pad(max_line_len+2, 'right', '\n')
    else: 
        # If it's the first or second line, add the first character of the next line to the end of this line.
        # This helps with training so that the next RNN has a better chance of getting the first character right.
        df['%s_out' % i] = (df[str(i)] + '\n' + df[str(i+1)].str[0]).str.pad(max_line_len+2, 'right', '\n')
    
max_line_len += 2

df
# Out:
#                                    0                                 1  \
# 0                    Memorial Day --                 a shadow for each
# 1                      spring rain -              as the doctor speaks
# 1                      spring rain -              as the doctor speaks
# 2                  spring moonset --                   a rice ball for
# 2                  spring moonset --                   a rice ball for
# 3                    sunny afternoon                an old man lingers
# 4                      cinco de mayo                       horses roll
# 5                      quitting time                 the smell of rain
# 6                              waves     slowly cresting towards shore
# 6                              waves     slowly cresting towards shore
# 7                  overnight rain --      the scent of orange blossoms
# 8                  misty summer rain                  calling pheasant
# 9                        day is done                    poppies amidst
# 10                   watching clouds                  the white petals
# 11                   mountain stream             two well placed rocks
# 12                     night shift--     in the parking lot car lights
# 13                     a wild violet                on the sunny hill~
# 13                     a wild violet                on the sunny hill~
# 14                       a sunny day  pink haze of the cherry blossoms
# 15                   polished oak --         the freesia's shadow ends
# 16                       nobody here           a table in the mountain
# 17                        first date                 not even noticing
# 18        vanishing difference . . .         gliding geese settle onto
# 18        vanishing difference . . .         gliding geese settle onto
# 19                      distant hawk           a gust of cherry petals
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 20      Orange sunrise peaks through   The tubes and wires of father's
# 21                    moonlessness--                      so many ways
# 22                       earth day--          even the shadows at dusk
# 23                         so cold -             a goose honks its way
# ...                              ...                               ...
# 143113         Fireworks Tonight How       many times are these people
# 143114            he's not okay this        man is not in a good place
# 143115           My dad's okay Thank        god he didn't get murdered
# 143115           My dad's okay Thank        god he didn't get murdered
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143116               being faded and             listening to music is
# 143117                 Am I the only      person that thinks Ace has a
# 143117                 Am I the only      person that thinks Ace has a
# 143118           One fucking comment         and my mood is ruined for
# 143119        Are you really friends      if you don't text each other
# 143120              Someone is upset      their team isn't winning the
# 143121            There's no casinos           in Texas but I can walk
# 143122           The write in Mickey    Mouse probably could have been
# 143122           The write in Mickey    Mouse probably could have been
# 143123            It's the beginning              of October and it is
# 143124           People really don't        be having shit else better
# 143125           newt muttering this    is the worst while looking for
# 143126                I'm so excited      for the tour are y'all going
# 143127            Today is the first        day of the rest of my LIFE
# 143128              If you follow me       sure I will follow you back
# 143129              I really have no           life anymore my head is
# 143130              Honestly the kit         isn't that bad The collar
# 143131              an authorship is              a skein alphanumeric
# 143132            I'm not asking did            you say it nor clarify
# 143133               You are truly a               moron or a liar I'm
# 143134            Ain't no selfie on   this earth that's gonna make me
# 143135              is doing a great          job turning Independents
# 143136              Wanted to send a         quick follow up on if the
#
#                               2 0_syllables 1_syllables 2_syllables  \
# 0                   white cross           5           5           2
# 1             i think of lilacs           2           5           5
# 1             i think of lilacs           3           5           5
# 2                     breakfast           3           4           2
# 2                     breakfast           4           4           2
# 3              near the mailbox           5           5           4
# 4               in the shallows           5           3           4
# 5                  in the lobby           3           4           4
# 6                  a faint moon           1           6           3
# 6                  a faint moon           1           7           3
# 7              in a desert town           4           7           5
# 8                 in Zen temple           5           4           4
# 9               the dying grass           3           4           4
# 10          of a crushed crocus           3           4           5
# 11                the path home           3           4           3
# 12             dim near morning           2           7           4
# 13                noon time nap           4           5           3
# 13                noon time nap           5           5           3
# 14                over the hill           4           8           4
# 15               in coffee foam           3           7           4
# 16         speckled with petals           4           7           5
# 17                 the new moon           2           6           3
# 18            their reflections           5           7           4
# 18            their reflections           6           7           4
# 19             crosses the lawn           3           7           4
# 20         Life support machine           6           8           5
# 20         Life support machine           6           7           5
# 21          I want to touch you           3           4           5
# 22                  smell green           2           7           2
# 23         across the night sky           2           5           5
# ...                         ...         ...         ...         ...
# 143113           being ignorant           5           7           5
# 143114        mentally speaking           5           7           5
# 143115          in a back alley           5           6           5
# 143115          in a back alley           5           7           5
# 143116        my favorite thing           5           6           4
# 143116        my favorite thing           5           6           5
# 143116        my favorite thing           5           7           4
# 143116        my favorite thing           5           7           5
# 143117    really high skill cap           5           7           5
# 143117    really high skill cap           6           7           5
# 143118      the rest of the day           5           7           5
# 143119   that you got home safe           5           7           5
# 143120     Super Bowl this year           5           7           5
# 143121        around with a gun           5           7           5
# 143122      president this time           5           6           5
# 143122      president this time           5           7           5
# 143123          already snowing           5           7           5
# 143124    to do with their time           5           7           5
# 143125     his glasses big mood           5           7           5
# 143126       to be meeting fans           5           7           5
# 143127       and YES it MATTERS           5           7           5
# 143128        this is a promise           5           7           5
# 143129       always in my books           5           7           5
# 143130       is terrible though           5           7           5
# 143131        and story telling           5           7           5
# 143132    what you said neither           5           7           5
# 143133   inclined to think both           5           7           5
# 143134         like Theresa May           5           7           5
# 143135           into Democrats           5           7           5
# 143136  blood is loud Talk soon           5           7           5
#
#                                                      0_in  \
# 0       MMemorial Day --\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       sspring rain -\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       sspring rain -\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       sspring moonset --\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       sspring moonset --\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3       ssunny afternoon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 4       ccinco de mayo\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5       qquitting time\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       wwaves\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       wwaves\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 7       oovernight rain --\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 8       mmisty summer rain\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 9       dday is done\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 10      wwatching clouds\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 11      mmountain stream\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 12      nnight shift--\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      aa wild violet\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      aa wild violet\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 14      aa sunny day\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 15      ppolished oak --\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      nnobody here\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 17      ffirst date\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 18      vvanishing difference . . .\n\n\n\n\n\n\n\n\n\...
# 18      vvanishing difference . . .\n\n\n\n\n\n\n\n\n\...
# 19      ddistant hawk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 20      OOrange sunrise peaks through\n\n\n\n\n\n\n\n\...
# 20      OOrange sunrise peaks through\n\n\n\n\n\n\n\n\...
# 21      mmoonlessness--\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 22      eearth day--\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 23      sso cold -\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 143113  FFireworks Tonight How\n\n\n\n\n\n\n\n\n\n\n\n...
# 143114  hhe's not okay this\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143115  MMy dad's okay Thank\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143115  MMy dad's okay Thank\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  bbeing faded and\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  bbeing faded and\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  bbeing faded and\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  bbeing faded and\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  AAm I the only\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  AAm I the only\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143118  OOne fucking comment\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143119  AAre you really friends\n\n\n\n\n\n\n\n\n\n\n\...
# 143120  SSomeone is upset\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143121  TThere's no casinos\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143122  TThe write in Mickey\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143122  TThe write in Mickey\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143123  IIt's the beginning\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143124  PPeople really don't\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143125  nnewt muttering this\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143126  II'm so excited\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143127  TToday is the first\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143128  IIf you follow me\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143129  II really have no\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143130  HHonestly the kit\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143131  aan authorship is\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143132  II'm not asking did\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143133  YYou are truly a\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143134  AAin't no selfie on\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143135  iis doing a great\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143136  WWanted to send a\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                     0_out  \
# 0       Memorial Day --\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       spring rain -\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       spring rain -\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       spring moonset --\na\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       spring moonset --\na\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3       sunny afternoon\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 4       cinco de mayo\nh\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5       quitting time\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       waves\ns\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       waves\ns\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 7       overnight rain --\nt\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 8       misty summer rain\nc\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 9       day is done\np\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 10      watching clouds\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 11      mountain stream\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 12      night shift--\ni\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      a wild violet\no\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      a wild violet\no\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 14      a sunny day\np\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 15      polished oak --\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      nobody here\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 17      first date\nn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 18      vanishing difference . . .\n \n\n\n\n\n\n\n\n\...
# 18      vanishing difference . . .\n \n\n\n\n\n\n\n\n\...
# 19      distant hawk\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 20      Orange sunrise peaks through\nT\n\n\n\n\n\n\n\...
# 20      Orange sunrise peaks through\nT\n\n\n\n\n\n\n\...
# 21      moonlessness--\ns\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 22      earth day--\ne\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 23      so cold -\na\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 143113  Fireworks Tonight How\n \n\n\n\n\n\n\n\n\n\n\n...
# 143114  he's not okay this\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143115  My dad's okay Thank\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143115  My dad's okay Thank\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  being faded and\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  being faded and\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  being faded and\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  being faded and\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  Am I the only\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  Am I the only\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143118  One fucking comment\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143119  Are you really friends\n \n\n\n\n\n\n\n\n\n\n\...
# 143120  Someone is upset\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143121  There's no casinos\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143122  The write in Mickey\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143122  The write in Mickey\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143123  It's the beginning\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143124  People really don't\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143125  newt muttering this\n \n\n\n\n\n\n\n\n\n\n\n\n...
# 143126  I'm so excited\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143127  Today is the first\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143128  If you follow me\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143129  I really have no\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143130  Honestly the kit\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143131  an authorship is\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143132  I'm not asking did\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143133  You are truly a\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143134  Ain't no selfie on\n \n\n\n\n\n\n\n\n\n\n\n\n\...
# 143135  is doing a great\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143136  Wanted to send a\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...
#
#                                                      1_in  \
# 0       aa shadow for each\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       aas the doctor speaks\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1       aas the doctor speaks\n\n\n\n\n\n\n\n\n\n\n\n\...
# 2       aa rice ball for\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       aa rice ball for\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3       aan old man lingers\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4       hhorses roll\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5       tthe smell of rain\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       sslowly cresting towards shore\n\n\n\n\n\n\n\n...
# 6       sslowly cresting towards shore\n\n\n\n\n\n\n\n...
# 7       tthe scent of orange blossoms\n\n\n\n\n\n\n\n\...
# 8       ccalling pheasant\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 9       ppoppies amidst\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 10      tthe white petals\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 11          two well placed rocks\n\n\n\n\n\n\n\n\n\n\...
# 12      iin the parking lot car lights\n\n\n\n\n\n\n\n...
# 13      oon the sunny hill~\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 13      oon the sunny hill~\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 14      ppink haze of the cherry blossoms\n\n\n\n\n\n\...
# 15      tthe freesia's shadow ends\n\n\n\n\n\n\n\n\n\n...
# 16      aa table in the mountain\n\n\n\n\n\n\n\n\n\n\n...
# 17      nnot even noticing\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 18         gliding geese settle onto\n\n\n\n\n\n\n\n\n...
# 18         gliding geese settle onto\n\n\n\n\n\n\n\n\n...
# 19      aa gust of cherry petals\n\n\n\n\n\n\n\n\n\n\n...
# 20      TThe tubes and wires of father's\n\n\n\n\n\n\n...
# 20      TThe tubes and wires of father's\n\n\n\n\n\n\n...
# 21      sso many ways\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 22      eeven the shadows at dusk\n\n\n\n\n\n\n\n\n\n\...
# 23      aa goose honks its way\n\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 143113    many times are these people\n\n\n\n\n\n\n\n\...
# 143114    man is not in a good place\n\n\n\n\n\n\n\n\n...
# 143115    god he didn't get murdered\n\n\n\n\n\n\n\n\n...
# 143115    god he didn't get murdered\n\n\n\n\n\n\n\n\n...
# 143116    listening to music is\n\n\n\n\n\n\n\n\n\n\n\...
# 143116    listening to music is\n\n\n\n\n\n\n\n\n\n\n\...
# 143116    listening to music is\n\n\n\n\n\n\n\n\n\n\n\...
# 143116    listening to music is\n\n\n\n\n\n\n\n\n\n\n\...
# 143117    person that thinks Ace has a\n\n\n\n\n\n\n\n...
# 143117    person that thinks Ace has a\n\n\n\n\n\n\n\n...
# 143118    and my mood is ruined for\n\n\n\n\n\n\n\n\n\...
# 143119    if you don't text each other\n\n\n\n\n\n\n\n...
# 143120    their team isn't winning the\n\n\n\n\n\n\n\n...
# 143121    in Texas but I can walk\n\n\n\n\n\n\n\n\n\n\...
# 143122    Mouse probably could have been\n\n\n\n\n\n\n...
# 143122    Mouse probably could have been\n\n\n\n\n\n\n...
# 143123    of October and it is\n\n\n\n\n\n\n\n\n\n\n\n...
# 143124    be having shit else better\n\n\n\n\n\n\n\n\n...
# 143125    is the worst while looking for\n\n\n\n\n\n\n...
# 143126    for the tour are y'all going\n\n\n\n\n\n\n\n...
# 143127    day of the rest of my LIFE\n\n\n\n\n\n\n\n\n...
# 143128    sure I will follow you back\n\n\n\n\n\n\n\n\...
# 143129    life anymore my head is\n\n\n\n\n\n\n\n\n\n\...
# 143130    isn't that bad The collar\n\n\n\n\n\n\n\n\n\...
# 143131    a skein alphanumeric\n\n\n\n\n\n\n\n\n\n\n\n...
# 143132    you say it nor clarify\n\n\n\n\n\n\n\n\n\n\n...
# 143133    moron or a liar I'm\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143134    this earth that's gonna make me\n\n\n\n\n\n\...
# 143135    job turning Independents\n\n\n\n\n\n\n\n\n\n...
# 143136    quick follow up on if the\n\n\n\n\n\n\n\n\n\...
#
#                                                     1_out  \
# 0       a shadow for each\nw\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       as the doctor speaks\ni\n\n\n\n\n\n\n\n\n\n\n\...
# 1       as the doctor speaks\ni\n\n\n\n\n\n\n\n\n\n\n\...
# 2       a rice ball for\nb\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       a rice ball for\nb\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3       an old man lingers\nn\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4       horses roll\ni\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5       the smell of rain\ni\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       slowly cresting towards shore\na\n\n\n\n\n\n\n...
# 6       slowly cresting towards shore\na\n\n\n\n\n\n\n...
# 7       the scent of orange blossoms\ni\n\n\n\n\n\n\n\...
# 8       calling pheasant\ni\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 9       poppies amidst\nt\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 10      the white petals\no\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 11         two well placed rocks\nt\n\n\n\n\n\n\n\n\n\...
# 12      in the parking lot car lights\nd\n\n\n\n\n\n\n...
# 13      on the sunny hill~\nn\n\n\n\n\n\n\n\n\n\n\n\n\...
# 13      on the sunny hill~\nn\n\n\n\n\n\n\n\n\n\n\n\n\...
# 14      pink haze of the cherry blossoms\no\n\n\n\n\n\...
# 15      the freesia's shadow ends\ni\n\n\n\n\n\n\n\n\n...
# 16      a table in the mountain\ns\n\n\n\n\n\n\n\n\n\n...
# 17      not even noticing\nt\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 18        gliding geese settle onto\n \n\n\n\n\n\n\n\n...
# 18        gliding geese settle onto\n \n\n\n\n\n\n\n\n...
# 19      a gust of cherry petals\nc\n\n\n\n\n\n\n\n\n\n...
# 20      The tubes and wires of father's\nL\n\n\n\n\n\n...
# 20      The tubes and wires of father's\nL\n\n\n\n\n\n...
# 21      so many ways\nI\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 22      even the shadows at dusk\ns\n\n\n\n\n\n\n\n\n\...
# 23      a goose honks its way\na\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 143113   many times are these people\nb\n\n\n\n\n\n\n\...
# 143114   man is not in a good place\nm\n\n\n\n\n\n\n\n...
# 143115   god he didn't get murdered\ni\n\n\n\n\n\n\n\n...
# 143115   god he didn't get murdered\ni\n\n\n\n\n\n\n\n...
# 143116   listening to music is\nm\n\n\n\n\n\n\n\n\n\n\...
# 143116   listening to music is\nm\n\n\n\n\n\n\n\n\n\n\...
# 143116   listening to music is\nm\n\n\n\n\n\n\n\n\n\n\...
# 143116   listening to music is\nm\n\n\n\n\n\n\n\n\n\n\...
# 143117   person that thinks Ace has a\nr\n\n\n\n\n\n\n...
# 143117   person that thinks Ace has a\nr\n\n\n\n\n\n\n...
# 143118   and my mood is ruined for\nt\n\n\n\n\n\n\n\n\...
# 143119   if you don't text each other\nt\n\n\n\n\n\n\n...
# 143120   their team isn't winning the\nS\n\n\n\n\n\n\n...
# 143121   in Texas but I can walk\na\n\n\n\n\n\n\n\n\n\...
# 143122   Mouse probably could have been\np\n\n\n\n\n\n...
# 143122   Mouse probably could have been\np\n\n\n\n\n\n...
# 143123   of October and it is\na\n\n\n\n\n\n\n\n\n\n\n...
# 143124   be having shit else better\nt\n\n\n\n\n\n\n\n...
# 143125   is the worst while looking for\nh\n\n\n\n\n\n...
# 143126   for the tour are y'all going\nt\n\n\n\n\n\n\n...
# 143127   day of the rest of my LIFE\na\n\n\n\n\n\n\n\n...
# 143128   sure I will follow you back\nt\n\n\n\n\n\n\n\...
# 143129   life anymore my head is\na\n\n\n\n\n\n\n\n\n\...
# 143130   isn't that bad The collar\ni\n\n\n\n\n\n\n\n\...
# 143131   a skein alphanumeric\na\n\n\n\n\n\n\n\n\n\n\n...
# 143132   you say it nor clarify\nw\n\n\n\n\n\n\n\n\n\n...
# 143133   moron or a liar I'm\ni\n\n\n\n\n\n\n\n\n\n\n\...
# 143134   this earth that's gonna make me\nl\n\n\n\n\n\...
# 143135   job turning Independents\ni\n\n\n\n\n\n\n\n\n...
# 143136   quick follow up on if the\nb\n\n\n\n\n\n\n\n\...
#
#                                                      2_in  \
# 0       wwhite cross\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       ii think of lilacs\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 1       ii think of lilacs\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       bbreakfast\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 2       bbreakfast\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 3       nnear the mailbox\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 4       iin the shallows\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 5       iin the lobby\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 6       aa faint moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 6       aa faint moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 7       iin a desert town\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 8       iin Zen temple\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 9       tthe dying grass\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 10      oof a crushed crocus\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 11      tthe path home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 12      ddim near morning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 13      nnoon time nap\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      nnoon time nap\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 14      oover the hill\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 15      iin coffee foam\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 16      sspeckled with petals\n\n\n\n\n\n\n\n\n\n\n\n\...
# 17      tthe new moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 18           their reflections\n\n\n\n\n\n\n\n\n\n\n\n...
# 18           their reflections\n\n\n\n\n\n\n\n\n\n\n\n...
# 19      ccrosses the lawn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 20      LLife support machine\n\n\n\n\n\n\n\n\n\n\n\n\...
# 20      LLife support machine\n\n\n\n\n\n\n\n\n\n\n\n\...
# 21      II want to touch you\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 22      ssmell green\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 23      aacross the night sky\n\n\n\n\n\n\n\n\n\n\n\n\...
# ...                                                   ...
# 143113  bbeing ignorant\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143114  mmentally speaking\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143115  iin a back alley\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143115  iin a back alley\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  mmy favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  mmy favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  mmy favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143116  mmy favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  rreally high skill cap\n\n\n\n\n\n\n\n\n\n\n\n...
# 143117  rreally high skill cap\n\n\n\n\n\n\n\n\n\n\n\n...
# 143118  tthe rest of the day\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143119  tthat you got home safe\n\n\n\n\n\n\n\n\n\n\n\...
# 143120  SSuper Bowl this year\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143121  aaround with a gun\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143122  ppresident this time\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143122  ppresident this time\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143123  aalready snowing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143124  tto do with their time\n\n\n\n\n\n\n\n\n\n\n\n...
# 143125  hhis glasses big mood\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143126  tto be meeting fans\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143127  aand YES it MATTERS\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143128  tthis is a promise\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143129  aalways in my books\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143130  iis terrible though\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143131  aand story telling\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143132  wwhat you said neither\n\n\n\n\n\n\n\n\n\n\n\n...
# 143133  iinclined to think both\n\n\n\n\n\n\n\n\n\n\n\...
# 143134  llike Theresa May\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143135  iinto Democrats\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143136  bblood is loud Talk soon\n\n\n\n\n\n\n\n\n\n\n...
#
#                                                     2_out
# 0       white cross\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1       i think of lilacs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 1       i think of lilacs\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 2       breakfast\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 2       breakfast\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 3       near the mailbox\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 4       in the shallows\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 5       in the lobby\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       a faint moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 6       a faint moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 7       in a desert town\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 8       in Zen temple\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 9       the dying grass\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 10      of a crushed crocus\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 11      the path home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 12      dim near morning\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 13      noon time nap\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 13      noon time nap\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 14      over the hill\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 15      in coffee foam\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 16      speckled with petals\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 17      the new moon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 18          their reflections\n\n\n\n\n\n\n\n\n\n\n\n\...
# 18          their reflections\n\n\n\n\n\n\n\n\n\n\n\n\...
# 19      crosses the lawn\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 20      Life support machine\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 20      Life support machine\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 21      I want to touch you\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 22      smell green\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 23      across the night sky\n\n\n\n\n\n\n\n\n\n\n\n\n...
# ...                                                   ...
# 143113  being ignorant\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143114  mentally speaking\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143115  in a back alley\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143115  in a back alley\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143116  my favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143116  my favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143116  my favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143116  my favorite thing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143117  really high skill cap\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143117  really high skill cap\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143118  the rest of the day\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143119  that you got home safe\n\n\n\n\n\n\n\n\n\n\n\n...
# 143120  Super Bowl this year\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143121  around with a gun\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143122  president this time\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143122  president this time\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143123  already snowing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143124  to do with their time\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143125  his glasses big mood\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143126  to be meeting fans\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143127  and YES it MATTERS\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143128  this is a promise\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143129  always in my books\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143130  is terrible though\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143131  and story telling\n\n\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143132  what you said neither\n\n\n\n\n\n\n\n\n\n\n\n\...
# 143133  inclined to think both\n\n\n\n\n\n\n\n\n\n\n\n...
# 143134  like Theresa May\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143135  into Democrats\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...
# 143136  blood is loud Talk soon\n\n\n\n\n\n\n\n\n\n\n\...
#
# [170155 rows x 12 columns]

# %%
inputs = df[['0_in', '1_in', '2_in']].values

tokenizer = Tokenizer(filters='', char_level=True)
tokenizer.fit_on_texts(inputs.flatten())
n_tokens = len(tokenizer.word_counts) + 1

# X is the input for each line in sequences of one-hot-encoded values
X = np_utils.to_categorical([
    tokenizer.texts_to_sequences(inputs[:,i]) for i in range(3)
], num_classes=n_tokens)

outputs = df[['0_out', '1_out', '2_out']].values

# Y is the output for each line in sequences of one-hot-encoded values
Y = np_utils.to_categorical([
    tokenizer.texts_to_sequences(outputs[:,i]) for i in range(3)
], num_classes=n_tokens)

# X_syllables is the count of syllables for each line
X_syllables = df[['0_syllables', '1_syllables', '2_syllables']].values

# %% [markdown]
# # Training Model

# %%
LATENT_DIM = 2048
class TrainingLine:
    def __init__(self, name, previous_line, lstm):
        self.char_input = Input(shape=(None, n_tokens), name='char_input_%s' % name)
        
        self.syllable_input = Input(shape=(1,), name='syllable_input_%s' % name)
        self.syllable_dense = Dense(lstm.units, activation='relu', name='syllable_dense_%s' % name)
        self.syllable_dense_output = self.syllable_dense(self.syllable_input)
        
        #self.lstm = LSTM(latent_dim, return_state=True, return_sequences=True, name='lstm_%s' % name)
        
        if previous_line:
            initial_state = [
                Add(name='add_h_%s' % name)([
                    previous_line.lstm_h,
                    self.syllable_dense_output
                ]),
                Add(name='add_c_%s' % name)([
                    previous_line.lstm_c,
                    self.syllable_dense_output
                ])
            ]
        else:
            initial_state = [self.syllable_dense_output, self.syllable_dense_output]
            
        self.lstm_out, self.lstm_h, self.lstm_c = lstm(self.char_input, initial_state=initial_state)
        
        self.output_dense = Dense(n_tokens, activation='softmax', name='output_%s' % name)
        self.output = self.output_dense(self.lstm_out)
        
lstm = LSTM(LATENT_DIM, return_state=True, return_sequences=True, name='lstm')
lines = []
inputs = []
outputs = []
for i in range(3):
    previous_line = lines[-1] if lines else None
    lines.append(TrainingLine('line_%s' % i, previous_line, lstm))
    inputs += [lines[-1].char_input, lines[-1].syllable_input]
    outputs.append(lines[-1].output)
    
training_model = Model(inputs, outputs)
training_model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
training_model.summary(line_length=200)
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# Layer (type)                                                      Output Shape                                Param #                 Connected to
# ========================================================================================================================================================================================================
# syllable_input_line_0 (InputLayer)                                (None, 1)                                   0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# char_input_line_0 (InputLayer)                                    (None, None, 81)                            0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# syllable_dense_line_0 (Dense)                                     (None, 2048)                                4096                    syllable_input_line_0[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# syllable_input_line_1 (InputLayer)                                (None, 1)                                   0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# lstm (LSTM)                                                       [(None, None, 2048), (None, 2048), (None, 2 17448960                char_input_line_0[0][0]
#                                                                                                                                       syllable_dense_line_0[0][0]
#                                                                                                                                       syllable_dense_line_0[0][0]
#                                                                                                                                       char_input_line_1[0][0]
#                                                                                                                                       add_h_line_1[0][0]
#                                                                                                                                       add_c_line_1[0][0]
#                                                                                                                                       char_input_line_2[0][0]
#                                                                                                                                       add_h_line_2[0][0]
#                                                                                                                                       add_c_line_2[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# syllable_dense_line_1 (Dense)                                     (None, 2048)                                4096                    syllable_input_line_1[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# char_input_line_1 (InputLayer)                                    (None, None, 81)                            0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# add_h_line_1 (Add)                                                (None, 2048)                                0                       lstm[0][1]
#                                                                                                                                       syllable_dense_line_1[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# add_c_line_1 (Add)                                                (None, 2048)                                0                       lstm[0][2]
#                                                                                                                                       syllable_dense_line_1[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# syllable_input_line_2 (InputLayer)                                (None, 1)                                   0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# syllable_dense_line_2 (Dense)                                     (None, 2048)                                4096                    syllable_input_line_2[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# char_input_line_2 (InputLayer)                                    (None, None, 81)                            0
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# add_h_line_2 (Add)                                                (None, 2048)                                0                       lstm[1][1]
#                                                                                                                                       syllable_dense_line_2[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# add_c_line_2 (Add)                                                (None, 2048)                                0                       lstm[1][2]
#                                                                                                                                       syllable_dense_line_2[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# output_line_0 (Dense)                                             (None, None, 81)                            165969                  lstm[0][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# output_line_1 (Dense)                                             (None, None, 81)                            165969                  lstm[1][0]
# ________________________________________________________________________________________________________________________________________________________________________________________________________
# output_line_2 (Dense)                                             (None, None, 81)                            165969                  lstm[2][0]
# ========================================================================================================================================================================================================
# Total params: 17,959,155
# Trainable params: 17,959,155
# Non-trainable params: 0
# ________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
# Either train the model or load an existing model

filepath="lstm-3-%s-{epoch:02d}-{val_loss:.2f}.hdf5" % LATENT_DIM
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

training_model.fit([
    X[0], X_syllables[:,0], 
    X[1], X_syllables[:,1], 
    X[2], X_syllables[:,2]
], [Y[0], Y[1], Y[2]], batch_size=64, epochs=1000, validation_split=.1, callbacks=callbacks_list)

#training_model.save('new_model_5.hdf5')

#training_model.load_weights('new_model_4.hdf5')
# Out:
# Train on 33316 samples, validate on 3702 samples
# Epoch 1/1000
# 33316/33316 [==============================] - 311s 9ms/step - loss: 4.1688 - output_line_0_loss: 1.2205 - output_line_1_loss: 1.5817 - output_line_2_loss: 1.3665 - val_loss: 3.3686 - val_output_line_0_loss: 0.9481 - val_output_line_1_loss: 1.4030 - val_output_line_2_loss: 1.0174
#
# Epoch 00001: val_loss improved from inf to 3.36855, saving model to lstm-3-2048-01-3.37.hdf5
# /usr/local/lib/python3.5/dist-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'syllable_dense_line_0_1/Relu:0' shape=(?, 2048) dtype=float32>, <tf.Tensor 'syllable_dense_line_0_1/Relu:0' shape=(?, 2048) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# /usr/local/lib/python3.5/dist-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'add_h_line_1_1/add:0' shape=(?, 2048) dtype=float32>, <tf.Tensor 'add_c_line_1_1/add:0' shape=(?, 2048) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# /usr/local/lib/python3.5/dist-packages/keras/engine/network.py:877: UserWarning: Layer lstm was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'add_h_line_2_1/add:0' shape=(?, 2048) dtype=float32>, <tf.Tensor 'add_c_line_2_1/add:0' shape=(?, 2048) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# Epoch 2/1000
# 33316/33316 [==============================] - 308s 9ms/step - loss: 2.6245 - output_line_0_loss: 0.7755 - output_line_1_loss: 1.0032 - output_line_2_loss: 0.8459 - val_loss: 2.4221 - val_output_line_0_loss: 0.7042 - val_output_line_1_loss: 1.0035 - val_output_line_2_loss: 0.7144
#
# Epoch 00002: val_loss improved from 3.36855 to 2.42214, saving model to lstm-3-2048-02-2.42.hdf5
# Epoch 3/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.8840 - output_line_0_loss: 0.5922 - output_line_1_loss: 0.7092 - output_line_2_loss: 0.5826 - val_loss: 2.0013 - val_output_line_0_loss: 0.6131 - val_output_line_1_loss: 0.8347 - val_output_line_2_loss: 0.5536
#
# Epoch 00003: val_loss improved from 2.42214 to 2.00134, saving model to lstm-3-2048-03-2.00.hdf5
# Epoch 4/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.6077 - output_line_0_loss: 0.5127 - output_line_1_loss: 0.6064 - output_line_2_loss: 0.4886 - val_loss: 1.8327 - val_output_line_0_loss: 0.5606 - val_output_line_1_loss: 0.7617 - val_output_line_2_loss: 0.5104
#
# Epoch 00004: val_loss improved from 2.00134 to 1.83268, saving model to lstm-3-2048-04-1.83.hdf5
# Epoch 5/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.4523 - output_line_0_loss: 0.4628 - output_line_1_loss: 0.5505 - output_line_2_loss: 0.4389 - val_loss: 1.7414 - val_output_line_0_loss: 0.5322 - val_output_line_1_loss: 0.7264 - val_output_line_2_loss: 0.4828
#
# Epoch 00005: val_loss improved from 1.83268 to 1.74142, saving model to lstm-3-2048-05-1.74.hdf5
# Epoch 6/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.3361 - output_line_0_loss: 0.4233 - output_line_1_loss: 0.5097 - output_line_2_loss: 0.4031 - val_loss: 1.7251 - val_output_line_0_loss: 0.5327 - val_output_line_1_loss: 0.7177 - val_output_line_2_loss: 0.4747
#
# Epoch 00006: val_loss improved from 1.74142 to 1.72514, saving model to lstm-3-2048-06-1.73.hdf5
# Epoch 7/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.2325 - output_line_0_loss: 0.3867 - output_line_1_loss: 0.4740 - output_line_2_loss: 0.3718 - val_loss: 1.7215 - val_output_line_0_loss: 0.5331 - val_output_line_1_loss: 0.7144 - val_output_line_2_loss: 0.4740
#
# Epoch 00007: val_loss improved from 1.72514 to 1.72147, saving model to lstm-3-2048-07-1.72.hdf5
# Epoch 8/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.1325 - output_line_0_loss: 0.3502 - output_line_1_loss: 0.4398 - output_line_2_loss: 0.3425 - val_loss: 1.7526 - val_output_line_0_loss: 0.5476 - val_output_line_1_loss: 0.7263 - val_output_line_2_loss: 0.4786
#
# Epoch 00008: val_loss did not improve from 1.72147
# Epoch 9/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 1.0360 - output_line_0_loss: 0.3149 - output_line_1_loss: 0.4068 - output_line_2_loss: 0.3144 - val_loss: 1.8010 - val_output_line_0_loss: 0.5616 - val_output_line_1_loss: 0.7453 - val_output_line_2_loss: 0.4941
#
# Epoch 00009: val_loss did not improve from 1.72147
# Epoch 10/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.9432 - output_line_0_loss: 0.2812 - output_line_1_loss: 0.3744 - output_line_2_loss: 0.2876 - val_loss: 1.8671 - val_output_line_0_loss: 0.5927 - val_output_line_1_loss: 0.7684 - val_output_line_2_loss: 0.5060
#
# Epoch 00010: val_loss did not improve from 1.72147
# Epoch 11/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.8554 - output_line_0_loss: 0.2506 - output_line_1_loss: 0.3429 - output_line_2_loss: 0.2620 - val_loss: 1.9367 - val_output_line_0_loss: 0.6207 - val_output_line_1_loss: 0.7894 - val_output_line_2_loss: 0.5265
#
# Epoch 00011: val_loss did not improve from 1.72147
# Epoch 12/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.7741 - output_line_0_loss: 0.2242 - output_line_1_loss: 0.3121 - output_line_2_loss: 0.2378 - val_loss: 2.0100 - val_output_line_0_loss: 0.6442 - val_output_line_1_loss: 0.8193 - val_output_line_2_loss: 0.5465
#
# Epoch 00012: val_loss did not improve from 1.72147
# Epoch 13/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.7004 - output_line_0_loss: 0.2020 - output_line_1_loss: 0.2831 - output_line_2_loss: 0.2153 - val_loss: 2.0883 - val_output_line_0_loss: 0.6660 - val_output_line_1_loss: 0.8586 - val_output_line_2_loss: 0.5636
#
# Epoch 00013: val_loss did not improve from 1.72147
# Epoch 14/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.6344 - output_line_0_loss: 0.1840 - output_line_1_loss: 0.2558 - output_line_2_loss: 0.1946 - val_loss: 2.1791 - val_output_line_0_loss: 0.7018 - val_output_line_1_loss: 0.8894 - val_output_line_2_loss: 0.5879
#
# Epoch 00014: val_loss did not improve from 1.72147
# Epoch 15/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.5770 - output_line_0_loss: 0.1701 - output_line_1_loss: 0.2312 - output_line_2_loss: 0.1757 - val_loss: 2.3240 - val_output_line_0_loss: 0.7387 - val_output_line_1_loss: 0.9509 - val_output_line_2_loss: 0.6344
#
# Epoch 00015: val_loss did not improve from 1.72147
# Epoch 16/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.5264 - output_line_0_loss: 0.1592 - output_line_1_loss: 0.2084 - output_line_2_loss: 0.1588 - val_loss: 2.3990 - val_output_line_0_loss: 0.7596 - val_output_line_1_loss: 0.9895 - val_output_line_2_loss: 0.6499
#
# Epoch 00016: val_loss did not improve from 1.72147
# Epoch 17/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.4839 - output_line_0_loss: 0.1515 - output_line_1_loss: 0.1885 - output_line_2_loss: 0.1440 - val_loss: 2.4335 - val_output_line_0_loss: 0.7682 - val_output_line_1_loss: 1.0097 - val_output_line_2_loss: 0.6557
#
# Epoch 00017: val_loss did not improve from 1.72147
# Epoch 18/1000
# 33316/33316 [==============================] - 311s 9ms/step - loss: 0.4468 - output_line_0_loss: 0.1452 - output_line_1_loss: 0.1709 - output_line_2_loss: 0.1308 - val_loss: 2.5185 - val_output_line_0_loss: 0.7912 - val_output_line_1_loss: 1.0446 - val_output_line_2_loss: 0.6828
#
# Epoch 00018: val_loss did not improve from 1.72147
# Epoch 19/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.4152 - output_line_0_loss: 0.1404 - output_line_1_loss: 0.1554 - output_line_2_loss: 0.1194 - val_loss: 2.6025 - val_output_line_0_loss: 0.8084 - val_output_line_1_loss: 1.0866 - val_output_line_2_loss: 0.7075
#
# Epoch 00019: val_loss did not improve from 1.72147
# Epoch 20/1000
# 33316/33316 [==============================] - 310s 9ms/step - loss: 0.3880 - output_line_0_loss: 0.1365 - output_line_1_loss: 0.1423 - output_line_2_loss: 0.1092 - val_loss: 2.6846 - val_output_line_0_loss: 0.8219 - val_output_line_1_loss: 1.1262 - val_output_line_2_loss: 0.7365
#
# Epoch 00020: val_loss did not improve from 1.72147
# Epoch 21/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.3661 - output_line_0_loss: 0.1338 - output_line_1_loss: 0.1314 - output_line_2_loss: 0.1009 - val_loss: 2.7871 - val_output_line_0_loss: 0.8438 - val_output_line_1_loss: 1.1789 - val_output_line_2_loss: 0.7644
#
# Epoch 00021: val_loss did not improve from 1.72147
# Epoch 22/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.3453 - output_line_0_loss: 0.1311 - output_line_1_loss: 0.1212 - output_line_2_loss: 0.0930 - val_loss: 2.8365 - val_output_line_0_loss: 0.8475 - val_output_line_1_loss: 1.2032 - val_output_line_2_loss: 0.7859
#
# Epoch 00022: val_loss did not improve from 1.72147
# Epoch 23/1000
# 33316/33316 [==============================] - 309s 9ms/step - loss: 0.3284 - output_line_0_loss: 0.1292 - output_line_1_loss: 0.1127 - output_line_2_loss: 0.0865 - val_loss: 2.9231 - val_output_line_0_loss: 0.8675 - val_output_line_1_loss: 1.2447 - val_output_line_2_loss: 0.8109
#
# Epoch 00023: val_loss did not improve from 1.72147
# Epoch 24/1000
#  3264/33316 [=>............................] - ETA: 4:31 - loss: 0.2748 - output_line_0_loss: 0.1157 - output_line_1_loss: 0.0903 - output_line_2_loss: 0.0687
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ee120be387eb> in <module>()
#       9     X[1], X_syllables[:,1],
#      10     X[2], X_syllables[:,2]
# ---> 11 ], [Y[0], Y[1], Y[2]], batch_size=64, epochs=1000, validation_split=.1, callbacks=callbacks_list)
#      12
#      13 #training_model.save('new_model_5.hdf5')
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# /usr/local/lib/python3.5/dist-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2719                     'In order to feed symbolic tensors to a Keras model '
#    2720                     'in TensorFlow, you need tensorflow 1.8 or higher.')
# -> 2721             return self._legacy_call(inputs)
#    2722
#    2723
#
# /usr/local/lib/python3.5/dist-packages/keras/backend/tensorflow_backend.py in _legacy_call(self, inputs)
#    2691         session = get_session()
#    2692         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2693                               **self.session_kwargs)
#    2694         return updated[:len(self.outputs)]
#    2695
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1348   def _do_call(self, fn, *args):
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#    1352       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1327           return tf_session.TF_Run(session, options,
#    1328                                    feed_dict, fetch_list, target_list,
# -> 1329                                    status, run_metadata)
#    1330
#    1331     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
training_model.load_weights('lstm-3-2048-07-1.72.hdf5')

# %%
generator_lstm = LSTM(LATENT_DIM, return_state=True, return_sequences=True, name='generator_lstm')

class GeneratorLine:
    def __init__(self, name, training_line, lstm, latent_dim=LATENT_DIM):
        self.char_input = Input(shape=(None, n_tokens), name='char_input_%s' % name)
        
        self.syllable_input = Input(shape=(1,), name='syllable_input_%s' % name)
        self.syllable_dense = Dense(latent_dim, activation='relu', name='syllable_dense_%s' % name)
        self.syllable_dense_output = self.syllable_dense(self.syllable_input)
        
        self.h_input = Input(shape=(latent_dim,), name='h_input_%s' % name)
        self.c_input = Input(shape=(latent_dim,), name='c_input_%s' % name)
        initial_state = [self.h_input, self.c_input]
        
        self.lstm = lstm
            
        self.lstm_out, self.lstm_h, self.lstm_c = self.lstm(self.char_input, initial_state=initial_state)
        
        self.output_dense = Dense(n_tokens, activation='softmax', name='output_%s' % name)
        self.output = self.output_dense(self.lstm_out)
        
        self.syllable_dense.set_weights(training_line.syllable_dense.get_weights())
        #self.lstm.set_weights(lstm.get_weights())
        self.output_dense.set_weights(training_line.output_dense.get_weights())

generator_lines = [GeneratorLine('generator_line_%s' % i, lines[i], generator_lstm) for i in range(3)]        
generator_lstm.set_weights(lstm.get_weights())

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
for _ in range(10):
    syllables = [5, 7, 5]
    h = None
    c = None
    #next_char = 4
    next_char = t.texts_to_sequences(chr(int(np.random.randint(ord('a'), ord('z')+1))))[0][0]

    for i in range(3):
        l = generator_lines[i]

        s = tf_session.run(
            l.syllable_dense_output,
            feed_dict={
                l.syllable_input: [[syllables[i]]]
            }
        )

        if h is None:
            h = s
            c = s
        else:
            h = h + s
            c = c + s

        line = [next_char]

        end = False
        next_char = None
        for i in range(max_line_len):
            char, h, c = tf_session.run(
                [l.output, l.lstm_h, l.lstm_c],
                feed_dict={
                    l.char_input: [[np_utils.to_categorical(line[-1], num_classes=n_tokens)]],
                    l.h_input: h,
                    l.c_input: c
                }
            )

            #char = np.argmax(char)
            char = sample(char[0,0], .6)
            if char == 1 and not end:
                end = True
            if char != 1 and end:
                next_char = char
                char = 1

            line.append(char)

        print(t.sequences_to_texts([line])[0].strip()[1:].replace('   ', '\n').replace(' ', '').replace('\n', ' '))
    print()
# Out:
# my hose with beauty
# in the morning house and white
# in a summer sky
#
# valentine's day
# we pass the fresh prayer of sin
# when sunset skin in
#
# xingle on the wind
# before the horizon bath
# a dust of the floor
#
# black with my shorefled
# in the higher wake a skin
# is the music night
#
# kingened towerder
# the fallen path of the weeds
# in the water streen
#
# beloved be ond glass
# which the distant was i blowd
# the tall of woth sun
#
# jaran sunset---
# i am a some one but on
# he last sunshine and with
#
# ghest though shall but the
# for we come of this hour of wine
# a white bene they rest
#
# kitchen the deep freeds
# the candle of the window
# on the star pitches
#
# o sunshine stars the
# love to watch the scent of the
# thus to deep on thee

# %%
word = 'today is celebrating'
df[df['0'].str.contains(word) | df['1'].str.contains(word) | df['2'].str.contains(word) ]
# Out:
#                                                        0  \
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
#
#                                                      1  \
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
# 15708  today everything is bright  cheerful  a chimera
#
#                                   2 0_syllables 1_syllables 2_syllables  \
# 15708  today is the feast of spring          16          13           8
# 15708  today is the feast of spring          16          13           7
# 15708  today is the feast of spring          17          13           8
# 15708  today is the feast of spring          17          13           7
# 15708  today is the feast of spring          18          13           8
# 15708  today is the feast of spring          18          13           7
# 15708  today is the feast of spring          19          13           8
# 15708  today is the feast of spring          19          13           7
#
#                                                     0_in  \
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
# 15708  eevery place  every thing  every house today i...
#
#                                                    0_out  \
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
# 15708  every place  every thing  every house today is...
#
#                                                     1_in  \
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
# 15708  ttoday everything is bright  cheerful  a chime...
#
#                                                    1_out  \
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
# 15708  today everything is bright  cheerful  a chimer...
#
#                                                     2_in  \
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
# 15708  ttoday is the feast of spring\n\n\n\n\n\n\n\n\...
#
#                                                    2_out
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...
# 15708  today is the feast of spring\n\n\n\n\n\n\n\n\n...

# %%
t.texts_to_sequences(['a', 'b', 'c'])
# Out:
# [[5], [21], [19]]

# %%
t.index_word
# Out:
# {1: '\n',
#  2: ' ',
#  3: 'e',
#  4: 't',
#  5: 'a',
#  6: 'o',
#  7: 's',
#  8: 'n',
#  9: 'i',
#  10: 'r',
#  11: 'h',
#  12: 'l',
#  13: 'd',
#  14: 'u',
#  15: 'm',
#  16: 'w',
#  17: 'f',
#  18: 'g',
#  19: 'c',
#  20: 'y',
#  21: 'b',
#  22: 'p',
#  23: 'k',
#  24: 'v',
#  25: '-',
#  26: "'",
#  27: '.',
#  28: 'j',
#  29: 'z',
#  30: 'x',
#  31: 'q',
#  32: '?',
#  33: ':',
#  34: ',',
#  35: '[',
#  36: '\x97',
#  37: '`',
#  38: '_',
#  39: '(',
#  40: ')',
#  41: '1',
#  42: '"',
#  43: '~',
#  44: '0',
#  45: '!',
#  46: '2',
#  47: ';',
#  48: '\x92',
#  49: '>',
#  50: '3',
#  51: '<',
#  52: '/',
#  53: '7',
#  54: '8',
#  55: '&',
#  56: '4',
#  57: '\xa0',
#  58: '\x96',
#  59: '6',
#  60: 'é',
#  61: '5',
#  62: '9',
#  63: ']',
#  64: '\x85',
#  65: '*',
#  66: '\u200b',
#  67: '=',
#  68: '{',
#  69: 'ä',
#  70: '@',
#  71: '%',
#  72: '…',
#  73: 'ê'}

# %%
np.random.randint(ord('a'), ord('z')+1)#, 100).max()
# Out:
# 118

# %%
ord('z')
# Out:
# 122

# %%
chr(int(np.random.randint(ord('a'), ord('z')+1)))
# Out:
# 'e'

# %%
t.texts_to_sequences(chr(int(np.random.randint(ord('a'), ord('z')+1))))[0]
# Out:
# [29]
